# %% [markdown]
# # Imports and utility

# %%
# !pip install -q --upgrade keras-hub
#d8f53b61969adf7ee621c216f680b707
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns
import cv2
import keras_hub
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models
from tensorflow.keras.layers import (Input, Conv2D, MaxPooling2D, Flatten, Dense, Dropout,
                                     BatchNormalization, Activation, GlobalAveragePooling2D)
from tensorflow.keras.applications import VGG16, VGG19, ResNet50, ResNet152, EfficientNetB0, DenseNet121, InceptionV3
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, LearningRateScheduler, ModelCheckpoint
from tensorflow.keras import optimizers
import keras_hub

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'   # 0 = todo, 1 = INFO, 2 = WARNING, 3 = ERROR
tf.get_logger().setLevel('ERROR')

train_dir = '/kaggle/input/knee-osteoarthritis-dataset-with-severity/train'
val_dir = '/kaggle/input/knee-osteoarthritis-dataset-with-severity/val'
test_dir = '/kaggle/input/knee-osteoarthritis-dataset-with-severity/test'
auto_test = '/kaggle/input/knee-osteoarthritis-dataset-with-severity/auto_test'
cat_dir = '/kaggle/input/cat-knee/clean'

IMG_SIZE = (224, 224)
BATCH_SIZE = 8
SEED = 66
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 792.1/792.1 kB 17.7 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# keras-nlp 0.18.1 requires keras-hub==0.18.1, but you have keras-hub 0.20.0 which is incompatible.

# %%
import pandas as pd
import os

def create_dataframe_from_directory(base_dir, regression=False):
    data = []
    for label_str in sorted(os.listdir(base_dir)):
        label_path = os.path.join(base_dir, label_str)
        if not os.path.isdir(label_path):
            continue
        label = float(label_str) if regression else label_str
        for fname in os.listdir(label_path):
            data.append({
                'filename': os.path.join(label_str, fname),  # ruta relativa
                'label': label  # KL debe ser numérico para regresión
            })
    return pd.DataFrame(data)

# %%
from sklearn.metrics import mean_absolute_error, accuracy_score
import numpy as np
import tensorflow as tf

class CatValidationCallback(tf.keras.callbacks.Callback):
    def __init__(self, cat_generator, regresion=False, filepath='best_model_cat.keras'):
        super().__init__()
        self.cat_generator = cat_generator
        self.epoch_metrics = []
        self.regresion = regresion
        self.filepath = filepath
        # Inicializamos best_score y best_loss
        if regresion:
            self.best_score = 0.0    # queremos maximizar accuracy
            self.best_loss  = np.inf # y minimizar MAE
        else:
            self.best_score = 0.0    # queremos maximizar accuracy
            self.best_loss  = np.inf # y minimizar categorical loss

    def on_epoch_end(self, epoch, logs=None):
        # Predicciones
        preds = self.model.predict(self.cat_generator, verbose=0)

        if self.regresion:
            # Regresión: calculamos MAE + accuracy sobre clases redondeadas
            y_pred = preds.flatten()
            y_true = self.cat_generator.labels
            loss = mean_absolute_error(y_true, y_pred)
            y_pred_class = np.clip(np.round(y_pred), 0, 4).astype(int)
            y_true_class = np.clip(np.round(y_true), 0, 4).astype(int)
            acc = accuracy_score(y_true_class, y_pred_class)
            score = acc
        else:
            # Clasificación: evalúa el loss y la accuracy
            loss, acc = self.model.evaluate(self.cat_generator, verbose=0)
            preds_class = np.argmax(preds, axis=1)
            y_true = self.cat_generator.classes
            # para consistency, recalculamos acc con sklearn
            acc = accuracy_score(y_true, preds_class)
            score = acc

        # Guardar métricas
        self.epoch_metrics.append({
            'epoch': epoch + 1,
            'val_cat_loss': loss,
            'val_cat_accuracy': acc
        })

        # Mostrar por consola
        tag = "MAE" if self.regresion else "Loss"
        print(f"🐾 [Cat Val] {tag}: {loss:.4f} | Accuracy: {acc:.4f}")

        # Comprobamos mejora: primero por score, si empate por loss
        improved = False
        if score > self.best_score:
            improved = True
        elif score == self.best_score and loss < self.best_loss:
            improved = True

        # Si mejoró, guardamos modelo y actualizamos referencias
        if improved:
            self.best_score = score
            self.best_loss  = loss
            self.model.save(self.filepath)
            print(f"📦 Modelo mejorado guardado en {self.filepath}")

# %%
from tensorflow.keras.callbacks import ModelCheckpoint

def get_callbacks(regression=False, cat_gen=None):
  cat_val_cb = CatValidationCallback(cat_gen, regresion=regression)
  

  checkpoint_cb = ModelCheckpoint(
    filepath='best_model.keras',
    monitor='val_accuracy',         # nombre de la métrica a monitorizar
    mode='max',                     # porque buscamos la mayor precisión
    save_best_only=True,
    save_weights_only=False,
    verbose=1
  )
  checkpoint_cb_reg = ModelCheckpoint(
    filepath='best_model.keras',
    monitor='val_loss',
    mode='min',
    save_best_only=True,
    save_weights_only=False,
    verbose=1
  )
  if regression:
    callbacks = [
        EarlyStopping(patience=10, restore_best_weights=True),
        ReduceLROnPlateau(factor=0.5, patience=5, verbose=1),
        cat_val_cb,
        checkpoint_cb_reg
    ]
  else:
    callbacks = [
        EarlyStopping(patience=10, restore_best_weights=True),
        ReduceLROnPlateau(factor=0.5, patience=5, verbose=1),
        cat_val_cb,
        checkpoint_cb
    ]
  return callbacks

# %%
from sklearn.metrics import classification_report, confusion_matrix, mean_absolute_error
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt


def _get_label_map(y_true, y_pred, generator=None, default_prefix="KL"):
    """
    Genera un mapa de etiquetas automáticamente:
    - Si el generador tiene `class_indices`, lo usa.
    - Si no, extrae las clases únicas de `y_true` y `y_pred`.
    - Si todo falla, crea etiquetas "KL 0", "KL 1", ..., según el número de clases.
    """
    # Caso Keras ImageDataGenerator con class_indices
    if generator is not None and hasattr(generator, 'class_indices'):
        sorted_items = sorted(generator.class_indices.items(), key=lambda x: x[1])
        return [name for name, _ in sorted_items]

    # Extraer clases únicas
    classes = np.unique(np.concatenate((y_true, y_pred)))

    # Si son enteros consecutivos desde 0 a n-1
    if np.array_equal(classes, np.arange(len(classes))):
        return [f"{default_prefix} {i}" for i in classes]

    # En otro caso, convertir cada clase a string
    return [str(c) for c in classes]


def evaluate_classification(y_true, y_pred, label_map=None, digits=4, title_suffix=""):
    """
    Imprime el reporte de clasificación y muestra la matriz de confusión.
    """
    if label_map is None:
        label_map = _get_label_map(y_true, y_pred)

    # Reporte de métricas
    print(classification_report(
        y_true,
        y_pred,
        target_names=label_map,
        digits=digits
    ))

    # Matriz de confusión
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(8, 6))
    sns.heatmap(
        cm,
        annot=True,
        fmt='d',
        cmap='Blues',
        xticklabels=label_map,
        yticklabels=label_map
    )
    plt.xlabel('Predicción')
    plt.ylabel('Etiqueta verdadera')

    if title_suffix:
        plt.title(title_suffix)

    plt.show()


def evaluate_model(model, regression, generator, label_map=None, digits=4):
    """
    Evalúa un modelo de Keras:
    - Si `regression=True`, calcula MAE y scatter plot, luego convierte a clases para el reporte.
    - Si `regression=False`, calcula reporte y matriz de confusión directamente.

    Parámetros:
    - model: modelo Keras ya entrenado.
    - regression: bool, True para regresión.
    - generator: generador Keras (ImageDataGenerator).
    - label_map: lista opcional de nombres de clases.
    - digits: número de dígitos en el reporte.
    """
    # Predicciones
    preds = model.predict(generator)

    if regression:
        # Valores continuos
        if hasattr(generator, 'labels'):
            y_true_cont = np.array(generator.labels).flatten()
        else:
            y_true_cont = np.array(generator.classes).flatten()
        y_pred_cont = preds.flatten()

        # MAE y scatter
        mae = mean_absolute_error(y_true_cont, y_pred_cont)
        print(f"Mean Absolute Error (MAE): {mae:.{digits}f}\n")

        plt.figure(figsize=(6, 6))
        plt.scatter(y_pred_cont, y_true_cont, alpha=0.5)
        mn, mx = min(y_true_cont.min(), y_pred_cont.min()), max(y_true_cont.max(), y_pred_cont.max())
        plt.plot([mn, mx], [mn, mx], 'r--', linewidth=1)
        plt.xlabel("Predicción (decimal)")
        plt.ylabel("Valor verdadero")
        plt.title("Scatter: Predicción vs Valor verdadero")
        plt.grid(True)
        plt.show()

        # Convertir a clases enteras
        y_true_cls = np.clip(np.round(y_true_cont).astype(int), 0, None)
        y_pred_cls = np.clip(np.round(y_pred_cont).astype(int), 0, None)

        if label_map is None:
            max_lbl = max(y_true_cls.max(), y_pred_cls.max())
            label_map = [f"KL {i}" for i in range(max_lbl + 1)]

        evaluate_classification(y_true_cls, y_pred_cls, label_map, digits)

    else:
        # Clasificación multiclase
        y_pred = np.argmax(preds, axis=1)
        y_true = generator.classes

        if label_map is None:
            label_map = _get_label_map(y_true, y_pred, generator)

        evaluate_classification(y_true, y_pred, label_map, digits)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import pandas as pd

def get_datagen(
    tarea: int,
    path: str,
    regression: bool = False,
    IMG_SIZE: tuple = (224, 224),
    BATCH_SIZE: int = 32,
    SEED: int = 42,
    augment: bool = False
):
    """
    Generador de imágenes para clasificación y regresión con distintos esquemas de tarea.

    Parámetros:
        tarea       – entero 0–5 que define esquema de etiquetas.
        path        – ruta al directorio de imágenes (train/val/test u otro).
        regression  – True para regresión (class_mode='raw'), False para clasificación.
        IMG_SIZE    – tupla (alto, ancho).
        BATCH_SIZE  – tamaño de lote.
        SEED        – semilla aleatoria.
        augment     – True para data augmentation (solo en entrenamiento).
    """
    # Configurar DataGenerator
    if augment:
        datagen = ImageDataGenerator(
            rescale=1./255,
            rotation_range=10,
            width_shift_range=0.1,
            height_shift_range=0.1,
            zoom_range=0.1,
            horizontal_flip=True
        )
        shuffle = True
    else:
        datagen = ImageDataGenerator(rescale=1./255)
        shuffle = False

    # Cargar dataframe con tu función; label como float si regresión, str si clasificación
    df = create_dataframe_from_directory(path, regression=regression)
    # Clasificación: convertir labels a ints para procesar tareas
    df_proc = df.copy()
    df_proc['label'] = df_proc['label'].astype(int)

    if tarea == 0:
        # Multiclase original 0–4: no cambio
        pass
    elif tarea == 1:
        df_proc['label'] = df_proc['label'].apply(
            lambda x: 0 if x in [0,1,2] else 1 if x == 3 else 2 if x == 4 else x
        )
    elif tarea in [2,3,4,5]:
        target = tarea - 1  # tarea=2->1, etc.
        df_proc = df_proc[df_proc['label'].isin([0, target])]
        df_proc['label'] = df_proc['label'].apply(lambda x: 1 if x == target else 0)
    elif tarea == 6:
        print("Detección binaria de artrosis")
        df_proc['label'] = df_proc['label'].apply(
            lambda x: 0 if x in [0] else 1
        )
    else:
        raise ValueError("tarea debe ser un entero entre 0 y 5.")

    if regression:
        # Asegurar float
        df_proc['label'] = df_proc['label'].astype(float)
        return datagen.flow_from_dataframe(
            dataframe=df_proc,
            directory=path,
            x_col='filename',
            y_col='label',
            target_size=IMG_SIZE,
            batch_size=BATCH_SIZE,
            class_mode='raw',
            shuffle=shuffle,
            seed=SEED
        )
    # Convertir a string para class_mode='categorical'
    df_proc['label'] = df_proc['label'].astype(str)
    
    # Generador de clasificación
    return datagen.flow_from_dataframe(
        dataframe=df_proc,
        directory=path,
        x_col='filename',
        y_col='label',
        target_size=IMG_SIZE,
        batch_size=BATCH_SIZE,
        class_mode='categorical',
        shuffle=shuffle,
        seed=SEED
    )

# %% [markdown]
# ## Experimentos a realizar
#
# Normal
# 012-3-4
# 0-1
# 0-2
# 0-3
# 0-4

# %%
def cnn_pequeno(num_classes = 5, regression=False):
    activation = 'linear' if regression else 'softmax'
    model = models.Sequential([
        layers.Conv2D(16, (3,3), activation='relu',
                      input_shape=(224,224,3)),
        layers.MaxPooling2D(2,2),
        layers.Flatten(),
        layers.Dense(num_classes, activation=activation)
    ])
    return model

# %%
def cnn_mediana(num_classes, regression=False):
    activation = 'linear' if regression else 'softmax'
    model = models.Sequential([
        # Primera capa convolucional
        Conv2D(32, (3, 3), activation='relu', padding='same', input_shape=(224,224,3)),
        MaxPooling2D((2, 2)),
        # Segunda capa convolucional
        Conv2D(64, (3, 3), activation='relu', padding='same'),
        MaxPooling2D((2, 2)),
        # Aplanamiento y capas densas
        Flatten(),
        Dense(128, activation='relu'),
        Dense(num_classes, activation=activation)
    ])
    return model

# %%
import os
import tensorflow as tf

def get_dataset(
    tarea: int,
    path: str,
    regression: bool = False,
    IMG_SIZE: tuple = (224, 224),
    BATCH_SIZE: int = 32,
    SEED: int = 42,
    augment: bool = False
):
    # 1. Construir lista de rutas y etiquetas según tu esquema de 'tarea'
    df = create_dataframe_from_directory(path, regression=regression)
    df['label'] = df['label'].astype(int)
    # aplicar transformaciones de 'tarea' sobre df['label']...
    # (idéntico a tu lógica original)

    file_paths = df['filename'].apply(lambda f: os.path.join(path, f)).tolist()
    labels = df['label'].tolist()

    # 2. Crear tf.data.Dataset
    ds = tf.data.Dataset.from_tensor_slices((file_paths, labels))

    # 3. Shuffle ligero (buffer pequeño)
    if not regression:
        ds = ds.shuffle(buffer_size=1000, seed=SEED)

    # 4. Función de lectura y preprocesado
    def _load_and_preprocess(fp, lbl):
        img = tf.io.read_file(fp)
        img = tf.image.decode_jpeg(img, channels=3)
        img = tf.image.resize(img, IMG_SIZE)
        img = img / 255.0
        if augment:
            img = tf.image.random_flip_left_right(img)
            img = tf.image.random_brightness(img, max_delta=0.1)
            img = tf.image.random_contrast(img, lower=0.9, upper=1.1)
        return img, tf.cast(lbl, tf.float32 if regression else tf.int32)

    # 5. Map paralelo y batching
    ds = ds.map(_load_and_preprocess, num_parallel_calls=tf.data.AUTOTUNE)
    ds = ds.batch(BATCH_SIZE)
    # 6. Prefetch mínimo (sin cache)
    ds = ds.prefetch(buffer_size=tf.data.AUTOTUNE)

    return ds

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (
    GlobalAveragePooling2D, BatchNormalization,
    Dropout, Dense
)
from tensorflow.keras.applications import EfficientNetB0, EfficientNetB7

def efficientnetB0_model(num_classes, regression=False, frozen=False):
    """
    Modelo basado en EfficientNetB0 con cabeza personalizada.
    - Input: 224×224×3
    - Preentrenado en ImageNet
    - Arquitectura secuencial
    """
    activation = 'linear' if regression else 'softmax'
    if num_classes == 2:
        activation='sigmoid'
    # Cargamos la base EfficientNetB0 sin la capa superior
    base = EfficientNetB0(
        include_top=False,
        weights='imagenet',
        input_shape=(224, 224, 3)
    )
    if frozen:
        base.trainable = False
    model = Sequential(name="EfficientNetB0_Custom")
    model.add(base)
    model.add(GlobalAveragePooling2D())
    model.add(BatchNormalization())
    model.add(Dropout(0.50))
    model.add(Dense(256, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.50))
    model.add(Dense(num_classes, activation=activation))
    return model

def efficientnetB7_model(num_classes, regression=False):
    """
    Modelo basado en EfficientNetB7 con cabeza personalizada.
    - Preentrenado en ImageNet
    - Arquitectura secuencial
    """
    activation = 'linear' if regression else 'softmax'
    base = EfficientNetB7(
        include_top=False,
        weights='imagenet',
        input_shape=(224, 224, 3)
    )
    model = Sequential(name="EfficientNetB7_Custom")
    model.add(base)
    model.add(GlobalAveragePooling2D())
    model.add(BatchNormalization())
    model.add(Dropout(0.50))
    model.add(Dense(256, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.50))
    model.add(Dense(num_classes, activation=activation))
    return model

# %%
def simple_transformer(num_classes=5, regression=False):
    activation = 'linear' if regression else 'softmax'

    inputs = layers.Input(shape=(224, 224, 3))
    x = layers.Conv2D(32, (3, 3), padding='same')(inputs)
    x = layers.Reshape((-1, 32))(x)
    x = layers.MultiHeadAttention(num_heads=1, key_dim=4)(x, x)
    x = layers.GlobalAveragePooling1D()(x)
    x = layers.Dense(128, activation='relu')(x)
    outputs = layers.Dense(num_classes, activation=activation)(x)

    model = models.Model(inputs, outputs)
    return model

# %%
def ajuan_transformer(num_classes=5, regression=False):
    activation = 'linear' if regression else 'softmax'

    backbone = 'vit_base_patch16_224_imagenet21k'
    M = keras_hub.models.ViTImageClassifier.from_preset(backbone, num_classes=40, activation=activation, dropout=0.5)
    return M

# %%
regression = False
tarea = 5
frozen=False
batch_size = 32
num_classes = 5
if regression:
    num_classes = 1
elif tarea == 1:
    num_classes = 3
elif tarea > 1:
    num_classes = 2

loss = 'mean_squared_error' if regression else 'categorical_crossentropy'
metrics = ['mae'] if regression else ['accuracy']

# Generadores de datos (entrenamiento y validación)
train_gen = get_datagen(tarea=tarea, path=train_dir, regression=regression, BATCH_SIZE=batch_size, augment=True)
val_gen   = get_datagen(tarea=tarea, path=val_dir,  BATCH_SIZE=batch_size, regression=regression)
cat_gen = get_datagen(tarea=tarea, path=cat_dir, BATCH_SIZE=batch_size, regression=regression)


model = efficientnetB0_model(num_classes, regression)
model.compile(optimizer='adam',
                  loss=loss,
                  metrics=metrics)
callbacks=get_callbacks(regression, cat_gen)
history = model.fit(
    train_gen,
    verbose=1,
    validation_data=val_gen,
    epochs=50,
    callbacks=callbacks
)

model.load_weights('best_model.keras')
# Obtén el diccionario original {etiqueta_str: índice_entero}
evaluate_model(model, regression=regression, generator=val_gen)
model.load_weights('best_model_cat.keras')
evaluate_model(model, regression=regression, generator=cat_gen)
# Out:
# Found 2459 validated image filenames belonging to 2 classes.
# Found 355 validated image filenames belonging to 2 classes.
# Found 24 validated image filenames belonging to 2 classes.
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Epoch 1/50
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 924ms/step - accuracy: 0.6101 - loss: 1.0080🐾 [Cat Val] Loss: 0.9812 | Accuracy: 0.1250
# 📦 Modelo mejorado guardado en best_model_cat.keras
#
# Epoch 1: val_accuracy improved from -inf to 0.08732, saving model to best_model.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 169s 1s/step - accuracy: 0.6112 - loss: 1.0047 - val_accuracy: 0.0873 - val_loss: 0.9062 - learning_rate: 0.0010
# Epoch 2/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 338ms/step - accuracy: 0.8761 - loss: 0.3217🐾 [Cat Val] Loss: 1.9618 | Accuracy: 0.9167
# 📦 Modelo mejorado guardado en best_model_cat.keras
#
# Epoch 2: val_accuracy improved from 0.08732 to 0.92394, saving model to best_model.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 32s 381ms/step - accuracy: 0.8766 - loss: 0.3211 - val_accuracy: 0.9239 - val_loss: 0.7146 - learning_rate: 0.0010
# Epoch 3/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step - accuracy: 0.9516 - loss: 0.1784🐾 [Cat Val] Loss: 2.9392 | Accuracy: 0.7083
#
# Epoch 3: val_accuracy did not improve from 0.92394
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 30s 357ms/step - accuracy: 0.9517 - loss: 0.1780 - val_accuracy: 0.9183 - val_loss: 3.3136 - learning_rate: 0.0010
# Epoch 4/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step - accuracy: 0.9883 - loss: 0.0861🐾 [Cat Val] Loss: 5.8579 | Accuracy: 0.5833
#
# Epoch 4: val_accuracy did not improve from 0.92394
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 30s 358ms/step - accuracy: 0.9883 - loss: 0.0859 - val_accuracy: 0.8704 - val_loss: 6.0319 - learning_rate: 0.0010
# Epoch 5/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step - accuracy: 0.9849 - loss: 0.0716🐾 [Cat Val] Loss: 21.7195 | Accuracy: 0.4167
#
# Epoch 5: val_accuracy did not improve from 0.92394
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 30s 352ms/step - accuracy: 0.9849 - loss: 0.0716 - val_accuracy: 0.9070 - val_loss: 12.9168 - learning_rate: 0.0010
# Epoch 6/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 336ms/step - accuracy: 0.9872 - loss: 0.0507🐾 [Cat Val] Loss: 1.9198 | Accuracy: 0.5417
#
# Epoch 6: val_accuracy did not improve from 0.92394
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 30s 355ms/step - accuracy: 0.9873 - loss: 0.0507 - val_accuracy: 0.8535 - val_loss: 3.4595 - learning_rate: 0.0010
# Epoch 7/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step - accuracy: 0.9949 - loss: 0.0244
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 🐾 [Cat Val] Loss: 0.4526 | Accuracy: 0.7917
#
# Epoch 7: val_accuracy did not improve from 0.92394
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 30s 358ms/step - accuracy: 0.9949 - loss: 0.0244 - val_accuracy: 0.4648 - val_loss: 5.8558 - learning_rate: 0.0010
# Epoch 8/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 337ms/step - accuracy: 0.9947 - loss: 0.0170🐾 [Cat Val] Loss: 0.3232 | Accuracy: 0.9167
# 📦 Modelo mejorado guardado en best_model_cat.keras
#
# Epoch 8: val_accuracy did not improve from 0.92394
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 31s 367ms/step - accuracy: 0.9947 - loss: 0.0170 - val_accuracy: 0.6817 - val_loss: 2.7980 - learning_rate: 5.0000e-04
# Epoch 9/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 338ms/step - accuracy: 0.9958 - loss: 0.0176🐾 [Cat Val] Loss: 0.3100 | Accuracy: 0.9167
# 📦 Modelo mejorado guardado en best_model_cat.keras
#
# Epoch 9: val_accuracy did not improve from 0.92394
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 31s 368ms/step - accuracy: 0.9958 - loss: 0.0176 - val_accuracy: 0.9211 - val_loss: 0.3088 - learning_rate: 5.0000e-04
# Epoch 10/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step - accuracy: 0.9987 - loss: 0.0094🐾 [Cat Val] Loss: 0.0734 | Accuracy: 0.9583
# 📦 Modelo mejorado guardado en best_model_cat.keras
#
# Epoch 10: val_accuracy improved from 0.92394 to 0.97183, saving model to best_model.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 32s 381ms/step - accuracy: 0.9987 - loss: 0.0094 - val_accuracy: 0.9718 - val_loss: 0.1092 - learning_rate: 5.0000e-04
# Epoch 11/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 337ms/step - accuracy: 0.9985 - loss: 0.0126🐾 [Cat Val] Loss: 0.2462 | Accuracy: 0.9167
#
# Epoch 11: val_accuracy improved from 0.97183 to 0.99437, saving model to best_model.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 31s 367ms/step - accuracy: 0.9985 - loss: 0.0127 - val_accuracy: 0.9944 - val_loss: 0.0200 - learning_rate: 5.0000e-04
# Epoch 12/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 336ms/step - accuracy: 0.9945 - loss: 0.0224🐾 [Cat Val] Loss: 0.1312 | Accuracy: 0.9167
#
# Epoch 12: val_accuracy did not improve from 0.99437
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 30s 355ms/step - accuracy: 0.9945 - loss: 0.0224 - val_accuracy: 0.9944 - val_loss: 0.0229 - learning_rate: 5.0000e-04
# Epoch 13/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 337ms/step - accuracy: 0.9983 - loss: 0.0089🐾 [Cat Val] Loss: 0.2297 | Accuracy: 0.9167
#
# Epoch 13: val_accuracy improved from 0.99437 to 0.99718, saving model to best_model.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 31s 368ms/step - accuracy: 0.9983 - loss: 0.0089 - val_accuracy: 0.9972 - val_loss: 0.0044 - learning_rate: 5.0000e-04
# Epoch 14/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step - accuracy: 0.9992 - loss: 0.0078🐾 [Cat Val] Loss: 0.1125 | Accuracy: 0.9583
#
# Epoch 14: val_accuracy improved from 0.99718 to 1.00000, saving model to best_model.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 31s 370ms/step - accuracy: 0.9992 - loss: 0.0078 - val_accuracy: 1.0000 - val_loss: 0.0035 - learning_rate: 5.0000e-04
# Epoch 15/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step - accuracy: 0.9992 - loss: 0.0081🐾 [Cat Val] Loss: 0.0605 | Accuracy: 0.9583
# 📦 Modelo mejorado guardado en best_model_cat.keras
#
# Epoch 15: val_accuracy did not improve from 1.00000
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 31s 365ms/step - accuracy: 0.9992 - loss: 0.0081 - val_accuracy: 0.9972 - val_loss: 0.0032 - learning_rate: 5.0000e-04
# Epoch 16/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 337ms/step - accuracy: 0.9998 - loss: 0.0032🐾 [Cat Val] Loss: 0.2514 | Accuracy: 0.9167
#
# Epoch 16: val_accuracy did not improve from 1.00000
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 30s 354ms/step - accuracy: 0.9998 - loss: 0.0032 - val_accuracy: 0.9972 - val_loss: 0.0043 - learning_rate: 5.0000e-04
# Epoch 17/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step - accuracy: 0.9994 - loss: 0.0067🐾 [Cat Val] Loss: 0.3198 | Accuracy: 0.9167
#
# Epoch 17: val_accuracy did not improve from 1.00000
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 30s 353ms/step - accuracy: 0.9994 - loss: 0.0067 - val_accuracy: 0.9944 - val_loss: 0.0200 - learning_rate: 5.0000e-04
# Epoch 18/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 343ms/step - accuracy: 0.9994 - loss: 0.0038🐾 [Cat Val] Loss: 0.0896 | Accuracy: 0.9583
#
# Epoch 18: val_accuracy did not improve from 1.00000
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 30s 362ms/step - accuracy: 0.9994 - loss: 0.0039 - val_accuracy: 1.0000 - val_loss: 0.0030 - learning_rate: 5.0000e-04
# Epoch 19/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step - accuracy: 0.9961 - loss: 0.0190🐾 [Cat Val] Loss: 0.1490 | Accuracy: 0.9583
#
# Epoch 19: val_accuracy did not improve from 1.00000
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 30s 351ms/step - accuracy: 0.9961 - loss: 0.0190 - val_accuracy: 0.9972 - val_loss: 0.0124 - learning_rate: 5.0000e-04
# Epoch 20/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 343ms/step - accuracy: 0.9905 - loss: 0.0568🐾 [Cat Val] Loss: 0.0917 | Accuracy: 0.9583
#
# Epoch 20: val_accuracy did not improve from 1.00000
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 30s 362ms/step - accuracy: 0.9905 - loss: 0.0565 - val_accuracy: 0.9944 - val_loss: 0.0136 - learning_rate: 5.0000e-04
# Epoch 21/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 336ms/step - accuracy: 0.9970 - loss: 0.0103🐾 [Cat Val] Loss: 0.1210 | Accuracy: 0.9583
#
# Epoch 21: val_accuracy did not improve from 1.00000
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 30s 354ms/step - accuracy: 0.9970 - loss: 0.0103 - val_accuracy: 0.9972 - val_loss: 0.0078 - learning_rate: 5.0000e-04
# Epoch 22/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step - accuracy: 0.9981 - loss: 0.0077🐾 [Cat Val] Loss: 0.0888 | Accuracy: 0.9583
#
# Epoch 22: val_accuracy did not improve from 1.00000
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 30s 352ms/step - accuracy: 0.9981 - loss: 0.0077 - val_accuracy: 0.9915 - val_loss: 0.0162 - learning_rate: 5.0000e-04
# Epoch 23/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step - accuracy: 0.9984 - loss: 0.0104
# Epoch 23: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 🐾 [Cat Val] Loss: 0.2204 | Accuracy: 0.9583
#
# Epoch 23: val_accuracy did not improve from 1.00000
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 30s 352ms/step - accuracy: 0.9984 - loss: 0.0105 - val_accuracy: 0.9746 - val_loss: 0.0906 - learning_rate: 5.0000e-04
# Epoch 24/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step - accuracy: 0.9985 - loss: 0.0043🐾 [Cat Val] Loss: 0.2878 | Accuracy: 0.9167
#
# Epoch 24: val_accuracy did not improve from 1.00000
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 30s 353ms/step - accuracy: 0.9985 - loss: 0.0043 - val_accuracy: 0.9944 - val_loss: 0.0207 - learning_rate: 2.5000e-04
# Epoch 25/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 338ms/step - accuracy: 0.9983 - loss: 0.0047🐾 [Cat Val] Loss: 0.3615 | Accuracy: 0.9167
#
# Epoch 25: val_accuracy did not improve from 1.00000
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 30s 356ms/step - accuracy: 0.9983 - loss: 0.0047 - val_accuracy: 0.9972 - val_loss: 0.0060 - learning_rate: 2.5000e-04
# Epoch 26/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 341ms/step - accuracy: 0.9971 - loss: 0.0090🐾 [Cat Val] Loss: 0.4174 | Accuracy: 0.9167
#
# Epoch 26: val_accuracy did not improve from 1.00000
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 30s 360ms/step - accuracy: 0.9971 - loss: 0.0089 - val_accuracy: 0.9972 - val_loss: 0.0058 - learning_rate: 2.5000e-04
# Epoch 27/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 348ms/step - accuracy: 0.9996 - loss: 0.0030🐾 [Cat Val] Loss: 0.4814 | Accuracy: 0.9167
#
# Epoch 27: val_accuracy did not improve from 1.00000
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 31s 367ms/step - accuracy: 0.9996 - loss: 0.0030 - val_accuracy: 1.0000 - val_loss: 0.0021 - learning_rate: 2.5000e-04
# Epoch 28/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step - accuracy: 0.9999 - loss: 0.0023🐾 [Cat Val] Loss: 0.5319 | Accuracy: 0.9167
#
# Epoch 28: val_accuracy did not improve from 1.00000
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 30s 359ms/step - accuracy: 0.9999 - loss: 0.0023 - val_accuracy: 0.9972 - val_loss: 0.0047 - learning_rate: 2.5000e-04
# Epoch 29/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 341ms/step - accuracy: 1.0000 - loss: 0.0020🐾 [Cat Val] Loss: 0.6025 | Accuracy: 0.9167
#
# Epoch 29: val_accuracy did not improve from 1.00000
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 31s 362ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 1.0000 - val_loss: 6.3739e-04 - learning_rate: 2.5000e-04
# Epoch 30/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 343ms/step - accuracy: 1.0000 - loss: 0.0012🐾 [Cat Val] Loss: 0.5598 | Accuracy: 0.9167
#
# Epoch 30: val_accuracy did not improve from 1.00000
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 30s 362ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 1.0000 - val_loss: 0.0010 - learning_rate: 2.5000e-04
# Epoch 31/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 1.0000 - loss: 0.0014🐾 [Cat Val] Loss: 0.5741 | Accuracy: 0.9167
#
# Epoch 31: val_accuracy did not improve from 1.00000
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 31s 365ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 1.0000 - val_loss: 6.9098e-04 - learning_rate: 2.5000e-04
# Epoch 32/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 341ms/step - accuracy: 0.9989 - loss: 0.0048🐾 [Cat Val] Loss: 0.3574 | Accuracy: 0.9167
#
# Epoch 32: val_accuracy did not improve from 1.00000
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 30s 360ms/step - accuracy: 0.9989 - loss: 0.0048 - val_accuracy: 0.9915 - val_loss: 0.0541 - learning_rate: 2.5000e-04
# Epoch 33/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 338ms/step - accuracy: 0.9998 - loss: 0.0018🐾 [Cat Val] Loss: 0.3447 | Accuracy: 0.9167
#
# Epoch 33: val_accuracy did not improve from 1.00000
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 30s 358ms/step - accuracy: 0.9998 - loss: 0.0018 - val_accuracy: 0.9972 - val_loss: 0.0040 - learning_rate: 2.5000e-04
# Epoch 34/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 343ms/step - accuracy: 0.9995 - loss: 0.0047
# Epoch 34: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 🐾 [Cat Val] Loss: 0.2886 | Accuracy: 0.9583
#
# Epoch 34: val_accuracy did not improve from 1.00000
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 31s 365ms/step - accuracy: 0.9995 - loss: 0.0047 - val_accuracy: 0.9972 - val_loss: 0.0028 - learning_rate: 2.5000e-04
# Epoch 35/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 337ms/step - accuracy: 0.9999 - loss: 0.0013🐾 [Cat Val] Loss: 0.5078 | Accuracy: 0.9167
#
# Epoch 35: val_accuracy did not improve from 1.00000
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 30s 357ms/step - accuracy: 0.9999 - loss: 0.0013 - val_accuracy: 1.0000 - val_loss: 4.0250e-04 - learning_rate: 1.2500e-04
# Epoch 36/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step - accuracy: 0.9998 - loss: 0.0020🐾 [Cat Val] Loss: 0.5526 | Accuracy: 0.9167
#
# Epoch 36: val_accuracy did not improve from 1.00000
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 30s 360ms/step - accuracy: 0.9998 - loss: 0.0020 - val_accuracy: 1.0000 - val_loss: 6.0067e-04 - learning_rate: 1.2500e-04
# Epoch 37/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 336ms/step - accuracy: 0.9990 - loss: 0.0021🐾 [Cat Val] Loss: 0.5453 | Accuracy: 0.9167
#
# Epoch 37: val_accuracy did not improve from 1.00000
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 30s 355ms/step - accuracy: 0.9990 - loss: 0.0021 - val_accuracy: 1.0000 - val_loss: 0.0012 - learning_rate: 1.2500e-04
# Epoch 38/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 341ms/step - accuracy: 1.0000 - loss: 0.0013🐾 [Cat Val] Loss: 0.5441 | Accuracy: 0.9167
#
# Epoch 38: val_accuracy did not improve from 1.00000
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 30s 359ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 1.0000 - val_loss: 0.0018 - learning_rate: 1.2500e-04
# Epoch 39/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step - accuracy: 1.0000 - loss: 9.6130e-04🐾 [Cat Val] Loss: 0.5461 | Accuracy: 0.9167
#
# Epoch 39: val_accuracy did not improve from 1.00000
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 30s 358ms/step - accuracy: 1.0000 - loss: 9.6148e-04 - val_accuracy: 1.0000 - val_loss: 0.0018 - learning_rate: 1.2500e-04
# Epoch 40/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step - accuracy: 1.0000 - loss: 9.6813e-04
# Epoch 40: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 🐾 [Cat Val] Loss: 0.5507 | Accuracy: 0.9167
#
# Epoch 40: val_accuracy did not improve from 1.00000
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 30s 359ms/step - accuracy: 1.0000 - loss: 9.6641e-04 - val_accuracy: 0.9972 - val_loss: 0.0024 - learning_rate: 1.2500e-04
# Epoch 41/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 337ms/step - accuracy: 1.0000 - loss: 9.2016e-04🐾 [Cat Val] Loss: 0.5452 | Accuracy: 0.9167
#
# Epoch 41: val_accuracy did not improve from 1.00000
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 30s 355ms/step - accuracy: 1.0000 - loss: 9.2084e-04 - val_accuracy: 0.9972 - val_loss: 0.0028 - learning_rate: 6.2500e-05
# Epoch 42/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 341ms/step - accuracy: 1.0000 - loss: 9.1764e-04🐾 [Cat Val] Loss: 0.5533 | Accuracy: 0.9167
#
# Epoch 42: val_accuracy did not improve from 1.00000
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 30s 360ms/step - accuracy: 1.0000 - loss: 9.1855e-04 - val_accuracy: 1.0000 - val_loss: 0.0015 - learning_rate: 6.2500e-05
# Epoch 43/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 1.0000 - loss: 9.4715e-04🐾 [Cat Val] Loss: 0.5322 | Accuracy: 0.9167
#
# Epoch 43: val_accuracy did not improve from 1.00000
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 30s 350ms/step - accuracy: 1.0000 - loss: 9.4976e-04 - val_accuracy: 0.9972 - val_loss: 0.0024 - learning_rate: 6.2500e-05
# Epoch 44/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step - accuracy: 0.9979 - loss: 0.0055🐾 [Cat Val] Loss: 0.4737 | Accuracy: 0.9167
#
# Epoch 44: val_accuracy did not improve from 1.00000
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 30s 355ms/step - accuracy: 0.9979 - loss: 0.0054 - val_accuracy: 0.9972 - val_loss: 0.0028 - learning_rate: 6.2500e-05
# Epoch 45/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step - accuracy: 1.0000 - loss: 9.5979e-04
# Epoch 45: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 🐾 [Cat Val] Loss: 0.5085 | Accuracy: 0.9167
#
# Epoch 45: val_accuracy did not improve from 1.00000
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 30s 351ms/step - accuracy: 1.0000 - loss: 9.6200e-04 - val_accuracy: 0.9972 - val_loss: 0.0025 - learning_rate: 6.2500e-05
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 343ms/step
#               precision    recall  f1-score   support
#
#            0     0.9239    1.0000    0.9605       328
#            1     0.0000    0.0000    0.0000        27
#
#     accuracy                         0.9239       355
#    macro avg     0.4620    0.5000    0.4802       355
# weighted avg     0.8537    0.9239    0.8874       355
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
#               precision    recall  f1-score   support
#
#            0     0.9565    1.0000    0.9778        22
#            1     1.0000    0.5000    0.6667         2
#
#     accuracy                         0.9583        24
#    macro avg     0.9783    0.7500    0.8222        24
# weighted avg     0.9601    0.9583    0.9519        24

# %% [markdown]
# # Anterior

# %% [markdown]
# ## Exploración del dataset de artrosis de rodilla
#
# - **Total de imágenes:** 9 786
#
# | Partición      | Imágenes | Porcentaje |
# |---------------|---------:|-----------:|
# | **Train**      | 5 778    | 59.04 %    |
# | **Validation** |   826    |  8.44 %    |
# | **Test**       | 1 656    | 16.92 %    |
# | **AutoTest**   | 1 526    | 15.59 %    |
#
#
# ### Distribución de clases en `Train`
#
# |  Clase  | Índice | Imágenes | Porcentaje |
# |---------|-------:|---------:|-----------:|
# | Sin     |      0 |    2 286 |     39.56 % |
# | Ligera  |      1 |    1 046 |     18.10 % |
# | Leve    |      2 |    1 516 |     26.24 % |
# | Moderada|      3 |      757 |     13.10 % |
# | Severa  |      4 |      173 |      2.99 % |
