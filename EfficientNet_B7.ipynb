# %% [markdown]
# # Github & Imports

# %%
# !git clone https://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@github.com/Tempus23/Radiography_TFG.git
# Out:
# Cloning into 'Radiography_TFG'...
# remote: Enumerating objects: 2336, done.
# remote: Counting objects: 100% (350/350), done.
# remote: Compressing objects: 100% (236/236), done.
# remote: Total 2336 (delta 205), reused 223 (delta 104), pack-reused 1986 (from 2)
# Receiving objects: 100% (2336/2336), 69.81 MiB | 43.75 MiB/s, done.
# Resolving deltas: 100% (366/366), done.

# %%
import os
import sys
print(os.getcwd())
os.chdir("Radiography_TFG")

sys.path.append("Radiography_TFG")
# Out:
# /kaggle/working

# %%
print(os.getcwd())
print(os.listdir())
# Out:
# /kaggle/working/Radiography_TFG
# ['texput.log', '.git', 'README.md', 'src', 'data.ipynb', 'reducir_brillo.ipynb', 'grad_maps_efficientNet.ipynb', 'Experiment1_capitulo3.ipynb', 'ResNet18_v2', 'HyperParameterSearch.ipynb', 'mendeley_dataset_split.ipynb', 'test_models.ipynb', 'documentos', 'Adamax_Expert1.ipynb', 'grad_maps.ipynb', 'Capitulo3_bright.ipynb', 'mendeleye_dataset_augmentation.ipynb', '10863523_IEE.ipynb', 'mix_datasets.ipynb', 'Capitulo3.ipynb', '.gitignore']

# %%
# !pip install -q lightning
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt

import torch
from torchvision import datasets, transforms
from torch.utils.data import DataLoader

from tensorflow.keras.preprocessing.image import ImageDataGenerator # type: ignore

from src.config import *
from src.data import *
from src.models.efficientnet import EfficientNetB5Custom, EfficientNetB0, EfficientNetB5, EfficientNetB7
from src.models.resnet18 import ResNet18_v2
from src.utils import *
from src.data import OriginalOAIDataset, DatasetExperiment1
from src.train import train, train_model, test_model
from src.trainers.classification import Classification, ClassificationAdamax
import wandb
# Set random seeds
torch.manual_seed(RANDOM_SEED)
np.random.seed(RANDOM_SEED)
torch.cuda.manual_seed(RANDOM_SEED)

# %% [markdown]
# # Training

# %%
BATCH_SIZE = 20
LEARNING_RATE = 0.001
FACTOR = 0.1
L1 = 0
L2 = 0.001
PATIENCE = 8
BETAS=(0.9, 0.999)
LOCAL = False
# Regularización L1 y L2
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# wandb 254f72e7bdeec44797ba1b2a91ebbc63900b89f4
DATASET_PATH = '../../input/augmented-oai-bright/augmented_oai_bright'
train_dataset = DatasetExperiment1('train', batch_size=BATCH_SIZE, local=LOCAL,grey=False, path = DATASET_PATH)
val_dataset = DatasetExperiment1('val', batch_size=BATCH_SIZE, local=LOCAL, grey=False, path = DATASET_PATH)
#model =ResNet18_v2(n_classes = 5)
model = EfficientNetB7(num_classes = 5)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
trainer = ClassificationAdamax(model, device, L1=L1, L2=L2, lr=LEARNING_RATE, factor=FACTOR, patience=PATIENCE, betas=BETAS)
wandb.login(key="254f72e7bdeec44797ba1b2a91ebbc63900b89f4")
# Out:
# Downloading: "https://download.pytorch.org/models/efficientnet_b7_lukemelas-c5b4e57e.pth" to /root/.cache/torch/hub/checkpoints/efficientnet_b7_lukemelas-c5b4e57e.pth
# 100%|██████████| 255M/255M [00:01<00:00, 233MB/s]
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: chermar (chermar-universitat-polit-cnica-de-val-ncia). Use `wandb login --relogin` to force relogin
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %%
train_model(model, trainer, train_dataset, val_dataset, epochs=50, device=device, save_model = "experimento1.2", name="", wdb=not LOCAL, local=False, early_stopping_patience=12)
# Out:
# wandb: Tracking run with wandb version 0.19.1
# wandb: Run data is saved locally in /kaggle/working/Radiography_TFG/wandb/run-20250311_143925-jok4b8hi
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run EfficientNetB7_
# wandb: ⭐️ View project at https://wandb.ai/chermar-universitat-polit-cnica-de-val-ncia/oai-knee-cartilage-segmentation
# wandb: 🚀 View run at https://wandb.ai/chermar-universitat-polit-cnica-de-val-ncia/oai-knee-cartilage-segmentation/runs/jok4b8hi
# Training Epoch [1/50]:   0%|                                                                                                                                                   | 0/1388 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/torchmetrics/utilities/prints.py:43: UserWarning: No positive samples in targets, true positive value should be meaningless. Returning zero tensor in true positive score
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Training Epoch [1/50]: 100%|██████████████████████████████████████| 1388/1388 [22:57<00:00,  1.01it/s, AUC=0.83, acc=0.596, complete_loss=176.7213, sensivity=0.54, specificity=0.88, train_loss=0.9890]
# Validation Epoch [1/50]: 100%|████████████████████████████████████████████████████████████████████████████| 39/39 [00:18<00:00,  2.07it/s, AUC=0.819, acc=0.412, specificity=0.808, val_loss=1.30789897]
# Training Epoch [2/50]: 100%|████████████████████████████████████| 1388/1388 [19:51<00:00,  1.16it/s, AUC=0.864, acc=0.642, complete_loss=33.8293, sensivity=0.606, specificity=0.894, train_loss=0.8710]
# Validation Epoch [2/50]: 100%|█████████████████████████████████████████████████████████████████████████████| 39/39 [00:14<00:00,  2.78it/s, AUC=0.86, acc=0.533, specificity=0.849, val_loss=1.08651313]
# Training Epoch [3/50]: 100%|█████████████████████████████████████| 1388/1388 [19:55<00:00,  1.16it/s, AUC=0.875, acc=0.651, complete_loss=14.6536, sensivity=0.62, specificity=0.896, train_loss=0.8364]
# Validation Epoch [3/50]: 100%|████████████████████████████████████████████████████████████████████████████| 39/39 [00:14<00:00,  2.78it/s, AUC=0.872, acc=0.582, specificity=0.869, val_loss=0.98050011]
# Training Epoch [4/50]: 100%|█████████████████████████████████████| 1388/1388 [20:18<00:00,  1.14it/s, AUC=0.882, acc=0.661, complete_loss=8.8962, sensivity=0.634, specificity=0.899, train_loss=0.8142]
# Validation Epoch [4/50]: 100%|████████████████████████████████████████████████████████████████████████████| 39/39 [00:14<00:00,  2.73it/s, AUC=0.875, acc=0.629, specificity=0.885, val_loss=0.91819542]
# Training Epoch [5/50]: 100%|█████████████████████████████████████| 1388/1388 [20:12<00:00,  1.14it/s, AUC=0.887, acc=0.668, complete_loss=6.3156, sensivity=0.645, specificity=0.902, train_loss=0.7957]
# Validation Epoch [5/50]: 100%|████████████████████████████████████████████████████████████████████████████| 39/39 [00:14<00:00,  2.68it/s, AUC=0.891, acc=0.633, specificity=0.885, val_loss=0.86421784]
# Training Epoch [6/50]: 100%|█████████████████████████████████████| 1388/1388 [20:01<00:00,  1.15it/s, AUC=0.892, acc=0.675, complete_loss=4.9562, sensivity=0.651, specificity=0.904, train_loss=0.7818]
# Validation Epoch [6/50]: 100%|█████████████████████████████████████████████████████████████████████████████| 39/39 [00:14<00:00,  2.75it/s, AUC=0.883, acc=0.64, specificity=0.889, val_loss=0.86564588]
# Training Epoch [7/50]: 100%|██████████████████████████████████████| 1388/1388 [19:59<00:00,  1.16it/s, AUC=0.896, acc=0.68, complete_loss=4.0876, sensivity=0.659, specificity=0.906, train_loss=0.7678]
# Validation Epoch [7/50]: 100%|█████████████████████████████████████████████████████████████████████████████| 39/39 [00:13<00:00,  2.82it/s, AUC=0.885, acc=0.66, specificity=0.904, val_loss=0.82638505]
# Training Epoch [8/50]: 100%|██████████████████████████████████████| 1388/1388 [20:06<00:00,  1.15it/s, AUC=0.898, acc=0.688, complete_loss=3.5016, sensivity=0.67, specificity=0.908, train_loss=0.7529]
# Validation Epoch [8/50]: 100%|████████████████████████████████████████████████████████████████████████████| 39/39 [00:15<00:00,  2.59it/s, AUC=0.877, acc=0.621, specificity=0.894, val_loss=0.87577995]
# Training Epoch [9/50]: 100%|██████████████████████████████████████| 1388/1388 [20:21<00:00,  1.14it/s, AUC=0.901, acc=0.693, complete_loss=3.0976, sensivity=0.678, specificity=0.91, train_loss=0.7444]
# Validation Epoch [9/50]: 100%|█████████████████████████████████████████████████████████████████████████████| 39/39 [00:15<00:00,  2.49it/s, AUC=0.891, acc=0.647, specificity=0.89, val_loss=0.84290215]
# Training Epoch [10/50]: 100%|████████████████████████████████████| 1388/1388 [20:19<00:00,  1.14it/s, AUC=0.905, acc=0.698, complete_loss=2.8004, sensivity=0.684, specificity=0.912, train_loss=0.7341]
# Validation Epoch [10/50]: 100%|███████████████████████████████████████████████████████████████████████████| 39/39 [00:14<00:00,  2.66it/s, AUC=0.888, acc=0.671, specificity=0.904, val_loss=0.79666792]
# Training Epoch [11/50]: 100%|█████████████████████████████████████| 1388/1388 [20:06<00:00,  1.15it/s, AUC=0.908, acc=0.704, complete_loss=2.5695, sensivity=0.69, specificity=0.913, train_loss=0.7198]
# Validation Epoch [11/50]: 100%|███████████████████████████████████████████████████████████████████████████| 39/39 [00:13<00:00,  2.79it/s, AUC=0.895, acc=0.674, specificity=0.904, val_loss=0.80182671]
# Training Epoch [12/50]: 100%|█████████████████████████████████████| 1388/1388 [20:01<00:00,  1.16it/s, AUC=0.91, acc=0.708, complete_loss=2.3863, sensivity=0.692, specificity=0.915, train_loss=0.7121]
# Validation Epoch [12/50]: 100%|█████████████████████████████████████████████████████████████████████████████| 39/39 [00:14<00:00,  2.67it/s, AUC=0.897, acc=0.651, specificity=0.9, val_loss=0.81119652]
# Training Epoch [13/50]: 100%|████████████████████████████████████| 1388/1388 [20:04<00:00,  1.15it/s, AUC=0.912, acc=0.711, complete_loss=2.2361, sensivity=0.698, specificity=0.916, train_loss=0.7013]
# Validation Epoch [13/50]: 100%|█████████████████████████████████████████████████████████████████████████████| 39/39 [00:14<00:00,  2.67it/s, AUC=0.896, acc=0.665, specificity=0.9, val_loss=0.79028108]
# Training Epoch [14/50]: 100%|████████████████████████████████████| 1388/1388 [20:06<00:00,  1.15it/s, AUC=0.916, acc=0.716, complete_loss=2.1067, sensivity=0.706, specificity=0.917, train_loss=0.6851]
# Validation Epoch [14/50]: 100%|███████████████████████████████████████████████████████████████████████████| 39/39 [00:14<00:00,  2.77it/s, AUC=0.895, acc=0.656, specificity=0.902, val_loss=0.79777413]
# Training Epoch [15/50]: 100%|████████████████████████████████████| 1388/1388 [20:22<00:00,  1.14it/s, AUC=0.916, acc=0.718, complete_loss=2.0095, sensivity=0.708, specificity=0.918, train_loss=0.6854]
# Validation Epoch [15/50]: 100%|████████████████████████████████████████████████████████████████████████████| 39/39 [00:15<00:00,  2.58it/s, AUC=0.885, acc=0.64, specificity=0.892, val_loss=0.85551368]
# Training Epoch [16/50]: 100%|█████████████████████████████████████| 1388/1388 [20:16<00:00,  1.14it/s, AUC=0.918, acc=0.72, complete_loss=1.9218, sensivity=0.709, specificity=0.919, train_loss=0.6815]
# Validation Epoch [16/50]: 100%|███████████████████████████████████████████████████████████████████████████| 39/39 [00:14<00:00,  2.76it/s, AUC=0.886, acc=0.646, specificity=0.891, val_loss=0.92333789]
# Training Epoch [17/50]: 100%|████████████████████████████████████| 1388/1388 [20:11<00:00,  1.15it/s, AUC=0.921, acc=0.729, complete_loss=1.8381, sensivity=0.715, specificity=0.921, train_loss=0.6682]
# Validation Epoch [17/50]: 100%|███████████████████████████████████████████████████████████████████████████| 39/39 [00:14<00:00,  2.69it/s, AUC=0.881, acc=0.621, specificity=0.889, val_loss=0.87856130]
# Training Epoch [18/50]: 100%|████████████████████████████████████| 1388/1388 [20:04<00:00,  1.15it/s, AUC=0.921, acc=0.727, complete_loss=1.7768, sensivity=0.714, specificity=0.921, train_loss=0.6650]
# Validation Epoch [18/50]: 100%|████████████████████████████████████████████████████████████████████████████| 39/39 [00:14<00:00,  2.67it/s, AUC=0.89, acc=0.662, specificity=0.904, val_loss=0.81844590]
# Training Epoch [19/50]: 100%|████████████████████████████████████| 1388/1388 [20:06<00:00,  1.15it/s, AUC=0.926, acc=0.733, complete_loss=1.7098, sensivity=0.722, specificity=0.923, train_loss=0.6489]
# Validation Epoch [19/50]: 100%|███████████████████████████████████████████████████████████████████████████| 39/39 [00:14<00:00,  2.60it/s, AUC=0.874, acc=0.638, specificity=0.892, val_loss=0.87770718]
# Training Epoch [20/50]: 100%|█████████████████████████████████████| 1388/1388 [20:10<00:00,  1.15it/s, AUC=0.928, acc=0.74, complete_loss=1.6534, sensivity=0.729, specificity=0.925, train_loss=0.6369]
# Validation Epoch [20/50]: 100%|██████████████████████████████████████████████████████████████████████████████| 39/39 [00:14<00:00,  2.78it/s, AUC=0.88, acc=0.655, specificity=0.9, val_loss=0.86483327]
# Training Epoch [21/50]: 100%|████████████████████████████████████| 1388/1388 [20:03<00:00,  1.15it/s, AUC=0.929, acc=0.745, complete_loss=1.6119, sensivity=0.739, specificity=0.926, train_loss=0.6349]
# Validation Epoch [21/50]: 100%|███████████████████████████████████████████████████████████████████████████| 39/39 [00:14<00:00,  2.77it/s, AUC=0.887, acc=0.635, specificity=0.901, val_loss=0.87530375]
# Training Epoch [22/50]: 100%|████████████████████████████████████| 1388/1388 [20:02<00:00,  1.15it/s, AUC=0.929, acc=0.743, complete_loss=1.5721, sensivity=0.732, specificity=0.926, train_loss=0.6314]
# Validation Epoch [22/50]: 100%|███████████████████████████████████████████████████████████████████████████| 39/39 [00:13<00:00,  2.82it/s, AUC=0.885, acc=0.653, specificity=0.901, val_loss=0.85273126]
# Training Epoch [23/50]: 100%|████████████████████████████████████| 1388/1388 [20:01<00:00,  1.16it/s, AUC=0.954, acc=0.796, complete_loss=1.4421, sensivity=0.787, specificity=0.941, train_loss=0.5205]
# Validation Epoch [23/50]: 100%|███████████████████████████████████████████████████████████████████████████| 39/39 [00:14<00:00,  2.75it/s, AUC=0.891, acc=0.655, specificity=0.903, val_loss=0.84961342]
# Training Epoch [24/50]: 100%|██████████████████████████████████████| 1388/1388 [20:01<00:00,  1.16it/s, AUC=0.96, acc=0.814, complete_loss=1.3974, sensivity=0.81, specificity=0.947, train_loss=0.4771]
# Validation Epoch [24/50]: 100%|███████████████████████████████████████████████████████████████████████████| 39/39 [00:14<00:00,  2.61it/s, AUC=0.891, acc=0.655, specificity=0.903, val_loss=0.86066232]
# Training Epoch [25/50]: 100%|█████████████████████████████████████| 1388/1388 [20:07<00:00,  1.15it/s, AUC=0.963, acc=0.825, complete_loss=1.3751, sensivity=0.822, specificity=0.95, train_loss=0.4564]
# Validation Epoch [25/50]: 100%|███████████████████████████████████████████████████████████████████████████| 39/39 [00:14<00:00,  2.63it/s, AUC=0.889, acc=0.636, specificity=0.898, val_loss=0.89622871]
# Early stopping at epoch 25
# Test model EfficientNetB7 - Loss: 0.90, ACC: 0.64, AUC: 0.89, Sensivility: 0.61, Specificity: 0.68

# %%
test_model(model, val_dataset.get_dataloader(), trainer, device)
test_model(model, train_dataset.get_dataloader(), trainer, device)
# Out:
# /usr/local/lib/python3.10/dist-packages/torchmetrics/utilities/prints.py:43: UserWarning: No positive samples in targets, true positive value should be meaningless. Returning zero tensor in true positive score
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Test model EfficientNetB7 - Loss: 0.90, ACC: 0.64, AUC: 0.89, Sensivility: 0.61, Specificity: 0.68
# /usr/local/lib/python3.10/dist-packages/torchmetrics/utilities/prints.py:43: UserWarning: No positive samples in targets, true positive value should be meaningless. Returning zero tensor in true positive score
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Test model EfficientNetB7 - Loss: 0.35, ACC: 0.88, AUC: 0.98, Sensivility: 0.88, Specificity: 0.89
