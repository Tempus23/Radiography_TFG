# %% [markdown]
# # Imports and utility

# %%
#d8f53b61969adf7ee621c216f680b707
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns
import cv2
import keras_hub
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models
from tensorflow.keras.layers import (Input, Conv2D, MaxPooling2D, Flatten, Dense, Dropout,
                                     BatchNormalization, Activation, GlobalAveragePooling2D)
from tensorflow.keras.applications import VGG16, VGG19, ResNet50, ResNet152, EfficientNetB0, DenseNet121, InceptionV3
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, LearningRateScheduler, ModelCheckpoint
from tensorflow.keras import optimizers

train_dir = '/kaggle/input/knee-osteoarthritis-dataset-with-severity/train'
val_dir = '/kaggle/input/knee-osteoarthritis-dataset-with-severity/val'
test_dir = '/kaggle/input/knee-osteoarthritis-dataset-with-severity/test'
auto_test = '/kaggle/input/knee-osteoarthritis-dataset-with-severity/auto_test'
cat_dir = '/kaggle/input/cat-knee/clean'

IMG_SIZE = (224, 224)
BATCH_SIZE = 8
SEED = 66

# %%
import pandas as pd
import os

def create_dataframe_from_directory(base_dir, regression=False):
    data = []
    for label_str in sorted(os.listdir(base_dir)):
        label_path = os.path.join(base_dir, label_str)
        if not os.path.isdir(label_path):
            continue
        label = float(label_str) if regression else label_str
        for fname in os.listdir(label_path):
            data.append({
                'filename': os.path.join(label_str, fname),  # ruta relativa
                'label': label  # KL debe ser numérico para regresión
            })
    return pd.DataFrame(data)

# %%
from sklearn.metrics import mean_absolute_error, accuracy_score
import numpy as np
import tensorflow as tf

class CatValidationCallback(tf.keras.callbacks.Callback):
    def __init__(self, cat_generator, regresion=False, filepath='best_model_cat.keras'):
        super().__init__()
        self.cat_generator = cat_generator
        self.epoch_metrics = []
        self.regresion = regresion
        self.filepath = filepath
        # Inicializamos best_score y best_loss
        if regresion:
            self.best_score = 0.0    # queremos maximizar accuracy
            self.best_loss  = np.inf # y minimizar MAE
        else:
            self.best_score = 0.0    # queremos maximizar accuracy
            self.best_loss  = np.inf # y minimizar categorical loss

    def on_epoch_end(self, epoch, logs=None):
        # Predicciones
        preds = self.model.predict(self.cat_generator, verbose=0)

        if self.regresion:
            # Regresión: calculamos MAE + accuracy sobre clases redondeadas
            y_pred = preds.flatten()
            y_true = self.cat_generator.labels
            loss = mean_absolute_error(y_true, y_pred)
            y_pred_class = np.clip(np.round(y_pred), 0, 4).astype(int)
            y_true_class = np.clip(np.round(y_true), 0, 4).astype(int)
            acc = accuracy_score(y_true_class, y_pred_class)
            score = acc
        else:
            # Clasificación: evalúa el loss y la accuracy
            loss, acc = self.model.evaluate(self.cat_generator, verbose=0)
            preds_class = np.argmax(preds, axis=1)
            y_true = self.cat_generator.classes
            # para consistency, recalculamos acc con sklearn
            acc = accuracy_score(y_true, preds_class)
            score = acc

        # Guardar métricas
        self.epoch_metrics.append({
            'epoch': epoch + 1,
            'val_cat_loss': loss,
            'val_cat_accuracy': acc
        })

        # Mostrar por consola
        tag = "MAE" if self.regresion else "Loss"
        print(f"🐾 [Cat Val] {tag}: {loss:.4f} | Accuracy: {acc:.4f}")

        # Comprobamos mejora: primero por score, si empate por loss
        improved = False
        if score > self.best_score:
            improved = True
        elif score == self.best_score and loss < self.best_loss:
            improved = True

        # Si mejoró, guardamos modelo y actualizamos referencias
        if improved:
            self.best_score = score
            self.best_loss  = loss
            self.model.save(self.filepath)
            print(f"📦 Modelo mejorado guardado en {self.filepath}")

# %%
from tensorflow.keras.callbacks import ModelCheckpoint

def get_callbacks(regression=False, cat_gen=None):
  cat_val_cb = CatValidationCallback(cat_gen, regresion=regression)
  

  checkpoint_cb = ModelCheckpoint(
    filepath='best_model.keras',
    monitor='val_accuracy',         # nombre de la métrica a monitorizar
    mode='max',                     # porque buscamos la mayor precisión
    save_best_only=True,
    save_weights_only=False,
    verbose=1
  )
  checkpoint_cb_reg = ModelCheckpoint(
    filepath='best_model.keras',
    monitor='val_loss',
    mode='min',
    save_best_only=True,
    save_weights_only=False,
    verbose=1
  )
  if regression:
    callbacks = [
        EarlyStopping(patience=10, restore_best_weights=True),
        ReduceLROnPlateau(factor=0.5, patience=5, verbose=1),
        cat_val_cb,
        checkpoint_cb_reg
    ]
  else:
    callbacks = [
        EarlyStopping(patience=10, restore_best_weights=True),
        ReduceLROnPlateau(factor=0.5, patience=5, verbose=1),
        cat_val_cb,
        checkpoint_cb
    ]
  return callbacks

# %%
from sklearn.metrics import classification_report, confusion_matrix, mean_absolute_error
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

def _get_label_map(y_true, y_pred, generator=None, default_prefix='KL'):
    """
    Genera label_map automáticamente.
    - Si el generador tiene class_indices (clasificación Keras), los usa.
    - Si no, extrae las clases únicas de y_true y y_pred.
    - Si todo falla, crea labels 'KL 0', 'KL 1', ..., según número de clases.
    """
    # Caso Keras classification_generator
    if generator is not None and hasattr(generator, 'class_indices'):
        # Ordenar por índice
        sorted_items = sorted(generator.class_indices.items(), key=lambda x: x[1])
        return [name for name, _ in sorted_items]
    
    # Extraer clases únicas
    classes = np.unique(np.concatenate((y_true, y_pred)))
    # Si son enteros consecutivos desde 0 a n-1
    if np.array_equal(classes, np.arange(len(classes))):
        return [f'{default_prefix} {i}' for i in classes]
    # En caso de etiquetas no enteras o desordenadas
    return [str(c) for c in classes]

def evaluate_classification(y_true, y_pred, label_map=None, digits=4, title_suffix=''):
    """
    Reporte de clasificación + matriz de confusión.
    """
    if label_map is None:
        label_map = _get_label_map(y_true, y_pred)
    # Reporte
    print(classification_report(
        y_true, y_pred,
        target_names=label_map,
        digits=digits
    ))
    # Matriz de confusión
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(8,6))
    sns.heatmap(
        cm, annot=True, fmt='d', cmap='Blues',
        xticklabels=label_map, yticklabels=label_map
    )
    plt.xlabel('Predicción')
    plt.ylabel('Etiqueta verdadera')
    if title_suffix:
        plt.title(title_suffix)
    plt.show()

def evaluate_model(model, regression, generator, label_map=None, digits=4):
    """
    Elige el modo de evaluación y asegura que label_map siempre se resuelva.
    """
    # Predicciones crudas
    preds = model.predict(generator)
    
    if regression:
        # Convertir a clases
        if hasattr(generator, 'labels'):
            y_true_cont = np.array(generator.labels).flatten()
        else:
            y_true_cont = np.array(generator.classes).flatten()
        y_pred_cont = np.array(preds).flatten()
        
        # MAE
        mae = mean_absolute_error(y_true_cont, y_pred_cont)
        print(f"Mean Absolute Error (MAE): {mae:.{digits}f}\n")
        plt.figure(figsize=(6,6))
        # Dispersión
        plt.scatter(y_pred_cont, y_true_cont, alpha=0.5)
        # Línea de identidad
        mn = min(y_true_cont.min(), y_pred_cont.min())
        mx = max(y_true_cont.max(), y_pred_cont.max())
        plt.plot([mn, mx], [mn, mx], 'r--', linewidth=1)
        # Etiquetas
        plt.xlabel("Predicción (decimal)")
        plt.ylabel("Valor verdadero")
        plt.title("Scatter: Predicción vs Valor verdadero")
        plt.grid(True)
        plt.show()

        y_true_class = np.clip(np.round(y_true_cont).astype(int), 0, None)
        y_pred_class = np.clip(np.round(y_pred_cont).astype(int), 0, None)
        # Obtener label_map adaptado al rango observado
        if label_map is None:
            max_label = max(y_true_class.max(), y_pred_class.max())
            label_map = [f'KL {i}' for i in range(max_label + 1)]
        
        evaluate_classification(
            y_true=y_true_class,
            y_pred=y_pred_class,
            label_map=label_map,
            digits=digits,
        )
    else:
        # Clasificación softmax u otra salida multiclase
        y_pred = np.argmax(preds, axis=1)
        y_true = generator.classes
        
        if label_map is None:
            label_map = _get_label_map(y_true, y_pred, generator=generator)
        
        evaluate_classification(
            y_true=y_true,
            y_pred=y_pred,
            label_map=label_map,
            digits=digits
        )

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import pandas as pd

def get_datagen(
    tarea: int,
    path: str,
    regression: bool = False,
    IMG_SIZE: tuple = (224, 224),
    BATCH_SIZE: int = 32,
    SEED: int = 42,
    augment: bool = False
):
    """
    Generador de imágenes para clasificación y regresión con distintos esquemas de tarea.

    Parámetros:
        tarea       – entero 0–5 que define esquema de etiquetas.
        path        – ruta al directorio de imágenes (train/val/test u otro).
        regression  – True para regresión (class_mode='raw'), False para clasificación.
        IMG_SIZE    – tupla (alto, ancho).
        BATCH_SIZE  – tamaño de lote.
        SEED        – semilla aleatoria.
        augment     – True para data augmentation (solo en entrenamiento).
    """
    # Configurar DataGenerator
    if augment:
        datagen = ImageDataGenerator(
            rescale=1./255,
            rotation_range=10,
            width_shift_range=0.1,
            height_shift_range=0.1,
            zoom_range=0.1,
            horizontal_flip=True
        )
        shuffle = True
    else:
        datagen = ImageDataGenerator(rescale=1./255)
        shuffle = False

    # Cargar dataframe con tu función; label como float si regresión, str si clasificación
    df = create_dataframe_from_directory(path, regression=regression)
    # Clasificación: convertir labels a ints para procesar tareas
    df_proc = df.copy()
    df_proc['label'] = df_proc['label'].astype(int)

    if tarea == 0:
        # Multiclase original 0–4: no cambio
        pass
    elif tarea == 1:
        df_proc['label'] = df_proc['label'].apply(
            lambda x: 0 if x in [0,1,2] else 1 if x == 3 else 2 if x == 4 else x
        )
    elif tarea in [2,3,4,5]:
        target = tarea - 1  # tarea=2->1, etc.
        df_proc = df_proc[df_proc['label'].isin([0, target])]
        df_proc['label'] = df_proc['label'].apply(lambda x: 1 if x == target else 0)
    else:
        raise ValueError("tarea debe ser un entero entre 0 y 5.")

    if regression:
        # Asegurar float
        df_proc['label'] = df_proc['label'].astype(float)
        return datagen.flow_from_dataframe(
            dataframe=df_proc,
            directory=path,
            x_col='filename',
            y_col='label',
            target_size=IMG_SIZE,
            batch_size=BATCH_SIZE,
            class_mode='raw',
            shuffle=shuffle,
            seed=SEED
        )
    # Convertir a string para class_mode='categorical'
    df_proc['label'] = df_proc['label'].astype(str)
    
    # Generador de clasificación
    return datagen.flow_from_dataframe(
        dataframe=df_proc,
        directory=path,
        x_col='filename',
        y_col='label',
        target_size=IMG_SIZE,
        batch_size=BATCH_SIZE,
        class_mode='categorical',
        shuffle=shuffle,
        seed=SEED
    )

# %% [markdown]
# ## Experimentos a realizar
#
# Normal
# 012-3-4
# 0-1
# 0-2
# 0-3
# 0-4

# %%
def cnn_pequeno(num_classes = 5, regression=False):
    activation = 'linear' if regression else 'softmax'
    model = models.Sequential([
        layers.Conv2D(16, (3,3), activation='relu',
                      input_shape=(224,224,3)),
        layers.MaxPooling2D(2,2),
        layers.Flatten(),
        layers.Dense(num_classes, activation=activation)
    ])
    return model

# %%
def cnn_mediana(num_classes, regression=False):
    activation = 'linear' if regression else 'softmax'
    model = models.Sequential([
        # Primera capa convolucional
        Conv2D(32, (3, 3), activation='relu', padding='same', input_shape=(224,224,3)),
        MaxPooling2D((2, 2)),
        # Segunda capa convolucional
        Conv2D(64, (3, 3), activation='relu', padding='same'),
        MaxPooling2D((2, 2)),
        # Aplanamiento y capas densas
        Flatten(),
        Dense(128, activation='relu'),
        Dense(num_classes, activation=activation)
    ])
    return model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (
    Conv2D, BatchNormalization, MaxPooling2D, Dropout,
    Flatten, Dense
)

def cnn_grande(num_classes, regression = False):
    activation = 'linear' if regression else 'softmax'
    model = Sequential(name="CNN_Profunda")

    # Bloque 1
    model.add(Conv2D(32, (3, 3), activation='relu', padding='same',
                     input_shape=(224,224,3)))
    model.add(BatchNormalization())
    model.add(Conv2D(32, (3, 3), activation='relu', padding='same'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D((2, 2)))
    model.add(Dropout(0.25))

    # Bloque 2
    model.add(Conv2D(64, (3, 3), activation='relu', padding='same'))
    model.add(BatchNormalization())
    model.add(Conv2D(64, (3, 3), activation='relu', padding='same'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D((2, 2)))
    model.add(Dropout(0.25))

    # Bloque 3
    model.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
    model.add(BatchNormalization())
    model.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D((2, 2)))
    model.add(Dropout(0.40))

    # Clasificación final
    model.add(Flatten())
    model.add(Dense(256, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.50))
    model.add(Dense(num_classes, activation=activation))

    return model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (
    GlobalAveragePooling2D, BatchNormalization,
    Dropout, Dense
)
from tensorflow.keras.applications import EfficientNetB0, EfficientNetB7

def efficientnetB0_model(num_classes, regression=False):
    """
    Modelo basado en EfficientNetB0 con cabeza personalizada.
    - Input: 224×224×3
    - Preentrenado en ImageNet
    - Arquitectura secuencial
    """
    activation = 'linear' if regression else 'softmax'
    # Cargamos la base EfficientNetB0 sin la capa superior
    base = EfficientNetB0(
        include_top=False,
        weights='imagenet',
        input_shape=(224, 224, 3)
    )
    model = Sequential(name="EfficientNetB0_Custom")
    model.add(base)
    model.add(GlobalAveragePooling2D())
    model.add(BatchNormalization())
    model.add(Dropout(0.50))
    model.add(Dense(256, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.50))
    model.add(Dense(num_classes, activation=activation))
    return model

def efficientnetB7_model(num_classes, regression=False):
    """
    Modelo basado en EfficientNetB7 con cabeza personalizada.
    - Input: 600×600×3 (recomendado para B7)
    - Preentrenado en ImageNet
    - Arquitectura secuencial
    """
    activation = 'linear' if regression else 'softmax'
    base = EfficientNetB7(
        include_top=False,
        weights='imagenet',
        input_shape=(600, 600, 3)
    )
    model = Sequential(name="EfficientNetB7_Custom")
    model.add(base)
    model.add(GlobalAveragePooling2D())
    model.add(BatchNormalization())
    model.add(Dropout(0.50))
    model.add(Dense(256, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.50))
    model.add(Dense(num_classes, activation=activation))
    return model

# %%
def simple_transformer(num_classes=5, regression=False):
    activation = 'linear' if regression else 'softmax'

    inputs = layers.Input(shape=(224, 224, 3))
    x = layers.Conv2D(32, (3, 3), padding='same')(inputs)
    x = layers.Reshape((-1, 32))(x)
    x = layers.MultiHeadAttention(num_heads=1, key_dim=4)(x, x)
    x = layers.GlobalAveragePooling1D()(x)
    x = layers.Dense(128, activation='relu')(x)
    outputs = layers.Dense(num_classes, activation=activation)(x)

    model = models.Model(inputs, outputs)
    return model

# %%
regression = False
tarea = 0
batch_size = 32
num_classes = 5
if regression:
    num_classes = 1
elif tarea == 1:
    num_classes = 3
elif tarea > 1:
    num_classes = 2

loss = 'mean_squared_error' if regression else 'categorical_crossentropy'
metrics = ['mae'] if regression else ['accuracy']

# Generadores de datos (entrenamiento y validación)
train_gen = get_datagen(tarea=tarea, path=train_dir, regression=regression, BATCH_SIZE=batch_size, augment=True)
val_gen   = get_datagen(tarea=tarea, path=val_dir,  BATCH_SIZE=batch_size, regression=regression)
cat_gen = get_datagen(tarea=tarea, path=cat_dir, BATCH_SIZE=batch_size, regression=regression)


model = efficientnetB0_model(num_classes, regression)
model.compile(optimizer='adam',
                  loss=loss,
                  metrics=metrics)
callbacks=get_callbacks(regression, cat_gen)
history = model.fit(
    train_gen,
    validation_data=val_gen,
    epochs=50,
    callbacks=callbacks
)

model.load_weights('best_model.keras')
# Obtén el diccionario original {etiqueta_str: índice_entero}
evaluate_model(model, regression=regression, generator=val_gen)
model.load_weights('best_model_cat.keras')
evaluate_model(model, regression=regression, generator=cat_gen)
# Out:
# Found 5778 validated image filenames belonging to 5 classes.
# Found 826 validated image filenames belonging to 5 classes.
# Found 83 validated image filenames belonging to 5 classes.
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
# Epoch 1/50
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 664ms/step - accuracy: 0.2901 - loss: 2.2999🐾 [Cat Val] Loss: 2.2284 | Accuracy: 0.1325
# 📦 Modelo mejorado guardado en best_model_cat.keras
#
# Epoch 1: val_accuracy improved from -inf to 0.12833, saving model to best_model.keras
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 226s 848ms/step - accuracy: 0.2905 - loss: 2.2980 - val_accuracy: 0.1283 - val_loss: 2.5741 - learning_rate: 0.0010
# Epoch 2/50
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 362ms/step - accuracy: 0.4920 - loss: 1.3346🐾 [Cat Val] Loss: 1.6511 | Accuracy: 0.2530
# 📦 Modelo mejorado guardado en best_model_cat.keras
#
# Epoch 2: val_accuracy improved from 0.12833 to 0.41162, saving model to best_model.keras
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 73s 390ms/step - accuracy: 0.4921 - loss: 1.3343 - val_accuracy: 0.4116 - val_loss: 1.4337 - learning_rate: 0.0010
# Epoch 3/50
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 356ms/step - accuracy: 0.5447 - loss: 1.1440🐾 [Cat Val] Loss: 1.6366 | Accuracy: 0.2169
#
# Epoch 3: val_accuracy improved from 0.41162 to 0.41283, saving model to best_model.keras
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 71s 380ms/step - accuracy: 0.5448 - loss: 1.1437 - val_accuracy: 0.4128 - val_loss: 1.4811 - learning_rate: 0.0010
# Epoch 4/50
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 359ms/step - accuracy: 0.5902 - loss: 1.0163🐾 [Cat Val] Loss: 2.0139 | Accuracy: 0.1928
#
# Epoch 4: val_accuracy improved from 0.41283 to 0.49637, saving model to best_model.keras
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 72s 383ms/step - accuracy: 0.5902 - loss: 1.0162 - val_accuracy: 0.4964 - val_loss: 1.1688 - learning_rate: 0.0010
# Epoch 5/50
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 358ms/step - accuracy: 0.6133 - loss: 0.9555🐾 [Cat Val] Loss: 2.0460 | Accuracy: 0.1928
#
# Epoch 5: val_accuracy improved from 0.49637 to 0.54722, saving model to best_model.keras
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 72s 384ms/step - accuracy: 0.6133 - loss: 0.9554 - val_accuracy: 0.5472 - val_loss: 1.4749 - learning_rate: 0.0010
# Epoch 6/50
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 361ms/step - accuracy: 0.6397 - loss: 0.8787🐾 [Cat Val] Loss: 1.8587 | Accuracy: 0.2410
#
# Epoch 6: val_accuracy improved from 0.54722 to 0.63559, saving model to best_model.keras
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 72s 385ms/step - accuracy: 0.6397 - loss: 0.8788 - val_accuracy: 0.6356 - val_loss: 0.8650 - learning_rate: 0.0010
# Epoch 7/50
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 357ms/step - accuracy: 0.6330 - loss: 0.8967🐾 [Cat Val] Loss: 2.2609 | Accuracy: 0.2289
#
# Epoch 7: val_accuracy did not improve from 0.63559
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 71s 376ms/step - accuracy: 0.6330 - loss: 0.8966 - val_accuracy: 0.6223 - val_loss: 0.8548 - learning_rate: 0.0010
# Epoch 8/50
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 357ms/step - accuracy: 0.6456 - loss: 0.8524🐾 [Cat Val] Loss: 1.8837 | Accuracy: 0.2048
#
# Epoch 8: val_accuracy improved from 0.63559 to 0.64649, saving model to best_model.keras
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 72s 381ms/step - accuracy: 0.6456 - loss: 0.8523 - val_accuracy: 0.6465 - val_loss: 0.8527 - learning_rate: 0.0010
# Epoch 9/50
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 358ms/step - accuracy: 0.6702 - loss: 0.7993🐾 [Cat Val] Loss: 1.9367 | Accuracy: 0.1446
#
# Epoch 9: val_accuracy did not improve from 0.64649
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 71s 377ms/step - accuracy: 0.6702 - loss: 0.7994 - val_accuracy: 0.6308 - val_loss: 0.9542 - learning_rate: 0.0010
# Epoch 10/50
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 355ms/step - accuracy: 0.6649 - loss: 0.7919🐾 [Cat Val] Loss: 2.1186 | Accuracy: 0.1928
#
# Epoch 10: val_accuracy improved from 0.64649 to 0.65133, saving model to best_model.keras
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 71s 380ms/step - accuracy: 0.6649 - loss: 0.7920 - val_accuracy: 0.6513 - val_loss: 0.8392 - learning_rate: 0.0010
# Epoch 11/50
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 356ms/step - accuracy: 0.6897 - loss: 0.7455🐾 [Cat Val] Loss: 2.1246 | Accuracy: 0.2410
#
# Epoch 11: val_accuracy did not improve from 0.65133
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 71s 375ms/step - accuracy: 0.6897 - loss: 0.7456 - val_accuracy: 0.5872 - val_loss: 0.9795 - learning_rate: 0.0010
# Epoch 12/50
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 355ms/step - accuracy: 0.6781 - loss: 0.7654🐾 [Cat Val] Loss: 2.4099 | Accuracy: 0.2048
#
# Epoch 12: val_accuracy did not improve from 0.65133
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 70s 373ms/step - accuracy: 0.6781 - loss: 0.7654 - val_accuracy: 0.6077 - val_loss: 1.0803 - learning_rate: 0.0010
# Epoch 13/50
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step - accuracy: 0.6824 - loss: 0.7602🐾 [Cat Val] Loss: 2.0821 | Accuracy: 0.2048
#
# Epoch 13: val_accuracy did not improve from 0.65133
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 70s 371ms/step - accuracy: 0.6824 - loss: 0.7603 - val_accuracy: 0.5799 - val_loss: 1.1462 - learning_rate: 0.0010
# Epoch 14/50
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step - accuracy: 0.6670 - loss: 0.7880🐾 [Cat Val] Loss: 1.9324 | Accuracy: 0.2169
#
# Epoch 14: val_accuracy did not improve from 0.65133
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 70s 372ms/step - accuracy: 0.6671 - loss: 0.7877 - val_accuracy: 0.6162 - val_loss: 0.8676 - learning_rate: 0.0010
# Epoch 15/50
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 355ms/step - accuracy: 0.6877 - loss: 0.7437
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 🐾 [Cat Val] Loss: 1.9459 | Accuracy: 0.2169
#
# Epoch 15: val_accuracy did not improve from 0.65133
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 70s 373ms/step - accuracy: 0.6877 - loss: 0.7436 - val_accuracy: 0.6356 - val_loss: 0.9139 - learning_rate: 0.0010
# Epoch 16/50
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 359ms/step - accuracy: 0.7170 - loss: 0.6778🐾 [Cat Val] Loss: 2.1263 | Accuracy: 0.1566
#
# Epoch 16: val_accuracy did not improve from 0.65133
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 71s 377ms/step - accuracy: 0.7170 - loss: 0.6777 - val_accuracy: 0.6162 - val_loss: 0.8973 - learning_rate: 5.0000e-04
# Epoch 17/50
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step - accuracy: 0.7301 - loss: 0.6381🐾 [Cat Val] Loss: 2.3336 | Accuracy: 0.1446
#
# Epoch 17: val_accuracy did not improve from 0.65133
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 70s 371ms/step - accuracy: 0.7301 - loss: 0.6380 - val_accuracy: 0.6320 - val_loss: 0.9397 - learning_rate: 5.0000e-04
# Epoch 18/50
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 351ms/step - accuracy: 0.7332 - loss: 0.6237🐾 [Cat Val] Loss: 2.1523 | Accuracy: 0.2410
#
# Epoch 18: val_accuracy improved from 0.65133 to 0.65617, saving model to best_model.keras
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 70s 374ms/step - accuracy: 0.7332 - loss: 0.6238 - val_accuracy: 0.6562 - val_loss: 0.8299 - learning_rate: 5.0000e-04
# Epoch 19/50
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 347ms/step - accuracy: 0.7433 - loss: 0.6168🐾 [Cat Val] Loss: 2.4300 | Accuracy: 0.1928
#
# Epoch 19: val_accuracy did not improve from 0.65617
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 69s 365ms/step - accuracy: 0.7433 - loss: 0.6168 - val_accuracy: 0.6562 - val_loss: 0.9037 - learning_rate: 5.0000e-04
# Epoch 20/50
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 347ms/step - accuracy: 0.7563 - loss: 0.5928🐾 [Cat Val] Loss: 2.7737 | Accuracy: 0.2048
#
# Epoch 20: val_accuracy improved from 0.65617 to 0.68644, saving model to best_model.keras
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 70s 370ms/step - accuracy: 0.7563 - loss: 0.5928 - val_accuracy: 0.6864 - val_loss: 1.0107 - learning_rate: 5.0000e-04
# Epoch 21/50
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 347ms/step - accuracy: 0.7722 - loss: 0.5450🐾 [Cat Val] Loss: 2.0677 | Accuracy: 0.1566
#
# Epoch 21: val_accuracy did not improve from 0.68644
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 69s 366ms/step - accuracy: 0.7721 - loss: 0.5451 - val_accuracy: 0.6320 - val_loss: 0.9724 - learning_rate: 5.0000e-04
# Epoch 22/50
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 350ms/step - accuracy: 0.7549 - loss: 0.5828🐾 [Cat Val] Loss: 2.7435 | Accuracy: 0.2410
#
# Epoch 22: val_accuracy did not improve from 0.68644
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 69s 368ms/step - accuracy: 0.7549 - loss: 0.5827 - val_accuracy: 0.6477 - val_loss: 0.9937 - learning_rate: 5.0000e-04
# Epoch 23/50
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step - accuracy: 0.7757 - loss: 0.5449
# Epoch 23: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 🐾 [Cat Val] Loss: 2.1967 | Accuracy: 0.2289
#
# Epoch 23: val_accuracy did not improve from 0.68644
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 70s 371ms/step - accuracy: 0.7756 - loss: 0.5450 - val_accuracy: 0.5969 - val_loss: 0.9992 - learning_rate: 5.0000e-04
# Epoch 24/50
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 351ms/step - accuracy: 0.8098 - loss: 0.4777🐾 [Cat Val] Loss: 2.0867 | Accuracy: 0.2530
#
# Epoch 24: val_accuracy did not improve from 0.68644
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 69s 369ms/step - accuracy: 0.8098 - loss: 0.4777 - val_accuracy: 0.6695 - val_loss: 0.9276 - learning_rate: 2.5000e-04
# Epoch 25/50
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step - accuracy: 0.8082 - loss: 0.4684🐾 [Cat Val] Loss: 2.3283 | Accuracy: 0.2410
#
# Epoch 25: val_accuracy did not improve from 0.68644
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 70s 372ms/step - accuracy: 0.8082 - loss: 0.4683 - val_accuracy: 0.6429 - val_loss: 1.1741 - learning_rate: 2.5000e-04
# Epoch 26/50
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - accuracy: 0.8295 - loss: 0.4211🐾 [Cat Val] Loss: 2.5189 | Accuracy: 0.2169
#
# Epoch 26: val_accuracy did not improve from 0.68644
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 69s 367ms/step - accuracy: 0.8295 - loss: 0.4211 - val_accuracy: 0.6138 - val_loss: 1.1774 - learning_rate: 2.5000e-04
# Epoch 27/50
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 350ms/step - accuracy: 0.8357 - loss: 0.4018🐾 [Cat Val] Loss: 2.1931 | Accuracy: 0.2169
#
# Epoch 27: val_accuracy did not improve from 0.68644
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 69s 368ms/step - accuracy: 0.8357 - loss: 0.4018 - val_accuracy: 0.6126 - val_loss: 1.1424 - learning_rate: 2.5000e-04
# Epoch 28/50
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 355ms/step - accuracy: 0.8482 - loss: 0.3791
# Epoch 28: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 🐾 [Cat Val] Loss: 2.6676 | Accuracy: 0.1928
#
# Epoch 28: val_accuracy did not improve from 0.68644
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 70s 374ms/step - accuracy: 0.8481 - loss: 0.3791 - val_accuracy: 0.6465 - val_loss: 1.0978 - learning_rate: 2.5000e-04
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 5s 208ms/step
#               precision    recall  f1-score   support
#
#            0     0.6561    0.9421    0.7735       328
#            1     0.4167    0.1307    0.1990       153
#            2     0.7401    0.6179    0.6735       212
#            3     0.7870    0.8019    0.7944       106
#            4     1.0000    0.8148    0.8980        27
#
#     accuracy                         0.6864       826
#    macro avg     0.7200    0.6615    0.6677       826
# weighted avg     0.6613    0.6864    0.6482       826
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
#               precision    recall  f1-score   support
#
#            0     0.2625    0.9545    0.4118        22
#            1     0.0000    0.0000    0.0000        30
#            2     0.0000    0.0000    0.0000        18
#            3     0.0000    0.0000    0.0000        11
#            4     0.0000    0.0000    0.0000         2
#
#     accuracy                         0.2530        83
#    macro avg     0.0525    0.1909    0.0824        83
# weighted avg     0.0696    0.2530    0.1091        83
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
regression = True
tarea = 0
batch_size = 32
num_classes = 5
if regression:
    num_classes = 1
elif tarea == 1:
    num_classes = 3
elif tarea > 1:
    num_classes = 2

loss = 'mean_squared_error' if regression else 'categorical_crossentropy'
metrics = ['mae'] if regression else ['accuracy']

# Generadores de datos (entrenamiento y validación)
train_gen = get_datagen(tarea=tarea, path=train_dir, regression=regression, BATCH_SIZE=batch_size, augment=True)
val_gen   = get_datagen(tarea=tarea, path=val_dir,  BATCH_SIZE=batch_size, regression=regression)
cat_gen = get_datagen(tarea=tarea, path=cat_dir, BATCH_SIZE=batch_size, regression=regression)


model = efficientnetB0_model(num_classes, regression)
model.compile(optimizer='adam',
                  loss=loss,
                  metrics=metrics)
callbacks=get_callbacks(regression, cat_gen)
history = model.fit(
    train_gen,
    validation_data=val_gen,
    epochs=50,
    callbacks=callbacks
)

model.load_weights('best_model.keras')
# Obtén el diccionario original {etiqueta_str: índice_entero}
evaluate_model(model, regression=regression, generator=val_gen)
model.load_weights('best_model_cat.keras')
evaluate_model(model, regression=regression, generator=cat_gen)
# Out:
# Found 5778 validated image filenames.
# Found 826 validated image filenames.
# Found 83 validated image filenames.
# Epoch 1/50
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 526ms/step - loss: 4.7718 - mae: 1.7064🐾 [Cat Val] MAE: 0.8891 | Accuracy: 0.3614
# 📦 Modelo mejorado guardado en best_model_cat.keras
#
# Epoch 1: val_loss improved from inf to 1.41534, saving model to best_model.keras
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 181s 652ms/step - loss: 4.7653 - mae: 1.7051 - val_loss: 1.4153 - val_mae: 1.0446 - learning_rate: 0.0010
# Epoch 2/50
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - loss: 1.7486 - mae: 1.0386🐾 [Cat Val] MAE: 0.8498 | Accuracy: 0.3614
# 📦 Modelo mejorado guardado en best_model_cat.keras
#
# Epoch 2: val_loss did not improve from 1.41534
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 69s 369ms/step - loss: 1.7476 - mae: 1.0383 - val_loss: 1.5084 - val_mae: 1.0257 - learning_rate: 0.0010
# Epoch 3/50
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 346ms/step - loss: 1.1306 - mae: 0.8377🐾 [Cat Val] MAE: 0.9340 | Accuracy: 0.3253
#
# Epoch 3: val_loss did not improve from 1.41534
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 68s 361ms/step - loss: 1.1300 - mae: 0.8375 - val_loss: 1.6143 - val_mae: 1.0611 - learning_rate: 0.0010
# Epoch 4/50
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - loss: 0.8566 - mae: 0.7298🐾 [Cat Val] MAE: 0.9833 | Accuracy: 0.2771
#
# Epoch 4: val_loss did not improve from 1.41534
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 69s 365ms/step - loss: 0.8566 - mae: 0.7297 - val_loss: 1.4274 - val_mae: 0.9815 - learning_rate: 0.0010
# Epoch 5/50
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 346ms/step - loss: 0.6985 - mae: 0.6656🐾 [Cat Val] MAE: 0.9460 | Accuracy: 0.3133
#
# Epoch 5: val_loss improved from 1.41534 to 0.69050, saving model to best_model.keras
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 69s 367ms/step - loss: 0.6985 - mae: 0.6655 - val_loss: 0.6905 - val_mae: 0.6475 - learning_rate: 0.0010
# Epoch 6/50
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - loss: 0.6219 - mae: 0.6168🐾 [Cat Val] MAE: 0.9768 | Accuracy: 0.2892
#
# Epoch 6: val_loss improved from 0.69050 to 0.58353, saving model to best_model.keras
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 70s 371ms/step - loss: 0.6218 - mae: 0.6167 - val_loss: 0.5835 - val_mae: 0.5925 - learning_rate: 0.0010
# Epoch 7/50
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - loss: 0.5690 - mae: 0.5935🐾 [Cat Val] MAE: 0.9659 | Accuracy: 0.3253
#
# Epoch 7: val_loss improved from 0.58353 to 0.49020, saving model to best_model.keras
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 69s 369ms/step - loss: 0.5690 - mae: 0.5935 - val_loss: 0.4902 - val_mae: 0.5496 - learning_rate: 0.0010
# Epoch 8/50
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 347ms/step - loss: 0.5244 - mae: 0.5713🐾 [Cat Val] MAE: 0.9929 | Accuracy: 0.3133
#
# Epoch 8: val_loss did not improve from 0.49020
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 68s 362ms/step - loss: 0.5245 - mae: 0.5714 - val_loss: 0.6262 - val_mae: 0.6060 - learning_rate: 0.0010
# Epoch 9/50
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - loss: 0.5150 - mae: 0.5655🐾 [Cat Val] MAE: 1.0057 | Accuracy: 0.2771
#
# Epoch 9: val_loss did not improve from 0.49020
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 69s 364ms/step - loss: 0.5149 - mae: 0.5654 - val_loss: 0.6209 - val_mae: 0.5866 - learning_rate: 0.0010
# Epoch 10/50
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 350ms/step - loss: 0.4953 - mae: 0.5561🐾 [Cat Val] MAE: 1.0726 | Accuracy: 0.2289
#
# Epoch 10: val_loss improved from 0.49020 to 0.48785, saving model to best_model.keras
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 69s 369ms/step - loss: 0.4953 - mae: 0.5561 - val_loss: 0.4878 - val_mae: 0.5411 - learning_rate: 0.0010
# Epoch 11/50
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 350ms/step - loss: 0.4461 - mae: 0.5214🐾 [Cat Val] MAE: 0.9708 | Accuracy: 0.3373
#
# Epoch 11: val_loss improved from 0.48785 to 0.47137, saving model to best_model.keras
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 70s 372ms/step - loss: 0.4462 - mae: 0.5214 - val_loss: 0.4714 - val_mae: 0.5222 - learning_rate: 0.0010
# Epoch 12/50
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step - loss: 0.4541 - mae: 0.5345🐾 [Cat Val] MAE: 0.9723 | Accuracy: 0.3133
#
# Epoch 12: val_loss did not improve from 0.47137
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 69s 369ms/step - loss: 0.4542 - mae: 0.5346 - val_loss: 0.5252 - val_mae: 0.5562 - learning_rate: 0.0010
# Epoch 13/50
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 350ms/step - loss: 0.4600 - mae: 0.5261🐾 [Cat Val] MAE: 0.9897 | Accuracy: 0.3133
#
# Epoch 13: val_loss did not improve from 0.47137
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 69s 366ms/step - loss: 0.4601 - mae: 0.5262 - val_loss: 0.4770 - val_mae: 0.5166 - learning_rate: 0.0010
# Epoch 14/50
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 347ms/step - loss: 0.4238 - mae: 0.5110🐾 [Cat Val] MAE: 1.1270 | Accuracy: 0.2169
#
# Epoch 14: val_loss did not improve from 0.47137
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 68s 363ms/step - loss: 0.4238 - mae: 0.5110 - val_loss: 0.6333 - val_mae: 0.5818 - learning_rate: 0.0010
# Epoch 15/50
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 350ms/step - loss: 0.4082 - mae: 0.4980🐾 [Cat Val] MAE: 1.1153 | Accuracy: 0.1928
#
# Epoch 15: val_loss did not improve from 0.47137
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 69s 364ms/step - loss: 0.4083 - mae: 0.4980 - val_loss: 0.8525 - val_mae: 0.7169 - learning_rate: 0.0010
# Epoch 16/50
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - loss: 0.4045 - mae: 0.4920🐾 [Cat Val] MAE: 1.0037 | Accuracy: 0.2892
#
# Epoch 16: val_loss improved from 0.47137 to 0.46837, saving model to best_model.keras
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 69s 369ms/step - loss: 0.4045 - mae: 0.4920 - val_loss: 0.4684 - val_mae: 0.5331 - learning_rate: 0.0010
# Epoch 17/50
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 347ms/step - loss: 0.4142 - mae: 0.5082🐾 [Cat Val] MAE: 1.0239 | Accuracy: 0.3012
#
# Epoch 17: val_loss did not improve from 0.46837
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 68s 362ms/step - loss: 0.4142 - mae: 0.5082 - val_loss: 0.4813 - val_mae: 0.5353 - learning_rate: 0.0010
# Epoch 18/50
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 351ms/step - loss: 0.3887 - mae: 0.4859🐾 [Cat Val] MAE: 0.9711 | Accuracy: 0.3012
#
# Epoch 18: val_loss did not improve from 0.46837
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 69s 367ms/step - loss: 0.3887 - mae: 0.4859 - val_loss: 0.4736 - val_mae: 0.5267 - learning_rate: 0.0010
# Epoch 19/50
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 355ms/step - loss: 0.3924 - mae: 0.4908🐾 [Cat Val] MAE: 1.2322 | Accuracy: 0.1566
#
# Epoch 19: val_loss did not improve from 0.46837
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 70s 372ms/step - loss: 0.3924 - mae: 0.4907 - val_loss: 0.5479 - val_mae: 0.5486 - learning_rate: 0.0010
# Epoch 20/50
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 361ms/step - loss: 0.4158 - mae: 0.5019🐾 [Cat Val] MAE: 1.0802 | Accuracy: 0.2530
#
# Epoch 20: val_loss did not improve from 0.46837
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 71s 377ms/step - loss: 0.4157 - mae: 0.5019 - val_loss: 0.7469 - val_mae: 0.6068 - learning_rate: 0.0010
# Epoch 21/50
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - loss: 0.3670 - mae: 0.4684🐾 [Cat Val] MAE: 1.0010 | Accuracy: 0.2892
#
# Epoch 21: val_loss improved from 0.46837 to 0.46564, saving model to best_model.keras
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 71s 378ms/step - loss: 0.3670 - mae: 0.4684 - val_loss: 0.4656 - val_mae: 0.5194 - learning_rate: 0.0010
# Epoch 22/50
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - loss: 0.3622 - mae: 0.4692🐾 [Cat Val] MAE: 0.9932 | Accuracy: 0.2651
#
# Epoch 22: val_loss improved from 0.46564 to 0.46288, saving model to best_model.keras
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 70s 372ms/step - loss: 0.3622 - mae: 0.4692 - val_loss: 0.4629 - val_mae: 0.5146 - learning_rate: 0.0010
# Epoch 23/50
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 351ms/step - loss: 0.3441 - mae: 0.4533🐾 [Cat Val] MAE: 1.0382 | Accuracy: 0.2530
#
# Epoch 23: val_loss did not improve from 0.46288
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 69s 366ms/step - loss: 0.3443 - mae: 0.4534 - val_loss: 0.5260 - val_mae: 0.5595 - learning_rate: 0.0010
# Epoch 24/50
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 351ms/step - loss: 0.3680 - mae: 0.4749🐾 [Cat Val] MAE: 1.0523 | Accuracy: 0.2771
#
# Epoch 24: val_loss did not improve from 0.46288
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 69s 367ms/step - loss: 0.3680 - mae: 0.4748 - val_loss: 0.5493 - val_mae: 0.5718 - learning_rate: 0.0010
# Epoch 25/50
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - loss: 0.3594 - mae: 0.4627🐾 [Cat Val] MAE: 0.8973 | Accuracy: 0.3253
#
# Epoch 25: val_loss improved from 0.46288 to 0.45069, saving model to best_model.keras
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 70s 373ms/step - loss: 0.3595 - mae: 0.4628 - val_loss: 0.4507 - val_mae: 0.5354 - learning_rate: 0.0010
# Epoch 26/50
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 348ms/step - loss: 0.3514 - mae: 0.4613🐾 [Cat Val] MAE: 1.0024 | Accuracy: 0.2771
#
# Epoch 26: val_loss did not improve from 0.45069
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 68s 362ms/step - loss: 0.3514 - mae: 0.4613 - val_loss: 0.5392 - val_mae: 0.5358 - learning_rate: 0.0010
# Epoch 27/50
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - loss: 0.3291 - mae: 0.4418🐾 [Cat Val] MAE: 0.9510 | Accuracy: 0.2771
#
# Epoch 27: val_loss did not improve from 0.45069
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 69s 365ms/step - loss: 0.3293 - mae: 0.4419 - val_loss: 0.5081 - val_mae: 0.5071 - learning_rate: 0.0010
# Epoch 28/50
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 346ms/step - loss: 0.3452 - mae: 0.4522🐾 [Cat Val] MAE: 1.2264 | Accuracy: 0.2892
#
# Epoch 28: val_loss did not improve from 0.45069
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 68s 361ms/step - loss: 0.3452 - mae: 0.4522 - val_loss: 0.6101 - val_mae: 0.5458 - learning_rate: 0.0010
# Epoch 29/50
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 346ms/step - loss: 0.3521 - mae: 0.4584🐾 [Cat Val] MAE: 1.0432 | Accuracy: 0.2651
#
# Epoch 29: val_loss did not improve from 0.45069
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 68s 361ms/step - loss: 0.3520 - mae: 0.4584 - val_loss: 0.6083 - val_mae: 0.6056 - learning_rate: 0.0010
# Epoch 30/50
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - loss: 0.3249 - mae: 0.4382
# Epoch 30: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 🐾 [Cat Val] MAE: 0.9958 | Accuracy: 0.2651
#
# Epoch 30: val_loss did not improve from 0.45069
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 69s 364ms/step - loss: 0.3250 - mae: 0.4383 - val_loss: 0.4545 - val_mae: 0.4867 - learning_rate: 0.0010
# Epoch 31/50
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 348ms/step - loss: 0.2897 - mae: 0.4201🐾 [Cat Val] MAE: 1.0606 | Accuracy: 0.2289
#
# Epoch 31: val_loss improved from 0.45069 to 0.44164, saving model to best_model.keras
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 70s 370ms/step - loss: 0.2897 - mae: 0.4201 - val_loss: 0.4416 - val_mae: 0.4637 - learning_rate: 5.0000e-04
# Epoch 32/50
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 347ms/step - loss: 0.2568 - mae: 0.3875🐾 [Cat Val] MAE: 0.9598 | Accuracy: 0.2651
#
# Epoch 32: val_loss improved from 0.44164 to 0.41614, saving model to best_model.keras
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 69s 367ms/step - loss: 0.2568 - mae: 0.3875 - val_loss: 0.4161 - val_mae: 0.4627 - learning_rate: 5.0000e-04
# Epoch 33/50
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 348ms/step - loss: 0.2469 - mae: 0.3723🐾 [Cat Val] MAE: 0.9794 | Accuracy: 0.2771
#
# Epoch 33: val_loss did not improve from 0.41614
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 68s 363ms/step - loss: 0.2469 - mae: 0.3723 - val_loss: 0.4249 - val_mae: 0.4892 - learning_rate: 5.0000e-04
# Epoch 34/50
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - loss: 0.2503 - mae: 0.3778🐾 [Cat Val] MAE: 1.0646 | Accuracy: 0.2410
#
# Epoch 34: val_loss did not improve from 0.41614
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 68s 363ms/step - loss: 0.2503 - mae: 0.3778 - val_loss: 0.5204 - val_mae: 0.5159 - learning_rate: 5.0000e-04
# Epoch 35/50
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - loss: 0.2195 - mae: 0.3525🐾 [Cat Val] MAE: 1.0147 | Accuracy: 0.2651
#
# Epoch 35: val_loss did not improve from 0.41614
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 69s 366ms/step - loss: 0.2195 - mae: 0.3526 - val_loss: 0.4923 - val_mae: 0.5038 - learning_rate: 5.0000e-04
# Epoch 36/50
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 346ms/step - loss: 0.2356 - mae: 0.3652🐾 [Cat Val] MAE: 0.9849 | Accuracy: 0.3133
#
# Epoch 36: val_loss did not improve from 0.41614
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 68s 361ms/step - loss: 0.2356 - mae: 0.3652 - val_loss: 0.5466 - val_mae: 0.5286 - learning_rate: 5.0000e-04
# Epoch 37/50
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 351ms/step - loss: 0.2251 - mae: 0.3621
# Epoch 37: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 🐾 [Cat Val] MAE: 0.9647 | Accuracy: 0.2771
#
# Epoch 37: val_loss did not improve from 0.41614
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 69s 366ms/step - loss: 0.2252 - mae: 0.3621 - val_loss: 0.4940 - val_mae: 0.5043 - learning_rate: 5.0000e-04
# Epoch 38/50
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 350ms/step - loss: 0.2061 - mae: 0.3421🐾 [Cat Val] MAE: 0.9164 | Accuracy: 0.2771
#
# Epoch 38: val_loss did not improve from 0.41614
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 69s 365ms/step - loss: 0.2061 - mae: 0.3422 - val_loss: 0.4633 - val_mae: 0.4773 - learning_rate: 2.5000e-04
# Epoch 39/50
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 351ms/step - loss: 0.1936 - mae: 0.3305🐾 [Cat Val] MAE: 0.9154 | Accuracy: 0.3494
#
# Epoch 39: val_loss did not improve from 0.41614
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 69s 366ms/step - loss: 0.1936 - mae: 0.3305 - val_loss: 0.4719 - val_mae: 0.4853 - learning_rate: 2.5000e-04
# Epoch 40/50
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - loss: 0.1664 - mae: 0.3092🐾 [Cat Val] MAE: 0.9792 | Accuracy: 0.2892
#
# Epoch 40: val_loss did not improve from 0.41614
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 69s 364ms/step - loss: 0.1664 - mae: 0.3092 - val_loss: 0.4492 - val_mae: 0.4724 - learning_rate: 2.5000e-04
# Epoch 41/50
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - loss: 0.1794 - mae: 0.3219🐾 [Cat Val] MAE: 0.9052 | Accuracy: 0.3373
#
# Epoch 41: val_loss did not improve from 0.41614
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 69s 364ms/step - loss: 0.1794 - mae: 0.3219 - val_loss: 0.4759 - val_mae: 0.4897 - learning_rate: 2.5000e-04
# Epoch 42/50
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 348ms/step - loss: 0.1840 - mae: 0.3257
# Epoch 42: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 🐾 [Cat Val] MAE: 0.9141 | Accuracy: 0.3373
#
# Epoch 42: val_loss did not improve from 0.41614
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 69s 365ms/step - loss: 0.1840 - mae: 0.3257 - val_loss: 0.4698 - val_mae: 0.4706 - learning_rate: 2.5000e-04
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 5s 208ms/step
# Mean Absolute Error (MAE): 0.4627
#               precision    recall  f1-score   support
#
#         KL 0     0.7485    0.7622    0.7553       328
#         KL 1     0.3492    0.4314    0.3860       153
#         KL 2     0.6480    0.5991    0.6225       212
#         KL 3     0.8554    0.6698    0.7513       106
#         KL 4     1.0000    0.8889    0.9412        27
#
#     accuracy                         0.6513       826
#    macro avg     0.7202    0.6703    0.6913       826
# weighted avg     0.6707    0.6513    0.6584       826
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# Mean Absolute Error (MAE): 0.8498
#               precision    recall  f1-score   support
#
#         KL 0     0.0000    0.0000    0.0000        22
#         KL 1     0.3614    1.0000    0.5310        30
#         KL 2     0.0000    0.0000    0.0000        18
#         KL 3     0.0000    0.0000    0.0000        11
#         KL 4     0.0000    0.0000    0.0000         2
#
#     accuracy                         0.3614        83
#    macro avg     0.0723    0.2000    0.1062        83
# weighted avg     0.1306    0.3614    0.1919        83
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
print("=== Historial de entrenamiento ===")
for metric_name, metric_values in history.history.items():
    print(f"{metric_name}: {metric_values}")

# 2. (Opcional) Graficar las curvas de entrenamiento y validación
import matplotlib.pyplot as plt

# Determinar qué métricas hay (loss, mae o accuracy, val_loss, val_mae o val_accuracy)
keys = list(history.history.keys())

# Para cada métrica de entrenamiento sin prefijo 'val_'
for k in keys:
    if not k.startswith('val_'):
        plt.figure()
        plt.plot(history.history[k], marker='o', label=f'train_{k}')
        val_key = f'val_{k}'
        if val_key in history.history:
            plt.plot(history.history[val_key], marker='s', label=f'val_{k}')
        plt.title(f'Curva de {k}')
        plt.xlabel('Época')
        plt.ylabel(k)
        plt.legend()
        plt.grid(True)
        plt.show()
# Out:
# === Historial de entrenamiento ===
# loss: [3.5959224700927734, 1.5802280902862549, 1.0308701992034912, 0.8491976857185364, 0.6888889074325562, 0.6057036519050598, 0.5811659097671509, 0.5370430946350098, 0.4947221875190735, 0.4910312294960022, 0.4606275260448456, 0.46772560477256775, 0.4666430354118347, 0.42207273840904236, 0.4177216589450836, 0.4066554605960846, 0.41481420397758484, 0.39584800601005554, 0.3919772803783417, 0.39297783374786377, 0.3684532940387726, 0.3743364214897156, 0.3710034489631653, 0.36628034710884094, 0.36930468678474426, 0.35806769132614136, 0.3488844633102417, 0.3466920554637909, 0.3514332175254822, 0.3416975438594818, 0.2913359999656677, 0.25525325536727905, 0.25208237767219543, 0.2508348226547241, 0.23126912117004395, 0.23139211535453796, 0.23401060700416565, 0.20689639449119568, 0.1875639259815216, 0.17246407270431519, 0.17606337368488312, 0.17999444901943207]
# mae: [1.464393138885498, 0.9806683659553528, 0.7979506850242615, 0.7214701175689697, 0.656700611114502, 0.6070975661277771, 0.6017653942108154, 0.5794142484664917, 0.5543824434280396, 0.5492808818817139, 0.5299575924873352, 0.5425761938095093, 0.5350111722946167, 0.5101767778396606, 0.5030848383903503, 0.4977823793888092, 0.5066962242126465, 0.4898955821990967, 0.4883888363838196, 0.4856583774089813, 0.4701930284500122, 0.4739626944065094, 0.4700956344604492, 0.4697130024433136, 0.4699796140193939, 0.46281561255455017, 0.45722949504852295, 0.45348432660102844, 0.4601176679134369, 0.4508737325668335, 0.41705209016799927, 0.38529348373413086, 0.37776362895965576, 0.3776921331882477, 0.3629482388496399, 0.36373162269592285, 0.3664984703063965, 0.3423626124858856, 0.3264468312263489, 0.3126954138278961, 0.3172845244407654, 0.3210802972316742]
# val_loss: [1.4153411388397217, 1.5084335803985596, 1.6142663955688477, 1.4273768663406372, 0.6905004978179932, 0.5835305452346802, 0.4901985824108124, 0.6262047290802002, 0.620902419090271, 0.487846314907074, 0.4713740050792694, 0.5252163410186768, 0.4770027995109558, 0.633302628993988, 0.8525462746620178, 0.46836790442466736, 0.4813087582588196, 0.4735927879810333, 0.5478792190551758, 0.7468650341033936, 0.4656428098678589, 0.4628843069076538, 0.5260391235351562, 0.5492829084396362, 0.45069238543510437, 0.539158284664154, 0.5080816745758057, 0.6101012825965881, 0.6082661151885986, 0.45449596643447876, 0.44163763523101807, 0.4161446690559387, 0.4248681366443634, 0.5203617215156555, 0.49230697751045227, 0.5465725064277649, 0.4940178394317627, 0.46328970789909363, 0.4719230532646179, 0.449209988117218, 0.47592219710350037, 0.46978527307510376]
# val_mae: [1.0446319580078125, 1.025670051574707, 1.0611170530319214, 0.9814770817756653, 0.647468090057373, 0.5925262570381165, 0.5496141314506531, 0.6059907078742981, 0.5866191983222961, 0.5411185026168823, 0.5221922397613525, 0.5561989545822144, 0.5166179537773132, 0.5817843079566956, 0.716890811920166, 0.5330756306648254, 0.5352518558502197, 0.5267407298088074, 0.5485859513282776, 0.606779932975769, 0.5194448828697205, 0.514603316783905, 0.5594946146011353, 0.5717891454696655, 0.5353842973709106, 0.5357661247253418, 0.5071371793746948, 0.545832633972168, 0.6055759787559509, 0.4867386221885681, 0.46369874477386475, 0.4626792073249817, 0.4891981780529022, 0.515903890132904, 0.5038377642631531, 0.5285932421684265, 0.504302442073822, 0.4773138761520386, 0.48529526591300964, 0.47240516543388367, 0.489681214094162, 0.4705694615840912]
# learning_rate: [0.0010000000474974513, 0.0010000000474974513, 0.0010000000474974513, 0.0010000000474974513, 0.0010000000474974513, 0.0010000000474974513, 0.0010000000474974513, 0.0010000000474974513, 0.0010000000474974513, 0.0010000000474974513, 0.0010000000474974513, 0.0010000000474974513, 0.0010000000474974513, 0.0010000000474974513, 0.0010000000474974513, 0.0010000000474974513, 0.0010000000474974513, 0.0010000000474974513, 0.0010000000474974513, 0.0010000000474974513, 0.0010000000474974513, 0.0010000000474974513, 0.0010000000474974513, 0.0010000000474974513, 0.0010000000474974513, 0.0010000000474974513, 0.0010000000474974513, 0.0010000000474974513, 0.0010000000474974513, 0.0010000000474974513, 0.0005000000237487257, 0.0005000000237487257, 0.0005000000237487257, 0.0005000000237487257, 0.0005000000237487257, 0.0005000000237487257, 0.0005000000237487257, 0.0002500000118743628, 0.0002500000118743628, 0.0002500000118743628, 0.0002500000118743628, 0.0002500000118743628]

# %%
cat_callback = callbacks[2]

print("=== Historial de validación de gatos ===")
for m in cat_callback.epoch_metrics:
    epoch = m['epoch']
    loss = m['val_cat_loss']
    acc  = m['val_cat_accuracy']
    print(f"Época {epoch}: Loss/MAE = {loss:.4f}, Accuracy = {acc:.4f}")

# (Opcional) Graficar la evolución de loss y accuracy de validación de gatos
import matplotlib.pyplot as plt

epochs = [m['epoch'] for m in cat_callback.epoch_metrics]
losses = [m['val_cat_loss'] for m in cat_callback.epoch_metrics]
accs   = [m['val_cat_accuracy'] for m in cat_callback.epoch_metrics]

plt.figure()
plt.plot(epochs, losses, marker='o', label='val_cat_loss/MAE')
plt.plot(epochs, accs,   marker='s', label='val_cat_accuracy')
plt.title('Curvas de validación (CatValidationCallback)')
plt.xlabel('Época')
plt.ylabel('Valor')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# === Historial de validación de gatos ===
# Época 1: Loss/MAE = 0.8891, Accuracy = 0.3614
# Época 2: Loss/MAE = 0.8498, Accuracy = 0.3614
# Época 3: Loss/MAE = 0.9340, Accuracy = 0.3253
# Época 4: Loss/MAE = 0.9833, Accuracy = 0.2771
# Época 5: Loss/MAE = 0.9460, Accuracy = 0.3133
# Época 6: Loss/MAE = 0.9768, Accuracy = 0.2892
# Época 7: Loss/MAE = 0.9659, Accuracy = 0.3253
# Época 8: Loss/MAE = 0.9929, Accuracy = 0.3133
# Época 9: Loss/MAE = 1.0057, Accuracy = 0.2771
# Época 10: Loss/MAE = 1.0726, Accuracy = 0.2289
# Época 11: Loss/MAE = 0.9708, Accuracy = 0.3373
# Época 12: Loss/MAE = 0.9723, Accuracy = 0.3133
# Época 13: Loss/MAE = 0.9897, Accuracy = 0.3133
# Época 14: Loss/MAE = 1.1270, Accuracy = 0.2169
# Época 15: Loss/MAE = 1.1153, Accuracy = 0.1928
# Época 16: Loss/MAE = 1.0037, Accuracy = 0.2892
# Época 17: Loss/MAE = 1.0239, Accuracy = 0.3012
# Época 18: Loss/MAE = 0.9711, Accuracy = 0.3012
# Época 19: Loss/MAE = 1.2322, Accuracy = 0.1566
# Época 20: Loss/MAE = 1.0802, Accuracy = 0.2530
# Época 21: Loss/MAE = 1.0010, Accuracy = 0.2892
# Época 22: Loss/MAE = 0.9932, Accuracy = 0.2651
# Época 23: Loss/MAE = 1.0382, Accuracy = 0.2530
# Época 24: Loss/MAE = 1.0523, Accuracy = 0.2771
# Época 25: Loss/MAE = 0.8973, Accuracy = 0.3253
# Época 26: Loss/MAE = 1.0024, Accuracy = 0.2771
# Época 27: Loss/MAE = 0.9510, Accuracy = 0.2771
# Época 28: Loss/MAE = 1.2264, Accuracy = 0.2892
# Época 29: Loss/MAE = 1.0432, Accuracy = 0.2651
# Época 30: Loss/MAE = 0.9958, Accuracy = 0.2651
# Época 31: Loss/MAE = 1.0606, Accuracy = 0.2289
# Época 32: Loss/MAE = 0.9598, Accuracy = 0.2651
# Época 33: Loss/MAE = 0.9794, Accuracy = 0.2771
# Época 34: Loss/MAE = 1.0646, Accuracy = 0.2410
# Época 35: Loss/MAE = 1.0147, Accuracy = 0.2651
# Época 36: Loss/MAE = 0.9849, Accuracy = 0.3133
# Época 37: Loss/MAE = 0.9647, Accuracy = 0.2771
# Época 38: Loss/MAE = 0.9164, Accuracy = 0.2771
# Época 39: Loss/MAE = 0.9154, Accuracy = 0.3494
# Época 40: Loss/MAE = 0.9792, Accuracy = 0.2892
# Época 41: Loss/MAE = 0.9052, Accuracy = 0.3373
# Época 42: Loss/MAE = 0.9141, Accuracy = 0.3373

# %% [markdown]
# # Anterior

# %% [markdown]
# ## Exploración del dataset de artrosis de rodilla
#
# - **Total de imágenes:** 9 786
#
# | Partición      | Imágenes | Porcentaje |
# |---------------|---------:|-----------:|
# | **Train**      | 5 778    | 59.04 %    |
# | **Validation** |   826    |  8.44 %    |
# | **Test**       | 1 656    | 16.92 %    |
# | **AutoTest**   | 1 526    | 15.59 %    |
#
#
# ### Distribución de clases en `Train`
#
# |  Clase  | Índice | Imágenes | Porcentaje |
# |---------|-------:|---------:|-----------:|
# | Sin     |      0 |    2 286 |     39.56 % |
# | Ligera  |      1 |    1 046 |     18.10 % |
# | Leve    |      2 |    1 516 |     26.24 % |
# | Moderada|      3 |      757 |     13.10 % |
# | Severa  |      4 |      173 |      2.99 % |
