# %% [markdown]
# # Github & Imports

# %%
# !git clone https://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@github.com/Tempus23/Radiography_TFG.git
# Out:
# Cloning into 'Radiography_TFG'...
# remote: Enumerating objects: 2585, done.
# remote: Counting objects: 100% (184/184), done.
# remote: Compressing objects: 100% (129/129), done.
# remote: Total 2585 (delta 118), reused 97 (delta 54), pack-reused 2401 (from 1)
# Receiving objects: 100% (2585/2585), 74.20 MiB | 51.41 MiB/s, done.
# Resolving deltas: 100% (557/557), done.

# %%
import os
import sys
os.chdir("Radiography_TFG")
sys.path.append("Radiography_TFG")

# %%
# !pip install -q lightning
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt

import torch
from torchvision import datasets, transforms
from torch.utils.data import DataLoader

from tensorflow.keras.preprocessing.image import ImageDataGenerator # type: ignore

from src.config import *
from src.data import *
from src.models.efficientnet import EfficientNetB5Custom, EfficientNetB0, EfficientNetB5, EfficientNetB7, EfficientNetB4
from src.models.resnet18 import ResNet18_v2
from src.models.ensembling import Ensembling
from src.models.simpleCNN import SimpleCNN
from src.utils import *
from src.data import OriginalOAIDataset, DatasetExperiment1
from src.train import train, train_model, test_model
from src.trainers.classification import Classification, ClassificationAdamax
from src.trainers.regresion import Regression
import wandb
# Set random seeds
torch.manual_seed(RANDOM_SEED)
np.random.seed(RANDOM_SEED)
torch.cuda.manual_seed(RANDOM_SEED)

# %% [markdown]
# # Training

# %%
BATCH_SIZE = 32
LEARNING_RATE = 0.001
FACTOR = 0.5
L1 = 0.00
L2 = 0.0001
PATIENCE = 5
BETAS=(0.9, 0.999)
LOCAL = False
# Regularización L1 y L2
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# wandb 254f72e7bdeec44797ba1b2a91ebbc63900b89f4
# /kaggle/input/aug-oai-capitulo3/augmented_oai
DATASET_PATH = '../../input/aug-oai-capitulo3/augmented_oai'
#DATASET_PATH = '../../input/original-oai/split_oai'
train_dataset = DatasetExperiment1('train', batch_size=BATCH_SIZE, local=LOCAL,grey=False, path = DATASET_PATH)
val_dataset = DatasetExperiment1('val', batch_size=BATCH_SIZE, local=LOCAL, grey=False, path = DATASET_PATH)
#model =ResNet18_v2(n_classes = 1)
#model = EfficientNetB0(num_classes = 1, pretrained = False)
model = EfficientNetB5(num_classes = 1, pretrained = True)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
trainer = Regression(model, device, L1=L1, L2=L2, lr=LEARNING_RATE, factor=FACTOR, patience=PATIENCE, betas=BETAS)
wandb.login(key="254f72e7bdeec44797ba1b2a91ebbc63900b89f4")
# Out:
# Downloading: "https://download.pytorch.org/models/efficientnet_b5_lukemelas-1a07897c.pth" to /root/.cache/torch/hub/checkpoints/efficientnet_b5_lukemelas-1a07897c.pth
# 100%|██████████| 117M/117M [00:00<00:00, 182MB/s]
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: chermar (chermar-universitat-polit-cnica-de-val-ncia). Use `wandb login --relogin` to force relogin
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %%
train_model(model, trainer, train_dataset, val_dataset, epochs=50, device=device, save_model = "reg_origOAI", name="reg_origOAI", wdb=True, local=False, early_stopping_patience=10)
# Out:
# wandb: Tracking run with wandb version 0.19.1
# wandb: Run data is saved locally in /kaggle/working/Radiography_TFG/wandb/run-20250326_152354-c4b4mmg5
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run EfficientNetB5_reg_origOAI
# wandb: ⭐️ View project at https://wandb.ai/chermar-universitat-polit-cnica-de-val-ncia/oai-knee-cartilage-segmentation
# wandb: 🚀 View run at https://wandb.ai/chermar-universitat-polit-cnica-de-val-ncia/oai-knee-cartilage-segmentation/runs/c4b4mmg5
# Training Epoch [1/50]: 100%|███████████████████████████| 918/918 [18:02<00:00,  1.18s/it, acc=0.418, complete_loss=16.80, train_loss=0.0481]
# Validation Epoch [1/50]: 100%|██████████████████████████████████████████████| 25/25 [00:18<00:00,  1.38it/s, acc=0.282, val_loss=0.12130286]
# Training Epoch [2/50]: 100%|████████████████████████████| 918/918 [13:35<00:00,  1.13it/s, acc=0.443, complete_loss=4.83, train_loss=0.0405]
# Validation Epoch [2/50]: 100%|██████████████████████████████████████████████| 25/25 [00:11<00:00,  2.25it/s, acc=0.264, val_loss=0.10607024]
# Training Epoch [3/50]: 100%|████████████████████████████| 918/918 [13:28<00:00,  1.14it/s, acc=0.441, complete_loss=1.83, train_loss=0.0407]
# Validation Epoch [3/50]: 100%|██████████████████████████████████████████████| 25/25 [00:11<00:00,  2.25it/s, acc=0.303, val_loss=0.06361740]
# Training Epoch [4/50]: 100%|████████████████████████████| 918/918 [13:29<00:00,  1.13it/s, acc=0.451, complete_loss=0.86, train_loss=0.0396]
# Validation Epoch [4/50]: 100%|██████████████████████████████████████████████| 25/25 [00:10<00:00,  2.28it/s, acc=0.418, val_loss=0.07609499]
# Training Epoch [5/50]: 100%|█████████████████████████████| 918/918 [13:24<00:00,  1.14it/s, acc=0.46, complete_loss=0.46, train_loss=0.0378]
# Validation Epoch [5/50]: 100%|██████████████████████████████████████████████| 25/25 [00:11<00:00,  2.22it/s, acc=0.318, val_loss=0.04290963]
# Training Epoch [6/50]: 100%|████████████████████████████| 918/918 [13:27<00:00,  1.14it/s, acc=0.473, complete_loss=0.26, train_loss=0.0365]
# Validation Epoch [6/50]: 100%|██████████████████████████████████████████████| 25/25 [00:11<00:00,  2.15it/s, acc=0.368, val_loss=0.04911996]
# Training Epoch [7/50]: 100%|████████████████████████████| 918/918 [13:23<00:00,  1.14it/s, acc=0.482, complete_loss=0.17, train_loss=0.0354]
# Validation Epoch [7/50]: 100%|███████████████████████████████████████████████| 25/25 [00:11<00:00,  2.15it/s, acc=0.36, val_loss=0.05778585]
# Training Epoch [8/50]: 100%|████████████████████████████| 918/918 [13:23<00:00,  1.14it/s, acc=0.479, complete_loss=0.12, train_loss=0.0357]
# Validation Epoch [8/50]: 100%|██████████████████████████████████████████████| 25/25 [00:11<00:00,  2.27it/s, acc=0.376, val_loss=0.04764206]
# Training Epoch [9/50]: 100%|████████████████████████████| 918/918 [13:22<00:00,  1.14it/s, acc=0.486, complete_loss=0.09, train_loss=0.0351]
# Validation Epoch [9/50]: 100%|██████████████████████████████████████████████| 25/25 [00:12<00:00,  2.07it/s, acc=0.414, val_loss=0.05239171]
# Training Epoch [10/50]: 100%|███████████████████████████| 918/918 [13:22<00:00,  1.14it/s, acc=0.487, complete_loss=0.08, train_loss=0.0348]
# Validation Epoch [10/50]: 100%|█████████████████████████████████████████████| 25/25 [00:11<00:00,  2.19it/s, acc=0.445, val_loss=0.06585866]
# Training Epoch [11/50]: 100%|███████████████████████████| 918/918 [13:26<00:00,  1.14it/s, acc=0.494, complete_loss=0.07, train_loss=0.0346]
# Validation Epoch [11/50]: 100%|█████████████████████████████████████████████| 25/25 [00:11<00:00,  2.09it/s, acc=0.422, val_loss=0.05100800]
# Training Epoch [12/50]: 100%|███████████████████████████| 918/918 [13:28<00:00,  1.13it/s, acc=0.524, complete_loss=0.06, train_loss=0.0312]
# Validation Epoch [12/50]: 100%|███████████████████████████████████████████████| 25/25 [00:11<00:00,  2.14it/s, acc=0.5, val_loss=0.05442425]
# Training Epoch [13/50]: 100%|███████████████████████████| 918/918 [13:30<00:00,  1.13it/s, acc=0.531, complete_loss=0.06, train_loss=0.0303]
# Validation Epoch [13/50]: 100%|█████████████████████████████████████████████| 25/25 [00:11<00:00,  2.15it/s, acc=0.428, val_loss=0.03385196]
# Training Epoch [14/50]: 100%|███████████████████████████| 918/918 [13:30<00:00,  1.13it/s, acc=0.535, complete_loss=0.06, train_loss=0.0300]
# Validation Epoch [14/50]: 100%|█████████████████████████████████████████████| 25/25 [00:11<00:00,  2.18it/s, acc=0.518, val_loss=0.03196336]
# Training Epoch [15/50]: 100%|███████████████████████████| 918/918 [13:26<00:00,  1.14it/s, acc=0.537, complete_loss=0.05, train_loss=0.0299]
# Validation Epoch [15/50]: 100%|█████████████████████████████████████████████| 25/25 [00:11<00:00,  2.25it/s, acc=0.476, val_loss=0.03259259]
# Training Epoch [16/50]: 100%|███████████████████████████| 918/918 [13:23<00:00,  1.14it/s, acc=0.547, complete_loss=0.05, train_loss=0.0292]
# Validation Epoch [16/50]: 100%|█████████████████████████████████████████████| 25/25 [00:10<00:00,  2.31it/s, acc=0.558, val_loss=0.03119721]
# Training Epoch [17/50]: 100%|███████████████████████████| 918/918 [13:35<00:00,  1.13it/s, acc=0.543, complete_loss=0.05, train_loss=0.0291]
# Validation Epoch [17/50]: 100%|██████████████████████████████████████████████| 25/25 [00:11<00:00,  2.22it/s, acc=0.49, val_loss=0.03258132]
# Training Epoch [18/50]: 100%|███████████████████████████| 918/918 [13:29<00:00,  1.13it/s, acc=0.543, complete_loss=0.05, train_loss=0.0294]
# Validation Epoch [18/50]: 100%|█████████████████████████████████████████████| 25/25 [00:11<00:00,  2.17it/s, acc=0.492, val_loss=0.03088659]
# Training Epoch [19/50]: 100%|████████████████████████████| 918/918 [13:26<00:00,  1.14it/s, acc=0.55, complete_loss=0.05, train_loss=0.0289]
# Validation Epoch [19/50]: 100%|█████████████████████████████████████████████| 25/25 [00:10<00:00,  2.28it/s, acc=0.515, val_loss=0.03608625]
# Training Epoch [20/50]: 100%|████████████████████████████| 918/918 [13:25<00:00,  1.14it/s, acc=0.55, complete_loss=0.05, train_loss=0.0289]
# Validation Epoch [20/50]: 100%|█████████████████████████████████████████████| 25/25 [00:12<00:00,  2.04it/s, acc=0.544, val_loss=0.03404237]
# Training Epoch [21/50]: 100%|███████████████████████████| 918/918 [13:31<00:00,  1.13it/s, acc=0.552, complete_loss=0.05, train_loss=0.0287]
# Validation Epoch [21/50]: 100%|█████████████████████████████████████████████| 25/25 [00:11<00:00,  2.24it/s, acc=0.545, val_loss=0.02902147]
# Training Epoch [22/50]: 100%|███████████████████████████| 918/918 [13:26<00:00,  1.14it/s, acc=0.554, complete_loss=0.05, train_loss=0.0285]
# Validation Epoch [22/50]: 100%|█████████████████████████████████████████████| 25/25 [00:11<00:00,  2.24it/s, acc=0.522, val_loss=0.03184003]
# Training Epoch [23/50]: 100%|███████████████████████████| 918/918 [13:30<00:00,  1.13it/s, acc=0.555, complete_loss=0.05, train_loss=0.0283]
# Validation Epoch [23/50]: 100%|█████████████████████████████████████████████| 25/25 [00:11<00:00,  2.16it/s, acc=0.481, val_loss=0.03245889]
# Training Epoch [24/50]: 100%|███████████████████████████| 918/918 [13:21<00:00,  1.14it/s, acc=0.552, complete_loss=0.05, train_loss=0.0283]
# Validation Epoch [24/50]: 100%|█████████████████████████████████████████████| 25/25 [00:10<00:00,  2.32it/s, acc=0.564, val_loss=0.03123408]
# Training Epoch [25/50]: 100%|███████████████████████████| 918/918 [13:32<00:00,  1.13it/s, acc=0.558, complete_loss=0.05, train_loss=0.0281]
# Validation Epoch [25/50]: 100%|█████████████████████████████████████████████| 25/25 [00:10<00:00,  2.33it/s, acc=0.442, val_loss=0.04719966]
# Training Epoch [26/50]: 100%|████████████████████████████| 918/918 [13:25<00:00,  1.14it/s, acc=0.56, complete_loss=0.04, train_loss=0.0280]
# Validation Epoch [26/50]: 100%|█████████████████████████████████████████████| 25/25 [00:10<00:00,  2.32it/s, acc=0.537, val_loss=0.03797235]
# Training Epoch [27/50]: 100%|███████████████████████████| 918/918 [13:26<00:00,  1.14it/s, acc=0.558, complete_loss=0.04, train_loss=0.0283]
# Validation Epoch [27/50]: 100%|█████████████████████████████████████████████| 25/25 [00:11<00:00,  2.25it/s, acc=0.503, val_loss=0.03561866]
# Training Epoch [28/50]: 100%|███████████████████████████| 918/918 [13:29<00:00,  1.13it/s, acc=0.586, complete_loss=0.04, train_loss=0.0253]
# Validation Epoch [28/50]: 100%|█████████████████████████████████████████████| 25/25 [00:11<00:00,  2.23it/s, acc=0.547, val_loss=0.03013894]
# Training Epoch [29/50]: 100%|███████████████████████████| 918/918 [13:33<00:00,  1.13it/s, acc=0.592, complete_loss=0.04, train_loss=0.0249]
# Validation Epoch [29/50]: 100%|█████████████████████████████████████████████| 25/25 [00:11<00:00,  2.14it/s, acc=0.564, val_loss=0.02913173]
# Training Epoch [30/50]: 100%|███████████████████████████| 918/918 [13:30<00:00,  1.13it/s, acc=0.591, complete_loss=0.04, train_loss=0.0248]
# Validation Epoch [30/50]: 100%|█████████████████████████████████████████████| 25/25 [00:11<00:00,  2.25it/s, acc=0.564, val_loss=0.03388588]
# Training Epoch [31/50]: 100%|███████████████████████████| 918/918 [13:27<00:00,  1.14it/s, acc=0.597, complete_loss=0.04, train_loss=0.0245]
# Validation Epoch [31/50]: 100%|█████████████████████████████████████████████| 25/25 [00:11<00:00,  2.22it/s, acc=0.526, val_loss=0.02902804]
# Early stopping at epoch 31
# Test model EfficientNetB5 - Loss: 0.03, ACC: 0.53, AUC: 0.41, Sensivility: 0.55, Specificity: 0.59
# Estadísticas detalladas por clase:
# +---------+---------+-----------+-------+-------+------+-------+-------+------------+
# |   Clase |   Media |   Mediana |   P25 |   P75 |   P5 |   P95 |   MAE |   Muestras |
# +=========+=========+===========+=======+=======+======+=======+=======+============+
# |       0 |    0.56 |      0.47 |  0.24 |  0.83 | 0.06 |  1.38 | 0.558 |        308 |
# +---------+---------+-----------+-------+-------+------+-------+-------+------------+
# |       1 |    0.95 |      0.87 |  0.53 |  1.28 | 0.21 |  1.94 | 0.417 |        141 |
# +---------+---------+-----------+-------+-------+------+-------+-------+------------+
# |       2 |    1.62 |      1.58 |  1.18 |  2.05 | 0.54 |  2.59 | 0.604 |        206 |
# +---------+---------+-----------+-------+-------+------+-------+-------+------------+
# |       3 |    2.72 |      2.83 |  2.35 |  3.07 | 1.53 |  3.61 | 0.497 |        102 |
# +---------+---------+-----------+-------+-------+------+-------+-------+------------+
# |       4 |    3.54 |      3.57 |  3.18 |  3.83 | 3.06 |  4.19 | 0.502 |         23 |
# +---------+---------+-----------+-------+-------+------+-------+-------+------------+

# %%
test_model(model, val_dataset.get_dataloader(), trainer, device)
test_model(model, train_dataset.get_dataloader(), trainer, device)
# Out:
# Test model EfficientNetB5 - Loss: 0.03, ACC: 0.53, AUC: 0.38, Sensivility: 0.55, Specificity: 0.59
# Estadísticas detalladas por clase:
# +---------+---------+-----------+-------+-------+------+-------+-------+------------+
# |   Clase |   Media |   Mediana |   P25 |   P75 |   P5 |   P95 |   MAE |   Muestras |
# +=========+=========+===========+=======+=======+======+=======+=======+============+
# |       0 |    0.56 |      0.47 |  0.24 |  0.83 | 0.06 |  1.38 | 0.558 |        308 |
# +---------+---------+-----------+-------+-------+------+-------+-------+------------+
# |       1 |    0.95 |      0.87 |  0.53 |  1.28 | 0.21 |  1.94 | 0.417 |        141 |
# +---------+---------+-----------+-------+-------+------+-------+-------+------------+
# |       2 |    1.62 |      1.58 |  1.18 |  2.05 | 0.54 |  2.59 | 0.604 |        206 |
# +---------+---------+-----------+-------+-------+------+-------+-------+------------+
# |       3 |    2.72 |      2.83 |  2.35 |  3.07 | 1.53 |  3.61 | 0.497 |        102 |
# +---------+---------+-----------+-------+-------+------+-------+-------+------------+
# |       4 |    3.54 |      3.57 |  3.18 |  3.83 | 3.06 |  4.19 | 0.502 |         23 |
# +---------+---------+-----------+-------+-------+------+-------+-------+------------+
# Test model EfficientNetB5 - Loss: 0.02, ACC: 0.62, AUC: 0.41, Sensivility: 0.66, Specificity: 0.70
# Estadísticas detalladas por clase:
# +---------+---------+-----------+-------+-------+------+-------+-------+------------+
# |   Clase |   Media |   Mediana |   P25 |   P75 |   P5 |   P95 |   MAE |   Muestras |
# +=========+=========+===========+=======+=======+======+=======+=======+============+
# |       0 |    0.47 |      0.4  |  0.22 |  0.64 | 0.08 |  1.08 | 0.47  |        808 |
# +---------+---------+-----------+-------+-------+------+-------+-------+------------+
# |       1 |    0.94 |      0.91 |  0.57 |  1.28 | 0.24 |  1.75 | 0.386 |        391 |
# +---------+---------+-----------+-------+-------+------+-------+-------+------------+
# |       2 |    1.62 |      1.6  |  1.29 |  2.03 | 0.69 |  2.51 | 0.532 |        517 |
# +---------+---------+-----------+-------+-------+------+-------+-------+------------+
# |       3 |    2.78 |      2.84 |  2.53 |  3.05 | 2.01 |  3.44 | 0.375 |        239 |
# +---------+---------+-----------+-------+-------+------+-------+-------+------------+
# |       4 |    3.86 |      3.88 |  3.55 |  4.22 | 3.17 |  4.7  | 0.406 |         61 |
# +---------+---------+-----------+-------+-------+------+-------+-------+------------+
