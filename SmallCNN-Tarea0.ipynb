# %% [markdown]
# # Imports and utility

# %%
#d8f53b61969adf7ee621c216f680b707
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns
import cv2
import keras_hub
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models
from tensorflow.keras.layers import (Input, Conv2D, MaxPooling2D, Flatten, Dense, Dropout,
                                     BatchNormalization, Activation, GlobalAveragePooling2D)
from tensorflow.keras.applications import VGG16, VGG19, ResNet50, ResNet152, EfficientNetB0, DenseNet121, InceptionV3
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, LearningRateScheduler, ModelCheckpoint
from tensorflow.keras import optimizers

train_dir = '/kaggle/input/knee-osteoarthritis-dataset-with-severity/train'
val_dir = '/kaggle/input/knee-osteoarthritis-dataset-with-severity/val'
test_dir = '/kaggle/input/knee-osteoarthritis-dataset-with-severity/test'
auto_test = '/kaggle/input/knee-osteoarthritis-dataset-with-severity/auto_test'
cat_dir = '/kaggle/input/cat-knee/clean'

IMG_SIZE = (224, 224)
BATCH_SIZE = 8
SEED = 66

# %%
import pandas as pd
import os

def create_dataframe_from_directory(base_dir, regression=False):
    data = []
    for label_str in sorted(os.listdir(base_dir)):
        label_path = os.path.join(base_dir, label_str)
        if not os.path.isdir(label_path):
            continue
        label = float(label_str) if regression else label_str
        for fname in os.listdir(label_path):
            data.append({
                'filename': os.path.join(label_str, fname),  # ruta relativa
                'label': label  # KL debe ser numérico para regresión
            })
    return pd.DataFrame(data)

# %%
from sklearn.metrics import mean_absolute_error, accuracy_score
import numpy as np
import tensorflow as tf

class CatValidationCallback(tf.keras.callbacks.Callback):
    def __init__(self, cat_generator, regresion=False, filepath='best_model_cat.keras'):
        super().__init__()
        self.cat_generator = cat_generator
        self.epoch_metrics = []
        self.regresion = regresion
        self.filepath = filepath
        # Inicializamos best_score y best_loss
        if regresion:
            self.best_score = 0.0    # queremos maximizar accuracy
            self.best_loss  = np.inf # y minimizar MAE
        else:
            self.best_score = 0.0    # queremos maximizar accuracy
            self.best_loss  = np.inf # y minimizar categorical loss

    def on_epoch_end(self, epoch, logs=None):
        # Predicciones
        preds = self.model.predict(self.cat_generator, verbose=0)

        if self.regresion:
            # Regresión: calculamos MAE + accuracy sobre clases redondeadas
            y_pred = preds.flatten()
            y_true = self.cat_generator.labels
            loss = mean_absolute_error(y_true, y_pred)
            y_pred_class = np.clip(np.round(y_pred), 0, 4).astype(int)
            y_true_class = np.clip(np.round(y_true), 0, 4).astype(int)
            acc = accuracy_score(y_true_class, y_pred_class)
            score = acc
        else:
            # Clasificación: evalúa el loss y la accuracy
            loss, acc = self.model.evaluate(self.cat_generator, verbose=0)
            preds_class = np.argmax(preds, axis=1)
            y_true = self.cat_generator.classes
            # para consistency, recalculamos acc con sklearn
            acc = accuracy_score(y_true, preds_class)
            score = acc

        # Guardar métricas
        self.epoch_metrics.append({
            'epoch': epoch + 1,
            'val_cat_loss': loss,
            'val_cat_accuracy': acc
        })

        # Mostrar por consola
        tag = "MAE" if self.regresion else "Loss"
        print(f"🐾 [Cat Val] {tag}: {loss:.4f} | Accuracy: {acc:.4f}")

        # Comprobamos mejora: primero por score, si empate por loss
        improved = False
        if score > self.best_score:
            improved = True
        elif score == self.best_score and loss < self.best_loss:
            improved = True

        # Si mejoró, guardamos modelo y actualizamos referencias
        if improved:
            self.best_score = score
            self.best_loss  = loss
            self.model.save(self.filepath)
            print(f"📦 Modelo mejorado guardado en {self.filepath}")

# %%
from tensorflow.keras.callbacks import ModelCheckpoint

def get_callbacks(regression=False, cat_gen=None):
  cat_val_cb = CatValidationCallback(cat_gen, regresion=regression)
  

  checkpoint_cb = ModelCheckpoint(
    filepath='best_model.keras',
    monitor='val_accuracy',         # nombre de la métrica a monitorizar
    mode='max',                     # porque buscamos la mayor precisión
    save_best_only=True,
    save_weights_only=False,
    verbose=1
  )
  checkpoint_cb_reg = ModelCheckpoint(
    filepath='best_model.keras',
    monitor='val_loss',
    mode='min',
    save_best_only=True,
    save_weights_only=False,
    verbose=1
  )
  if regression:
    callbacks = [
        EarlyStopping(patience=10, restore_best_weights=True),
        ReduceLROnPlateau(factor=0.5, patience=5, verbose=1),
        cat_val_cb,
        checkpoint_cb_reg
    ]
  else:
    callbacks = [
        EarlyStopping(patience=10, restore_best_weights=True),
        ReduceLROnPlateau(factor=0.5, patience=5, verbose=1),
        cat_val_cb,
        checkpoint_cb
    ]
  return callbacks

# %%
from sklearn.metrics import classification_report, confusion_matrix, mean_absolute_error
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

def _get_label_map(y_true, y_pred, generator=None, default_prefix='KL'):
    """
    Genera label_map automáticamente.
    - Si el generador tiene class_indices (clasificación Keras), los usa.
    - Si no, extrae las clases únicas de y_true y y_pred.
    - Si todo falla, crea labels 'KL 0', 'KL 1', ..., según número de clases.
    """
    # Caso Keras classification_generator
    if generator is not None and hasattr(generator, 'class_indices'):
        # Ordenar por índice
        sorted_items = sorted(generator.class_indices.items(), key=lambda x: x[1])
        return [name for name, _ in sorted_items]
    
    # Extraer clases únicas
    classes = np.unique(np.concatenate((y_true, y_pred)))
    # Si son enteros consecutivos desde 0 a n-1
    if np.array_equal(classes, np.arange(len(classes))):
        return [f'{default_prefix} {i}' for i in classes]
    # En caso de etiquetas no enteras o desordenadas
    return [str(c) for c in classes]

def evaluate_classification(y_true, y_pred, label_map=None, digits=4, title_suffix=''):
    """
    Reporte de clasificación + matriz de confusión.
    """
    if label_map is None:
        label_map = _get_label_map(y_true, y_pred)
    # Reporte
    print(classification_report(
        y_true, y_pred,
        target_names=label_map,
        digits=digits
    ))
    # Matriz de confusión
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(8,6))
    sns.heatmap(
        cm, annot=True, fmt='d', cmap='Blues',
        xticklabels=label_map, yticklabels=label_map
    )
    plt.xlabel('Predicción')
    plt.ylabel('Etiqueta verdadera')
    if title_suffix:
        plt.title(title_suffix)
    plt.show()

def evaluate_model(model, regression, generator, label_map=None, digits=4):
    """
    Elige el modo de evaluación y asegura que label_map siempre se resuelva.
    """
    # Predicciones crudas
    preds = model.predict(generator)
    
    if regression:
        # Convertir a clases
        if hasattr(generator, 'labels'):
            y_true_cont = np.array(generator.labels).flatten()
        else:
            y_true_cont = np.array(generator.classes).flatten()
        y_pred_cont = np.array(preds).flatten()
        
        # MAE
        mae = mean_absolute_error(y_true_cont, y_pred_cont)
        print(f"Mean Absolute Error (MAE): {mae:.{digits}f}\n")
        plt.figure(figsize=(6,6))
        # Dispersión
        plt.scatter(y_pred_cont, y_true_cont, alpha=0.5)
        # Línea de identidad
        mn = min(y_true_cont.min(), y_pred_cont.min())
        mx = max(y_true_cont.max(), y_pred_cont.max())
        plt.plot([mn, mx], [mn, mx], 'r--', linewidth=1)
        # Etiquetas
        plt.xlabel("Predicción (decimal)")
        plt.ylabel("Valor verdadero")
        plt.title("Scatter: Predicción vs Valor verdadero")
        plt.grid(True)
        plt.show()

        y_true_class = np.clip(np.round(y_true_cont).astype(int), 0, None)
        y_pred_class = np.clip(np.round(y_pred_cont).astype(int), 0, None)
        # Obtener label_map adaptado al rango observado
        if label_map is None:
            max_label = max(y_true_class.max(), y_pred_class.max())
            label_map = [f'KL {i}' for i in range(max_label + 1)]
        
        evaluate_classification(
            y_true=y_true_class,
            y_pred=y_pred_class,
            label_map=label_map,
            digits=digits,
        )
    else:
        # Clasificación softmax u otra salida multiclase
        y_pred = np.argmax(preds, axis=1)
        y_true = generator.classes
        
        if label_map is None:
            label_map = _get_label_map(y_true, y_pred, generator=generator)
        
        evaluate_classification(
            y_true=y_true,
            y_pred=y_pred,
            label_map=label_map,
            digits=digits
        )

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import pandas as pd

def get_datagen(
    tarea: int,
    path: str,
    regression: bool = False,
    IMG_SIZE: tuple = (224, 224),
    BATCH_SIZE: int = 32,
    SEED: int = 42,
    augment: bool = False
):
    """
    Generador de imágenes para clasificación y regresión con distintos esquemas de tarea.

    Parámetros:
        tarea       – entero 0–5 que define esquema de etiquetas.
        path        – ruta al directorio de imágenes (train/val/test u otro).
        regression  – True para regresión (class_mode='raw'), False para clasificación.
        IMG_SIZE    – tupla (alto, ancho).
        BATCH_SIZE  – tamaño de lote.
        SEED        – semilla aleatoria.
        augment     – True para data augmentation (solo en entrenamiento).
    """
    # Configurar DataGenerator
    if augment:
        datagen = ImageDataGenerator(
            rescale=1./255,
            rotation_range=10,
            width_shift_range=0.1,
            height_shift_range=0.1,
            zoom_range=0.1,
            horizontal_flip=True
        )
        shuffle = True
    else:
        datagen = ImageDataGenerator(rescale=1./255)
        shuffle = False

    # Cargar dataframe con tu función; label como float si regresión, str si clasificación
    df = create_dataframe_from_directory(path, regression=regression)
    # Clasificación: convertir labels a ints para procesar tareas
    df_proc = df.copy()
    df_proc['label'] = df_proc['label'].astype(int)

    if tarea == 0:
        # Multiclase original 0–4: no cambio
        pass
    elif tarea == 1:
        df_proc['label'] = df_proc['label'].apply(
            lambda x: 0 if x in [0,1,2] else 1 if x == 3 else 2 if x == 4 else x
        )
    elif tarea in [2,3,4,5]:
        target = tarea - 1  # tarea=2->1, etc.
        df_proc = df_proc[df_proc['label'].isin([0, target])]
        df_proc['label'] = df_proc['label'].apply(lambda x: 1 if x == target else 0)
    else:
        raise ValueError("tarea debe ser un entero entre 0 y 5.")

    if regression:
        # Asegurar float
        df_proc['label'] = df_proc['label'].astype(float)
        return datagen.flow_from_dataframe(
            dataframe=df_proc,
            directory=path,
            x_col='filename',
            y_col='label',
            target_size=IMG_SIZE,
            batch_size=BATCH_SIZE,
            class_mode='raw',
            shuffle=shuffle,
            seed=SEED
        )
    # Convertir a string para class_mode='categorical'
    df_proc['label'] = df_proc['label'].astype(str)
    
    # Generador de clasificación
    return datagen.flow_from_dataframe(
        dataframe=df_proc,
        directory=path,
        x_col='filename',
        y_col='label',
        target_size=IMG_SIZE,
        batch_size=BATCH_SIZE,
        class_mode='categorical',
        shuffle=shuffle,
        seed=SEED
    )

# %% [markdown]
# ## Experimentos a realizar
#
# Normal
# 012-3-4
# 0-1
# 0-2
# 0-3
# 0-4

# %%
def cnn_pequeno(num_classes = 5, regression=False):
    activation = 'linear' if regression else 'softmax'
    model = models.Sequential([
        layers.Conv2D(16, (3,3), activation='relu',
                      input_shape=(224,224,3)),
        layers.MaxPooling2D(2,2),
        layers.Flatten(),
        layers.Dense(num_classes, activation=activation)
    ])
    return model

# %%
def cnn_mediana(num_classes, regression=False):
    activation = 'linear' if regression else 'softmax'
    model = models.Sequential([
        # Primera capa convolucional
        Conv2D(32, (3, 3), activation='relu', padding='same', input_shape=(224,224,3)),
        MaxPooling2D((2, 2)),
        # Segunda capa convolucional
        Conv2D(64, (3, 3), activation='relu', padding='same'),
        MaxPooling2D((2, 2)),
        # Aplanamiento y capas densas
        Flatten(),
        Dense(128, activation='relu'),
        Dense(num_classes, activation=activation)
    ])
    return model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (
    Conv2D, BatchNormalization, MaxPooling2D, Dropout,
    Flatten, Dense
)

def cnn_grande(num_classes, regression = False):
    activation = 'linear' if regression else 'softmax'
    model = Sequential(name="CNN_Profunda")

    # Bloque 1
    model.add(Conv2D(32, (3, 3), activation='relu', padding='same',
                     input_shape=(224,224,3)))
    model.add(BatchNormalization())
    model.add(Conv2D(32, (3, 3), activation='relu', padding='same'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D((2, 2)))
    model.add(Dropout(0.25))

    # Bloque 2
    model.add(Conv2D(64, (3, 3), activation='relu', padding='same'))
    model.add(BatchNormalization())
    model.add(Conv2D(64, (3, 3), activation='relu', padding='same'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D((2, 2)))
    model.add(Dropout(0.25))

    # Bloque 3
    model.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
    model.add(BatchNormalization())
    model.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D((2, 2)))
    model.add(Dropout(0.40))

    # Clasificación final
    model.add(Flatten())
    model.add(Dense(256, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.50))
    model.add(Dense(num_classes, activation=activation))

    return model

# %%
def simple_transformer(num_classes=5, regression=False):
    activation = 'linear' if regression else 'softmax'

    inputs = layers.Input(shape=(224, 224, 3))
    x = layers.Conv2D(32, (3, 3), padding='same')(inputs)
    x = layers.Reshape((-1, 32))(x)
    x = layers.MultiHeadAttention(num_heads=1, key_dim=4)(x, x)
    x = layers.GlobalAveragePooling1D()(x)
    x = layers.Dense(128, activation='relu')(x)
    outputs = layers.Dense(num_classes, activation=activation)(x)

    model = models.Model(inputs, outputs)
    return model

# %%
regression = False
tarea = 0
batch_size = 32
num_classes = 5
if regression:
    num_classes = 1
elif tarea == 1:
    num_classes = 3
elif tarea > 1:
    num_classes = 2

loss = 'mean_squared_error' if regression else 'categorical_crossentropy'
metrics = ['mae'] if regression else ['accuracy']

# Generadores de datos (entrenamiento y validación)
train_gen = get_datagen(tarea=tarea, path=train_dir, regression=regression, BATCH_SIZE=batch_size, augment=True)
val_gen   = get_datagen(tarea=tarea, path=val_dir,  BATCH_SIZE=batch_size, regression=regression)
cat_gen = get_datagen(tarea=tarea, path=cat_dir, BATCH_SIZE=batch_size, regression=regression)


model = cnn_pequeno(num_classes, regression)
model.compile(optimizer='adam',
                  loss=loss,
                  metrics=metrics)
callbacks=get_callbacks(regression, cat_gen)
history = model.fit(
    train_gen,
    validation_data=val_gen,
    epochs=50,
    callbacks=callbacks
)

model.load_weights('best_model.keras')
# Obtén el diccionario original {etiqueta_str: índice_entero}
evaluate_model(model, regression=regression, generator=val_gen)
model.load_weights('best_model_cat.keras')
evaluate_model(model, regression=regression, generator=cat_gen)
# Out:
# Found 5778 validated image filenames belonging to 5 classes.
# Found 826 validated image filenames belonging to 5 classes.
# Found 83 validated image filenames belonging to 5 classes.
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/50
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 179/181 ━━━━━━━━━━━━━━━━━━━━ 0s 453ms/step - accuracy: 0.3225 - loss: 11.2145🐾 [Cat Val] Loss: 1.5390 | Accuracy: 0.2651
# 📦 Modelo mejorado guardado en best_model_cat.keras
#
# Epoch 1: val_accuracy improved from -inf to 0.40557, saving model to best_model.keras
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 98s 501ms/step - accuracy: 0.3232 - loss: 11.1045 - val_accuracy: 0.4056 - val_loss: 1.4155 - learning_rate: 0.0010
# Epoch 2/50
# 178/181 ━━━━━━━━━━━━━━━━━━━━ 1s 335ms/step - accuracy: 0.3919 - loss: 1.4197🐾 [Cat Val] Loss: 1.5464 | Accuracy: 0.2651
#
# Epoch 2: val_accuracy did not improve from 0.40557
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 65s 346ms/step - accuracy: 0.3920 - loss: 1.4195 - val_accuracy: 0.4056 - val_loss: 1.4026 - learning_rate: 0.0010
# Epoch 3/50
# 179/181 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step - accuracy: 0.3995 - loss: 1.4027🐾 [Cat Val] Loss: 1.5238 | Accuracy: 0.2651
# 📦 Modelo mejorado guardado en best_model_cat.keras
#
# Epoch 3: val_accuracy did not improve from 0.40557
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 65s 344ms/step - accuracy: 0.3995 - loss: 1.4028 - val_accuracy: 0.4031 - val_loss: 1.4089 - learning_rate: 0.0010
# Epoch 4/50
# 179/181 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step - accuracy: 0.4005 - loss: 1.4081🐾 [Cat Val] Loss: 1.5531 | Accuracy: 0.2651
#
# Epoch 4: val_accuracy did not improve from 0.40557
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 64s 339ms/step - accuracy: 0.4005 - loss: 1.4080 - val_accuracy: 0.4044 - val_loss: 1.3982 - learning_rate: 0.0010
# Epoch 5/50
# 179/181 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step - accuracy: 0.4088 - loss: 1.4032🐾 [Cat Val] Loss: 1.5758 | Accuracy: 0.2651
#
# Epoch 5: val_accuracy improved from 0.40557 to 0.40920, saving model to best_model.keras
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 64s 341ms/step - accuracy: 0.4088 - loss: 1.4031 - val_accuracy: 0.4092 - val_loss: 1.4190 - learning_rate: 0.0010
# Epoch 6/50
# 179/181 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step - accuracy: 0.4069 - loss: 1.3990🐾 [Cat Val] Loss: 1.5900 | Accuracy: 0.2651
#
# Epoch 6: val_accuracy improved from 0.40920 to 0.41889, saving model to best_model.keras
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 64s 340ms/step - accuracy: 0.4070 - loss: 1.3990 - val_accuracy: 0.4189 - val_loss: 1.4024 - learning_rate: 0.0010
# Epoch 7/50
# 179/181 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.4099 - loss: 1.3879🐾 [Cat Val] Loss: 1.6336 | Accuracy: 0.2651
#
# Epoch 7: val_accuracy did not improve from 0.41889
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 64s 343ms/step - accuracy: 0.4099 - loss: 1.3879 - val_accuracy: 0.4019 - val_loss: 1.4044 - learning_rate: 0.0010
# Epoch 8/50
# 179/181 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.4155 - loss: 1.3885🐾 [Cat Val] Loss: 1.6042 | Accuracy: 0.2651
#
# Epoch 8: val_accuracy did not improve from 0.41889
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 64s 343ms/step - accuracy: 0.4156 - loss: 1.3885 - val_accuracy: 0.3959 - val_loss: 1.3793 - learning_rate: 0.0010
# Epoch 9/50
# 179/181 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step - accuracy: 0.4035 - loss: 1.3841🐾 [Cat Val] Loss: 1.6088 | Accuracy: 0.2651
#
# Epoch 9: val_accuracy did not improve from 0.41889
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 64s 340ms/step - accuracy: 0.4035 - loss: 1.3840 - val_accuracy: 0.4031 - val_loss: 1.3822 - learning_rate: 0.0010
# Epoch 10/50
# 179/181 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step - accuracy: 0.4149 - loss: 1.3750🐾 [Cat Val] Loss: 1.5405 | Accuracy: 0.2651
#
# Epoch 10: val_accuracy did not improve from 0.41889
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 64s 341ms/step - accuracy: 0.4149 - loss: 1.3752 - val_accuracy: 0.4007 - val_loss: 1.3778 - learning_rate: 0.0010
# Epoch 11/50
# 179/181 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.4180 - loss: 1.3807🐾 [Cat Val] Loss: 1.6063 | Accuracy: 0.2651
#
# Epoch 11: val_accuracy did not improve from 0.41889
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 65s 345ms/step - accuracy: 0.4180 - loss: 1.3806 - val_accuracy: 0.4056 - val_loss: 1.3744 - learning_rate: 0.0010
# Epoch 12/50
# 179/181 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step - accuracy: 0.4133 - loss: 1.3811🐾 [Cat Val] Loss: 1.5570 | Accuracy: 0.2651
#
# Epoch 12: val_accuracy did not improve from 0.41889
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 64s 339ms/step - accuracy: 0.4133 - loss: 1.3811 - val_accuracy: 0.4165 - val_loss: 1.3741 - learning_rate: 0.0010
# Epoch 13/50
# 179/181 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.4140 - loss: 1.3693🐾 [Cat Val] Loss: 1.5785 | Accuracy: 0.2530
#
# Epoch 13: val_accuracy did not improve from 0.41889
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 64s 342ms/step - accuracy: 0.4139 - loss: 1.3694 - val_accuracy: 0.4007 - val_loss: 1.3729 - learning_rate: 0.0010
# Epoch 14/50
# 179/181 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step - accuracy: 0.4312 - loss: 1.3639🐾 [Cat Val] Loss: 1.5728 | Accuracy: 0.2410
#
# Epoch 14: val_accuracy did not improve from 0.41889
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 64s 342ms/step - accuracy: 0.4310 - loss: 1.3639 - val_accuracy: 0.4189 - val_loss: 1.3631 - learning_rate: 0.0010
# Epoch 15/50
# 179/181 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.4124 - loss: 1.3711🐾 [Cat Val] Loss: 1.7989 | Accuracy: 0.2892
# 📦 Modelo mejorado guardado en best_model_cat.keras
#
# Epoch 15: val_accuracy did not improve from 0.41889
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 65s 343ms/step - accuracy: 0.4124 - loss: 1.3711 - val_accuracy: 0.4007 - val_loss: 1.3575 - learning_rate: 0.0010
# Epoch 16/50
# 179/181 ━━━━━━━━━━━━━━━━━━━━ 0s 337ms/step - accuracy: 0.4196 - loss: 1.3626🐾 [Cat Val] Loss: 1.6008 | Accuracy: 0.2651
#
# Epoch 16: val_accuracy did not improve from 0.41889
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 66s 350ms/step - accuracy: 0.4197 - loss: 1.3625 - val_accuracy: 0.4128 - val_loss: 1.3301 - learning_rate: 0.0010
# Epoch 17/50
# 179/181 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step - accuracy: 0.4284 - loss: 1.3586🐾 [Cat Val] Loss: 1.6958 | Accuracy: 0.2651
#
# Epoch 17: val_accuracy did not improve from 0.41889
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 65s 347ms/step - accuracy: 0.4283 - loss: 1.3587 - val_accuracy: 0.4128 - val_loss: 1.3363 - learning_rate: 0.0010
# Epoch 18/50
# 179/181 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step - accuracy: 0.4041 - loss: 1.3674🐾 [Cat Val] Loss: 1.6296 | Accuracy: 0.2651
#
# Epoch 18: val_accuracy did not improve from 0.41889
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 65s 344ms/step - accuracy: 0.4043 - loss: 1.3672 - val_accuracy: 0.4080 - val_loss: 1.3455 - learning_rate: 0.0010
# Epoch 19/50
# 179/181 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step - accuracy: 0.3917 - loss: 1.3746🐾 [Cat Val] Loss: 1.6361 | Accuracy: 0.2651
#
# Epoch 19: val_accuracy improved from 0.41889 to 0.42736, saving model to best_model.keras
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 65s 344ms/step - accuracy: 0.3921 - loss: 1.3743 - val_accuracy: 0.4274 - val_loss: 1.3252 - learning_rate: 0.0010
# Epoch 20/50
# 179/181 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step - accuracy: 0.4043 - loss: 1.3583🐾 [Cat Val] Loss: 1.7374 | Accuracy: 0.2651
#
# Epoch 20: val_accuracy did not improve from 0.42736
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 65s 344ms/step - accuracy: 0.4044 - loss: 1.3583 - val_accuracy: 0.4104 - val_loss: 1.3388 - learning_rate: 0.0010
# Epoch 21/50
# 179/181 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step - accuracy: 0.4306 - loss: 1.3409🐾 [Cat Val] Loss: 1.7023 | Accuracy: 0.2530
#
# Epoch 21: val_accuracy did not improve from 0.42736
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 65s 344ms/step - accuracy: 0.4305 - loss: 1.3411 - val_accuracy: 0.4237 - val_loss: 1.3058 - learning_rate: 0.0010
# Epoch 22/50
# 179/181 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.4107 - loss: 1.3720🐾 [Cat Val] Loss: 1.5533 | Accuracy: 0.2410
#
# Epoch 22: val_accuracy did not improve from 0.42736
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 64s 343ms/step - accuracy: 0.4106 - loss: 1.3725 - val_accuracy: 0.3947 - val_loss: 1.4202 - learning_rate: 0.0010
# Epoch 23/50
# 179/181 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step - accuracy: 0.3948 - loss: 1.4188🐾 [Cat Val] Loss: 1.6007 | Accuracy: 0.2651
#
# Epoch 23: val_accuracy did not improve from 0.42736
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 65s 346ms/step - accuracy: 0.3948 - loss: 1.4187 - val_accuracy: 0.3947 - val_loss: 1.4124 - learning_rate: 0.0010
# Epoch 24/50
# 179/181 ━━━━━━━━━━━━━━━━━━━━ 0s 341ms/step - accuracy: 0.3960 - loss: 1.4033🐾 [Cat Val] Loss: 1.6380 | Accuracy: 0.2771
#
# Epoch 24: val_accuracy did not improve from 0.42736
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 67s 355ms/step - accuracy: 0.3959 - loss: 1.4033 - val_accuracy: 0.3947 - val_loss: 1.4065 - learning_rate: 0.0010
# Epoch 25/50
# 179/181 ━━━━━━━━━━━━━━━━━━━━ 0s 341ms/step - accuracy: 0.3940 - loss: 1.4015🐾 [Cat Val] Loss: 1.6655 | Accuracy: 0.2771
#
# Epoch 25: val_accuracy did not improve from 0.42736
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 66s 354ms/step - accuracy: 0.3941 - loss: 1.4015 - val_accuracy: 0.3959 - val_loss: 1.4060 - learning_rate: 0.0010
# Epoch 26/50
# 179/181 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step - accuracy: 0.3968 - loss: 1.4052
# Epoch 26: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 🐾 [Cat Val] Loss: 1.6747 | Accuracy: 0.2651
#
# Epoch 26: val_accuracy did not improve from 0.42736
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 65s 345ms/step - accuracy: 0.3968 - loss: 1.4051 - val_accuracy: 0.3959 - val_loss: 1.4043 - learning_rate: 0.0010
# Epoch 27/50
# 179/181 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.3940 - loss: 1.3972🐾 [Cat Val] Loss: 1.7423 | Accuracy: 0.1928
#
# Epoch 27: val_accuracy did not improve from 0.42736
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 65s 343ms/step - accuracy: 0.3940 - loss: 1.3972 - val_accuracy: 0.3959 - val_loss: 1.4034 - learning_rate: 5.0000e-04
# Epoch 28/50
# 179/181 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.3996 - loss: 1.4032🐾 [Cat Val] Loss: 1.9886 | Accuracy: 0.2289
#
# Epoch 28: val_accuracy did not improve from 0.42736
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 65s 344ms/step - accuracy: 0.3995 - loss: 1.4031 - val_accuracy: 0.3947 - val_loss: 1.4013 - learning_rate: 5.0000e-04
# Epoch 29/50
# 179/181 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step - accuracy: 0.4104 - loss: 1.3800🐾 [Cat Val] Loss: 1.8666 | Accuracy: 0.1928
#
# Epoch 29: val_accuracy did not improve from 0.42736
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 65s 347ms/step - accuracy: 0.4102 - loss: 1.3803 - val_accuracy: 0.3959 - val_loss: 1.4020 - learning_rate: 5.0000e-04
# Epoch 30/50
# 179/181 ━━━━━━━━━━━━━━━━━━━━ 0s 336ms/step - accuracy: 0.3928 - loss: 1.4109🐾 [Cat Val] Loss: 1.8883 | Accuracy: 0.2048
#
# Epoch 30: val_accuracy did not improve from 0.42736
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 66s 349ms/step - accuracy: 0.3929 - loss: 1.4107 - val_accuracy: 0.3959 - val_loss: 1.4023 - learning_rate: 5.0000e-04
# Epoch 31/50
# 179/181 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step - accuracy: 0.3965 - loss: 1.3926
# Epoch 31: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 🐾 [Cat Val] Loss: 1.8126 | Accuracy: 0.2169
#
# Epoch 31: val_accuracy did not improve from 0.42736
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 65s 344ms/step - accuracy: 0.3965 - loss: 1.3927 - val_accuracy: 0.3971 - val_loss: 1.4024 - learning_rate: 5.0000e-04
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step
#               precision    recall  f1-score   support
#
#            0     0.4597    0.8354    0.5931       328
#            1     0.3333    0.0131    0.0252       153
#            2     0.3636    0.2642    0.3060       212
#            3     0.3000    0.1981    0.2386       106
#            4     0.0000    0.0000    0.0000        27
#
#     accuracy                         0.4274       826
#    macro avg     0.2913    0.2621    0.2326       826
# weighted avg     0.3761    0.4274    0.3493       826
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
#               precision    recall  f1-score   support
#
#            0     0.2778    0.9091    0.4255        22
#            1     0.0000    0.0000    0.0000        30
#            2     0.3636    0.2222    0.2759        18
#            3     0.0000    0.0000    0.0000        11
#            4     0.0000    0.0000    0.0000         2
#
#     accuracy                         0.2892        83
#    macro avg     0.1283    0.2263    0.1403        83
# weighted avg     0.1525    0.2892    0.1726        83
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
from tensorflow.keras.optimizers import Adam

regression = True
optimizar, steps = False, 4
tarea = 0


batch_size: int = 32
optimizer = Adam()
if optimizar:
    batch_size = 32//steps
    from tensorflow.keras import mixed_precision
    mixed_precision.set_global_policy('mixed_float16')
    from tensorflow.keras.optimizers import AdamW

    optimizer = AdamW(learning_rate=0.001,
                      gradient_accumulation_steps=steps)

num_classes = 5
if regression:
    num_classes = 1
elif tarea == 1:
    num_classes = 3
elif tarea > 1:
    num_classes = 2

loss = 'mean_squared_error' if regression else 'categorical_crossentropy'
metrics = ['mae'] if regression else ['accuracy']

# Generadores de datos (entrenamiento y validación)
train_gen = get_datagen(tarea=tarea, path=train_dir, regression=regression, BATCH_SIZE=batch_size, augment=True)
val_gen   = get_datagen(tarea=tarea, path=val_dir,  BATCH_SIZE=batch_size, regression=regression)
cat_gen = get_datagen(tarea=tarea, path=cat_dir, BATCH_SIZE=batch_size, regression=regression)


model = cnn_pequeno(num_classes, regression)
model.compile(optimizer='adam',
                  loss=loss,
                  metrics=metrics)
callbacks=get_callbacks(regression, cat_gen)
history = model.fit(
    train_gen,
    validation_data=val_gen,
    epochs=50,
    callbacks=callbacks
)

model.load_weights('best_model.keras')
# Obtén el diccionario original {etiqueta_str: índice_entero}
evaluate_model(model, regression=regression, generator=val_gen)
model.load_weights('best_model_cat.keras')
evaluate_model(model, regression=regression, generator=cat_gen)
# Out:
# Found 5778 validated image filenames.
# Found 826 validated image filenames.
# Found 83 validated image filenames.
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/50
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 179/181 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step - loss: 2.6657 - mae: 1.2859🐾 [Cat Val] MAE: 0.9640 | Accuracy: 0.3373
# 📦 Modelo mejorado guardado en best_model_cat.keras
#
# Epoch 1: val_loss improved from inf to 1.45953, saving model to best_model.keras
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 68s 350ms/step - loss: 2.6504 - mae: 1.2828 - val_loss: 1.4595 - val_mae: 1.0665 - learning_rate: 0.0010
# Epoch 2/50
# 179/181 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - loss: 1.4420 - mae: 1.0400🐾 [Cat Val] MAE: 1.0043 | Accuracy: 0.3373
#
# Epoch 2: val_loss improved from 1.45953 to 1.45761, saving model to best_model.keras
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 64s 340ms/step - loss: 1.4417 - mae: 1.0398 - val_loss: 1.4576 - val_mae: 1.0222 - learning_rate: 0.0010
# Epoch 3/50
# 179/181 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - loss: 1.4250 - mae: 1.0300🐾 [Cat Val] MAE: 1.0434 | Accuracy: 0.3373
#
# Epoch 3: val_loss did not improve from 1.45761
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 64s 340ms/step - loss: 1.4251 - mae: 1.0300 - val_loss: 1.6600 - val_mae: 1.0626 - learning_rate: 0.0010
# Epoch 4/50
# 179/181 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - loss: 1.4126 - mae: 1.0200🐾 [Cat Val] MAE: 0.9613 | Accuracy: 0.3133
#
# Epoch 4: val_loss improved from 1.45761 to 1.37596, saving model to best_model.keras
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 64s 340ms/step - loss: 1.4128 - mae: 1.0201 - val_loss: 1.3760 - val_mae: 1.0215 - learning_rate: 0.0010
# Epoch 5/50
# 179/181 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step - loss: 1.3964 - mae: 1.0116🐾 [Cat Val] MAE: 0.9339 | Accuracy: 0.3494
# 📦 Modelo mejorado guardado en best_model_cat.keras
#
# Epoch 5: val_loss improved from 1.37596 to 1.37223, saving model to best_model.keras
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 65s 343ms/step - loss: 1.3969 - mae: 1.0119 - val_loss: 1.3722 - val_mae: 1.0292 - learning_rate: 0.0010
# Epoch 6/50
# 179/181 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step - loss: 1.3782 - mae: 1.0079🐾 [Cat Val] MAE: 0.9445 | Accuracy: 0.3373
#
# Epoch 6: val_loss improved from 1.37223 to 1.35280, saving model to best_model.keras
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 64s 342ms/step - loss: 1.3783 - mae: 1.0080 - val_loss: 1.3528 - val_mae: 1.0190 - learning_rate: 0.0010
# Epoch 7/50
# 179/181 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - loss: 1.3825 - mae: 1.0138🐾 [Cat Val] MAE: 0.9484 | Accuracy: 0.3614
# 📦 Modelo mejorado guardado en best_model_cat.keras
#
# Epoch 7: val_loss did not improve from 1.35280
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 64s 341ms/step - loss: 1.3831 - mae: 1.0140 - val_loss: 1.3614 - val_mae: 1.0085 - learning_rate: 0.0010
# Epoch 8/50
# 179/181 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step - loss: 1.3811 - mae: 1.0175🐾 [Cat Val] MAE: 0.9357 | Accuracy: 0.3614
# 📦 Modelo mejorado guardado en best_model_cat.keras
#
# Epoch 8: val_loss improved from 1.35280 to 1.32910, saving model to best_model.keras
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 65s 344ms/step - loss: 1.3809 - mae: 1.0174 - val_loss: 1.3291 - val_mae: 1.0003 - learning_rate: 0.0010
# Epoch 9/50
# 179/181 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - loss: 1.4065 - mae: 1.0228🐾 [Cat Val] MAE: 0.9232 | Accuracy: 0.3133
#
# Epoch 9: val_loss did not improve from 1.32910
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 64s 341ms/step - loss: 1.4062 - mae: 1.0226 - val_loss: 1.3660 - val_mae: 1.0305 - learning_rate: 0.0010
# Epoch 10/50
# 179/181 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step - loss: 1.3546 - mae: 0.9963🐾 [Cat Val] MAE: 1.0693 | Accuracy: 0.3133
#
# Epoch 10: val_loss improved from 1.32910 to 1.29667, saving model to best_model.keras
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 65s 345ms/step - loss: 1.3552 - mae: 0.9964 - val_loss: 1.2967 - val_mae: 0.9878 - learning_rate: 0.0010
# Epoch 11/50
# 179/181 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step - loss: 1.3397 - mae: 0.9963🐾 [Cat Val] MAE: 0.9706 | Accuracy: 0.3494
#
# Epoch 11: val_loss improved from 1.29667 to 1.28057, saving model to best_model.keras
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 65s 345ms/step - loss: 1.3404 - mae: 0.9965 - val_loss: 1.2806 - val_mae: 0.9836 - learning_rate: 0.0010
# Epoch 12/50
# 180/181 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - loss: 1.3472 - mae: 0.9923🐾 [Cat Val] MAE: 0.9678 | Accuracy: 0.3494
#
# Epoch 12: val_loss did not improve from 1.28057
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 64s 342ms/step - loss: 1.3473 - mae: 0.9924 - val_loss: 1.4206 - val_mae: 1.0349 - learning_rate: 0.0010
# Epoch 13/50
# 179/181 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step - loss: 1.3474 - mae: 0.9968🐾 [Cat Val] MAE: 1.0110 | Accuracy: 0.3494
#
# Epoch 13: val_loss improved from 1.28057 to 1.25398, saving model to best_model.keras
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 64s 342ms/step - loss: 1.3476 - mae: 0.9969 - val_loss: 1.2540 - val_mae: 0.9641 - learning_rate: 0.0010
# Epoch 14/50
# 179/181 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step - loss: 1.3164 - mae: 0.9829🐾 [Cat Val] MAE: 1.2244 | Accuracy: 0.2530
#
# Epoch 14: val_loss did not improve from 1.25398
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 64s 343ms/step - loss: 1.3167 - mae: 0.9830 - val_loss: 1.3456 - val_mae: 0.9716 - learning_rate: 0.0010
# Epoch 15/50
# 179/181 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - loss: 1.3515 - mae: 0.9854🐾 [Cat Val] MAE: 0.9638 | Accuracy: 0.3012
#
# Epoch 15: val_loss did not improve from 1.25398
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 64s 340ms/step - loss: 1.3515 - mae: 0.9855 - val_loss: 1.4522 - val_mae: 1.0395 - learning_rate: 0.0010
# Epoch 16/50
# 179/181 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step - loss: 1.3554 - mae: 0.9938🐾 [Cat Val] MAE: 1.0406 | Accuracy: 0.3012
#
# Epoch 16: val_loss improved from 1.25398 to 1.21242, saving model to best_model.keras
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 65s 344ms/step - loss: 1.3553 - mae: 0.9938 - val_loss: 1.2124 - val_mae: 0.9462 - learning_rate: 0.0010
# Epoch 17/50
# 179/181 ━━━━━━━━━━━━━━━━━━━━ 0s 338ms/step - loss: 1.3194 - mae: 0.9813🐾 [Cat Val] MAE: 1.0069 | Accuracy: 0.3735
# 📦 Modelo mejorado guardado en best_model_cat.keras
#
# Epoch 17: val_loss improved from 1.21242 to 1.19599, saving model to best_model.keras
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 65s 348ms/step - loss: 1.3193 - mae: 0.9812 - val_loss: 1.1960 - val_mae: 0.9466 - learning_rate: 0.0010
# Epoch 18/50
# 179/181 ━━━━━━━━━━━━━━━━━━━━ 0s 337ms/step - loss: 1.3564 - mae: 0.9948🐾 [Cat Val] MAE: 1.0081 | Accuracy: 0.3373
#
# Epoch 18: val_loss did not improve from 1.19599
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 65s 347ms/step - loss: 1.3565 - mae: 0.9948 - val_loss: 1.3165 - val_mae: 0.9688 - learning_rate: 0.0010
# Epoch 19/50
# 179/181 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step - loss: 1.3679 - mae: 0.9914🐾 [Cat Val] MAE: 1.1447 | Accuracy: 0.3133
#
# Epoch 19: val_loss did not improve from 1.19599
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 65s 343ms/step - loss: 1.3678 - mae: 0.9913 - val_loss: 1.2870 - val_mae: 0.9627 - learning_rate: 0.0010
# Epoch 20/50
# 180/181 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - loss: 1.2955 - mae: 0.9724🐾 [Cat Val] MAE: 1.0188 | Accuracy: 0.3494
#
# Epoch 20: val_loss improved from 1.19599 to 1.17912, saving model to best_model.keras
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 64s 341ms/step - loss: 1.2956 - mae: 0.9724 - val_loss: 1.1791 - val_mae: 0.9437 - learning_rate: 0.0010
# Epoch 21/50
# 179/181 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - loss: 1.2994 - mae: 0.9674🐾 [Cat Val] MAE: 1.0379 | Accuracy: 0.3253
#
# Epoch 21: val_loss did not improve from 1.17912
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 64s 340ms/step - loss: 1.2992 - mae: 0.9673 - val_loss: 1.1964 - val_mae: 0.9407 - learning_rate: 0.0010
# Epoch 22/50
# 179/181 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step - loss: 1.3884 - mae: 0.9964🐾 [Cat Val] MAE: 1.0399 | Accuracy: 0.3494
#
# Epoch 22: val_loss improved from 1.17912 to 1.17655, saving model to best_model.keras
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 64s 342ms/step - loss: 1.3872 - mae: 0.9961 - val_loss: 1.1766 - val_mae: 0.9324 - learning_rate: 0.0010
# Epoch 23/50
# 179/181 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step - loss: 1.3381 - mae: 0.9850🐾 [Cat Val] MAE: 1.2428 | Accuracy: 0.3012
#
# Epoch 23: val_loss did not improve from 1.17655
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 66s 349ms/step - loss: 1.3384 - mae: 0.9849 - val_loss: 1.5336 - val_mae: 1.0115 - learning_rate: 0.0010
# Epoch 24/50
# 179/181 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step - loss: 1.2766 - mae: 0.9628🐾 [Cat Val] MAE: 1.0324 | Accuracy: 0.3494
#
# Epoch 24: val_loss did not improve from 1.17655
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 65s 344ms/step - loss: 1.2763 - mae: 0.9627 - val_loss: 1.3404 - val_mae: 0.9592 - learning_rate: 0.0010
# Epoch 25/50
# 179/181 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step - loss: 1.3950 - mae: 1.0023🐾 [Cat Val] MAE: 1.1306 | Accuracy: 0.3373
#
# Epoch 25: val_loss improved from 1.17655 to 1.16386, saving model to best_model.keras
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 64s 342ms/step - loss: 1.3935 - mae: 1.0018 - val_loss: 1.1639 - val_mae: 0.9358 - learning_rate: 0.0010
# Epoch 26/50
# 180/181 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step - loss: 1.2749 - mae: 0.9607🐾 [Cat Val] MAE: 1.2131 | Accuracy: 0.3614
#
# Epoch 26: val_loss did not improve from 1.16386
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 64s 338ms/step - loss: 1.2750 - mae: 0.9608 - val_loss: 1.1842 - val_mae: 0.9420 - learning_rate: 0.0010
# Epoch 27/50
# 179/181 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step - loss: 1.3223 - mae: 0.9824🐾 [Cat Val] MAE: 1.1822 | Accuracy: 0.3373
#
# Epoch 27: val_loss did not improve from 1.16386
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 63s 336ms/step - loss: 1.3217 - mae: 0.9821 - val_loss: 1.1820 - val_mae: 0.9362 - learning_rate: 0.0010
# Epoch 28/50
# 179/181 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - loss: 1.2100 - mae: 0.9343🐾 [Cat Val] MAE: 1.2053 | Accuracy: 0.3373
#
# Epoch 28: val_loss did not improve from 1.16386
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 64s 341ms/step - loss: 1.2107 - mae: 0.9346 - val_loss: 1.1658 - val_mae: 0.9300 - learning_rate: 0.0010
# Epoch 29/50
# 179/181 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step - loss: 1.2618 - mae: 0.9568🐾 [Cat Val] MAE: 1.0909 | Accuracy: 0.3494
#
# Epoch 29: val_loss improved from 1.16386 to 1.14676, saving model to best_model.keras
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 63s 336ms/step - loss: 1.2620 - mae: 0.9569 - val_loss: 1.1468 - val_mae: 0.9258 - learning_rate: 0.0010
# Epoch 30/50
# 179/181 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step - loss: 1.2744 - mae: 0.9656🐾 [Cat Val] MAE: 1.0870 | Accuracy: 0.3373
#
# Epoch 30: val_loss did not improve from 1.14676
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 64s 338ms/step - loss: 1.2743 - mae: 0.9655 - val_loss: 1.2136 - val_mae: 0.9384 - learning_rate: 0.0010
# Epoch 31/50
# 179/181 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step - loss: 1.2225 - mae: 0.9402🐾 [Cat Val] MAE: 1.0827 | Accuracy: 0.3253
#
# Epoch 31: val_loss did not improve from 1.14676
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 64s 338ms/step - loss: 1.2228 - mae: 0.9403 - val_loss: 1.2817 - val_mae: 0.9452 - learning_rate: 0.0010
# Epoch 32/50
# 179/181 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step - loss: 1.2967 - mae: 0.9758🐾 [Cat Val] MAE: 1.1978 | Accuracy: 0.3373
#
# Epoch 32: val_loss did not improve from 1.14676
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 63s 337ms/step - loss: 1.2961 - mae: 0.9754 - val_loss: 1.1867 - val_mae: 0.9291 - learning_rate: 0.0010
# Epoch 33/50
# 179/181 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step - loss: 1.2524 - mae: 0.9563🐾 [Cat Val] MAE: 1.2643 | Accuracy: 0.3253
#
# Epoch 33: val_loss did not improve from 1.14676
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 63s 334ms/step - loss: 1.2524 - mae: 0.9562 - val_loss: 1.1519 - val_mae: 0.9182 - learning_rate: 0.0010
# Epoch 34/50
# 180/181 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - loss: 1.3038 - mae: 0.9713
# Epoch 34: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 🐾 [Cat Val] MAE: 1.1505 | Accuracy: 0.3253
#
# Epoch 34: val_loss did not improve from 1.14676
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 63s 334ms/step - loss: 1.3034 - mae: 0.9711 - val_loss: 1.1478 - val_mae: 0.9284 - learning_rate: 0.0010
# Epoch 35/50
# 180/181 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - loss: 1.1945 - mae: 0.9308🐾 [Cat Val] MAE: 1.0868 | Accuracy: 0.3373
#
# Epoch 35: val_loss did not improve from 1.14676
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 64s 343ms/step - loss: 1.1947 - mae: 0.9309 - val_loss: 1.1600 - val_mae: 0.9302 - learning_rate: 5.0000e-04
# Epoch 36/50
# 179/181 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - loss: 1.2540 - mae: 0.9515🐾 [Cat Val] MAE: 1.1428 | Accuracy: 0.3133
#
# Epoch 36: val_loss improved from 1.14676 to 1.13292, saving model to best_model.keras
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 64s 341ms/step - loss: 1.2534 - mae: 0.9513 - val_loss: 1.1329 - val_mae: 0.9179 - learning_rate: 5.0000e-04
# Epoch 37/50
# 179/181 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step - loss: 1.2658 - mae: 0.9572🐾 [Cat Val] MAE: 1.0469 | Accuracy: 0.3133
#
# Epoch 37: val_loss did not improve from 1.13292
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 64s 339ms/step - loss: 1.2655 - mae: 0.9571 - val_loss: 1.1632 - val_mae: 0.9372 - learning_rate: 5.0000e-04
# Epoch 38/50
# 179/181 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step - loss: 1.1888 - mae: 0.9327🐾 [Cat Val] MAE: 1.1073 | Accuracy: 0.3253
#
# Epoch 38: val_loss improved from 1.13292 to 1.10260, saving model to best_model.keras
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 63s 336ms/step - loss: 1.1893 - mae: 0.9329 - val_loss: 1.1026 - val_mae: 0.9042 - learning_rate: 5.0000e-04
# Epoch 39/50
# 180/181 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step - loss: 1.1954 - mae: 0.9268🐾 [Cat Val] MAE: 1.0596 | Accuracy: 0.3133
#
# Epoch 39: val_loss did not improve from 1.10260
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 63s 336ms/step - loss: 1.1955 - mae: 0.9268 - val_loss: 1.2382 - val_mae: 0.9408 - learning_rate: 5.0000e-04
# Epoch 40/50
# 179/181 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step - loss: 1.2287 - mae: 0.9491🐾 [Cat Val] MAE: 1.2477 | Accuracy: 0.3373
#
# Epoch 40: val_loss did not improve from 1.10260
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 64s 342ms/step - loss: 1.2285 - mae: 0.9489 - val_loss: 1.1539 - val_mae: 0.9195 - learning_rate: 5.0000e-04
# Epoch 41/50
# 179/181 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - loss: 1.1846 - mae: 0.9267🐾 [Cat Val] MAE: 1.0635 | Accuracy: 0.3253
#
# Epoch 41: val_loss did not improve from 1.10260
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 64s 341ms/step - loss: 1.1849 - mae: 0.9268 - val_loss: 1.1150 - val_mae: 0.9165 - learning_rate: 5.0000e-04
# Epoch 42/50
# 179/181 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step - loss: 1.2372 - mae: 0.9553🐾 [Cat Val] MAE: 1.2632 | Accuracy: 0.3253
#
# Epoch 42: val_loss improved from 1.10260 to 1.10097, saving model to best_model.keras
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 64s 338ms/step - loss: 1.2367 - mae: 0.9550 - val_loss: 1.1010 - val_mae: 0.8990 - learning_rate: 5.0000e-04
# Epoch 43/50
# 179/181 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step - loss: 1.2104 - mae: 0.9383🐾 [Cat Val] MAE: 1.1200 | Accuracy: 0.3012
#
# Epoch 43: val_loss did not improve from 1.10097
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 64s 338ms/step - loss: 1.2103 - mae: 0.9383 - val_loss: 1.2056 - val_mae: 0.9240 - learning_rate: 5.0000e-04
# Epoch 44/50
# 179/181 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step - loss: 1.2339 - mae: 0.9458🐾 [Cat Val] MAE: 1.1465 | Accuracy: 0.3253
#
# Epoch 44: val_loss did not improve from 1.10097
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 64s 343ms/step - loss: 1.2334 - mae: 0.9456 - val_loss: 1.1229 - val_mae: 0.9059 - learning_rate: 5.0000e-04
# Epoch 45/50
# 179/181 ━━━━━━━━━━━━━━━━━━━━ 0s 337ms/step - loss: 1.1983 - mae: 0.9279🐾 [Cat Val] MAE: 1.1205 | Accuracy: 0.3373
#
# Epoch 45: val_loss did not improve from 1.10097
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 65s 345ms/step - loss: 1.1983 - mae: 0.9279 - val_loss: 1.1778 - val_mae: 0.9298 - learning_rate: 5.0000e-04
# Epoch 46/50
# 179/181 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step - loss: 1.2154 - mae: 0.9394🐾 [Cat Val] MAE: 1.1696 | Accuracy: 0.3373
#
# Epoch 46: val_loss did not improve from 1.10097
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 64s 342ms/step - loss: 1.2158 - mae: 0.9395 - val_loss: 1.1243 - val_mae: 0.9146 - learning_rate: 5.0000e-04
# Epoch 47/50
# 179/181 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - loss: 1.2298 - mae: 0.9491
# Epoch 47: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 🐾 [Cat Val] MAE: 1.0672 | Accuracy: 0.3494
#
# Epoch 47: val_loss did not improve from 1.10097
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 64s 341ms/step - loss: 1.2296 - mae: 0.9490 - val_loss: 1.1226 - val_mae: 0.9194 - learning_rate: 5.0000e-04
# Epoch 48/50
# 179/181 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step - loss: 1.1746 - mae: 0.9252🐾 [Cat Val] MAE: 1.2237 | Accuracy: 0.3253
#
# Epoch 48: val_loss did not improve from 1.10097
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 64s 337ms/step - loss: 1.1747 - mae: 0.9252 - val_loss: 1.1338 - val_mae: 0.9001 - learning_rate: 2.5000e-04
# Epoch 49/50
# 179/181 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step - loss: 1.1790 - mae: 0.9294🐾 [Cat Val] MAE: 1.1350 | Accuracy: 0.3012
#
# Epoch 49: val_loss improved from 1.10097 to 1.09891, saving model to best_model.keras
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 63s 336ms/step - loss: 1.1790 - mae: 0.9293 - val_loss: 1.0989 - val_mae: 0.8977 - learning_rate: 2.5000e-04
# Epoch 50/50
# 179/181 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - loss: 1.1868 - mae: 0.9256🐾 [Cat Val] MAE: 1.1072 | Accuracy: 0.3133
#
# Epoch 50: val_loss did not improve from 1.09891
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 64s 340ms/step - loss: 1.1868 - mae: 0.9257 - val_loss: 1.2261 - val_mae: 0.9311 - learning_rate: 2.5000e-04
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step
# Mean Absolute Error (MAE): 0.8977
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#         KL 0     0.5455    0.0915    0.1567       328
#         KL 1     0.1965    0.8039    0.3158       153
#         KL 2     0.2993    0.1934    0.2350       212
#         KL 3     0.2500    0.0189    0.0351       106
#         KL 4     0.0000    0.0000    0.0000        27
#
#     accuracy                         0.2373       826
#    macro avg     0.2582    0.2215    0.1485       826
# weighted avg     0.3619    0.2373    0.1855       826
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# Mean Absolute Error (MAE): 1.0069
#               precision    recall  f1-score   support
#
#         KL 0     0.2941    0.2273    0.2564        22
#         KL 1     0.4400    0.7333    0.5500        30
#         KL 2     0.2500    0.2222    0.2353        18
#         KL 3     0.0000    0.0000    0.0000        11
#         KL 4     0.0000    0.0000    0.0000         2
#
#     accuracy                         0.3735        83
#    macro avg     0.1968    0.2366    0.2083        83
# weighted avg     0.2912    0.3735    0.3178        83
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
print("=== Historial de entrenamiento ===")
for metric_name, metric_values in history.history.items():
    print(f"{metric_name}: {metric_values}")

# 2. (Opcional) Graficar las curvas de entrenamiento y validación
import matplotlib.pyplot as plt

# Determinar qué métricas hay (loss, mae o accuracy, val_loss, val_mae o val_accuracy)
keys = list(history.history.keys())

# Para cada métrica de entrenamiento sin prefijo 'val_'
for k in keys:
    if not k.startswith('val_'):
        plt.figure()
        plt.plot(history.history[k], marker='o', label=f'train_{k}')
        val_key = f'val_{k}'
        if val_key in history.history:
            plt.plot(history.history[val_key], marker='s', label=f'val_{k}')
        plt.title(f'Curva de {k}')
        plt.xlabel('Época')
        plt.ylabel(k)
        plt.legend()
        plt.grid(True)
        plt.show()
# Out:
# === Historial de entrenamiento ===
# loss: [1.7362852096557617, 1.424218773841858, 1.4345169067382812, 1.422670602798462, 1.4298003911972046, 1.3834995031356812, 1.4183005094528198, 1.3695969581604004, 1.3836719989776611, 1.3889946937561035, 1.383470058441162, 1.3606382608413696, 1.3624604940414429, 1.3322833776474, 1.3526113033294678, 1.347941279411316, 1.3161853551864624, 1.3671679496765137, 1.3631713390350342, 1.3031690120697021, 1.2855093479156494, 1.3168282508850098, 1.3555455207824707, 1.2569986581802368, 1.305405616760254, 1.2927101850509644, 1.2886631488800049, 1.251625418663025, 1.278468370437622, 1.2707699537277222, 1.2415692806243896, 1.2593989372253418, 1.2515977621078491, 1.2718958854675293, 1.2162666320800781, 1.2176252603530884, 1.2446908950805664, 1.2205833196640015, 1.200707197189331, 1.213930606842041, 1.2005934715270996, 1.2048468589782715, 1.2071006298065186, 1.2066495418548584, 1.1978927850723267, 1.2375363111495972, 1.2167540788650513, 1.1780903339385986, 1.1798423528671265, 1.1890857219696045]
# mae: [1.0982295274734497, 1.0307170152664185, 1.0302098989486694, 1.0263818502426147, 1.0271167755126953, 1.0125045776367188, 1.021856427192688, 1.0099397897720337, 1.0130544900894165, 1.0068038702011108, 1.008583903312683, 0.9993112683296204, 0.9999269247055054, 0.9895882606506348, 0.9909555315971375, 0.9911375641822815, 0.9788665771484375, 0.9924055337905884, 0.9875971674919128, 0.9713342785835266, 0.9648982286453247, 0.973299503326416, 0.9846882820129395, 0.9555782079696655, 0.9725534319877625, 0.9675148725509644, 0.9661089181900024, 0.9530792236328125, 0.9610230922698975, 0.9590029716491699, 0.9472229480743408, 0.9568554759025574, 0.9509847164154053, 0.9602820873260498, 0.941071629524231, 0.940157413482666, 0.9497784376144409, 0.9436923265457153, 0.9313328266143799, 0.9405527114868164, 0.9329537749290466, 0.9364467859268188, 0.9380428791046143, 0.9340969920158386, 0.9312291741371155, 0.9457273483276367, 0.9416407346725464, 0.9259907603263855, 0.9259654879570007, 0.9277776479721069]
# val_loss: [1.4595261812210083, 1.4576088190078735, 1.6599700450897217, 1.3759609460830688, 1.3722310066223145, 1.3527973890304565, 1.3614336252212524, 1.3291047811508179, 1.3660465478897095, 1.2966657876968384, 1.2805651426315308, 1.4206374883651733, 1.2539796829223633, 1.3455523252487183, 1.4521918296813965, 1.2124229669570923, 1.1959930658340454, 1.3165178298950195, 1.287023901939392, 1.1791163682937622, 1.1964423656463623, 1.176554799079895, 1.5335841178894043, 1.3403970003128052, 1.1638623476028442, 1.1842178106307983, 1.1819674968719482, 1.1658340692520142, 1.1467602252960205, 1.2136155366897583, 1.2816895246505737, 1.1867187023162842, 1.1518833637237549, 1.1478081941604614, 1.1599856615066528, 1.1329232454299927, 1.1631810665130615, 1.1026041507720947, 1.2381720542907715, 1.153914451599121, 1.1150481700897217, 1.100970983505249, 1.2056114673614502, 1.1229461431503296, 1.1778225898742676, 1.1243135929107666, 1.1225848197937012, 1.1337823867797852, 1.0989118814468384, 1.226120948791504]
# val_mae: [1.0664665699005127, 1.0222052335739136, 1.0625756978988647, 1.0214506387710571, 1.02922523021698, 1.0190175771713257, 1.008517861366272, 1.0003011226654053, 1.0305445194244385, 0.9877949357032776, 0.9836478233337402, 1.0349258184432983, 0.964121401309967, 0.9716322422027588, 1.0395209789276123, 0.9462169408798218, 0.9465778470039368, 0.9688012003898621, 0.9627495408058167, 0.9436559677124023, 0.9406902194023132, 0.9323558807373047, 1.0114829540252686, 0.9592026472091675, 0.9358143210411072, 0.9420045018196106, 0.9361698031425476, 0.9299710988998413, 0.9258176684379578, 0.938423752784729, 0.9451508522033691, 0.9290957450866699, 0.9182246923446655, 0.9283523559570312, 0.9301896095275879, 0.9178709387779236, 0.9371577501296997, 0.9042490720748901, 0.9408005475997925, 0.9195024371147156, 0.9164770245552063, 0.8989794850349426, 0.9239729046821594, 0.9059072732925415, 0.9298280477523804, 0.9146193265914917, 0.9194083213806152, 0.9001421332359314, 0.8977025151252747, 0.9310922026634216]
# learning_rate: [0.0010000000474974513, 0.0010000000474974513, 0.0010000000474974513, 0.0010000000474974513, 0.0010000000474974513, 0.0010000000474974513, 0.0010000000474974513, 0.0010000000474974513, 0.0010000000474974513, 0.0010000000474974513, 0.0010000000474974513, 0.0010000000474974513, 0.0010000000474974513, 0.0010000000474974513, 0.0010000000474974513, 0.0010000000474974513, 0.0010000000474974513, 0.0010000000474974513, 0.0010000000474974513, 0.0010000000474974513, 0.0010000000474974513, 0.0010000000474974513, 0.0010000000474974513, 0.0010000000474974513, 0.0010000000474974513, 0.0010000000474974513, 0.0010000000474974513, 0.0010000000474974513, 0.0010000000474974513, 0.0010000000474974513, 0.0010000000474974513, 0.0010000000474974513, 0.0010000000474974513, 0.0010000000474974513, 0.0005000000237487257, 0.0005000000237487257, 0.0005000000237487257, 0.0005000000237487257, 0.0005000000237487257, 0.0005000000237487257, 0.0005000000237487257, 0.0005000000237487257, 0.0005000000237487257, 0.0005000000237487257, 0.0005000000237487257, 0.0005000000237487257, 0.0005000000237487257, 0.0002500000118743628, 0.0002500000118743628, 0.0002500000118743628]

# %%
cat_callback = callbacks[2]

print("=== Historial de validación de gatos ===")
for m in cat_callback.epoch_metrics:
    epoch = m['epoch']
    loss = m['val_cat_loss']
    acc  = m['val_cat_accuracy']
    print(f"Época {epoch}: Loss/MAE = {loss:.4f}, Accuracy = {acc:.4f}")

# (Opcional) Graficar la evolución de loss y accuracy de validación de gatos
import matplotlib.pyplot as plt

epochs = [m['epoch'] for m in cat_callback.epoch_metrics]
losses = [m['val_cat_loss'] for m in cat_callback.epoch_metrics]
accs   = [m['val_cat_accuracy'] for m in cat_callback.epoch_metrics]

plt.figure()
plt.plot(epochs, losses, marker='o', label='val_cat_loss/MAE')
plt.plot(epochs, accs,   marker='s', label='val_cat_accuracy')
plt.title('Curvas de validación (CatValidationCallback)')
plt.xlabel('Época')
plt.ylabel('Valor')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# === Historial de validación de gatos ===
# Época 1: Loss/MAE = 0.9640, Accuracy = 0.3373
# Época 2: Loss/MAE = 1.0043, Accuracy = 0.3373
# Época 3: Loss/MAE = 1.0434, Accuracy = 0.3373
# Época 4: Loss/MAE = 0.9613, Accuracy = 0.3133
# Época 5: Loss/MAE = 0.9339, Accuracy = 0.3494
# Época 6: Loss/MAE = 0.9445, Accuracy = 0.3373
# Época 7: Loss/MAE = 0.9484, Accuracy = 0.3614
# Época 8: Loss/MAE = 0.9357, Accuracy = 0.3614
# Época 9: Loss/MAE = 0.9232, Accuracy = 0.3133
# Época 10: Loss/MAE = 1.0693, Accuracy = 0.3133
# Época 11: Loss/MAE = 0.9706, Accuracy = 0.3494
# Época 12: Loss/MAE = 0.9678, Accuracy = 0.3494
# Época 13: Loss/MAE = 1.0110, Accuracy = 0.3494
# Época 14: Loss/MAE = 1.2244, Accuracy = 0.2530
# Época 15: Loss/MAE = 0.9638, Accuracy = 0.3012
# Época 16: Loss/MAE = 1.0406, Accuracy = 0.3012
# Época 17: Loss/MAE = 1.0069, Accuracy = 0.3735
# Época 18: Loss/MAE = 1.0081, Accuracy = 0.3373
# Época 19: Loss/MAE = 1.1447, Accuracy = 0.3133
# Época 20: Loss/MAE = 1.0188, Accuracy = 0.3494
# Época 21: Loss/MAE = 1.0379, Accuracy = 0.3253
# Época 22: Loss/MAE = 1.0399, Accuracy = 0.3494
# Época 23: Loss/MAE = 1.2428, Accuracy = 0.3012
# Época 24: Loss/MAE = 1.0324, Accuracy = 0.3494
# Época 25: Loss/MAE = 1.1306, Accuracy = 0.3373
# Época 26: Loss/MAE = 1.2131, Accuracy = 0.3614
# Época 27: Loss/MAE = 1.1822, Accuracy = 0.3373
# Época 28: Loss/MAE = 1.2053, Accuracy = 0.3373
# Época 29: Loss/MAE = 1.0909, Accuracy = 0.3494
# Época 30: Loss/MAE = 1.0870, Accuracy = 0.3373
# Época 31: Loss/MAE = 1.0827, Accuracy = 0.3253
# Época 32: Loss/MAE = 1.1978, Accuracy = 0.3373
# Época 33: Loss/MAE = 1.2643, Accuracy = 0.3253
# Época 34: Loss/MAE = 1.1505, Accuracy = 0.3253
# Época 35: Loss/MAE = 1.0868, Accuracy = 0.3373
# Época 36: Loss/MAE = 1.1428, Accuracy = 0.3133
# Época 37: Loss/MAE = 1.0469, Accuracy = 0.3133
# Época 38: Loss/MAE = 1.1073, Accuracy = 0.3253
# Época 39: Loss/MAE = 1.0596, Accuracy = 0.3133
# Época 40: Loss/MAE = 1.2477, Accuracy = 0.3373
# Época 41: Loss/MAE = 1.0635, Accuracy = 0.3253
# Época 42: Loss/MAE = 1.2632, Accuracy = 0.3253
# Época 43: Loss/MAE = 1.1200, Accuracy = 0.3012
# Época 44: Loss/MAE = 1.1465, Accuracy = 0.3253
# Época 45: Loss/MAE = 1.1205, Accuracy = 0.3373
# Época 46: Loss/MAE = 1.1696, Accuracy = 0.3373
# Época 47: Loss/MAE = 1.0672, Accuracy = 0.3494
# Época 48: Loss/MAE = 1.2237, Accuracy = 0.3253
# Época 49: Loss/MAE = 1.1350, Accuracy = 0.3012
# Época 50: Loss/MAE = 1.1072, Accuracy = 0.3133

# %% [markdown]
# # Anterior

# %% [markdown]
# ## Exploración del dataset de artrosis de rodilla
#
# - **Total de imágenes:** 9 786
#
# | Partición      | Imágenes | Porcentaje |
# |---------------|---------:|-----------:|
# | **Train**      | 5 778    | 59.04 %    |
# | **Validation** |   826    |  8.44 %    |
# | **Test**       | 1 656    | 16.92 %    |
# | **AutoTest**   | 1 526    | 15.59 %    |
#
#
# ### Distribución de clases en `Train`
#
# |  Clase  | Índice | Imágenes | Porcentaje |
# |---------|-------:|---------:|-----------:|
# | Sin     |      0 |    2 286 |     39.56 % |
# | Ligera  |      1 |    1 046 |     18.10 % |
# | Leve    |      2 |    1 516 |     26.24 % |
# | Moderada|      3 |      757 |     13.10 % |
# | Severa  |      4 |      173 |      2.99 % |
