# %% [markdown]
# # Github & Imports

# %%
# !git clone https://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@github.com/Tempus23/Radiography_TFG.git
# Out:
# Cloning into 'Radiography_TFG'...
# remote: Enumerating objects: 2409, done.
# remote: Counting objects: 100% (8/8), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 2409 (delta 1), reused 1 (delta 1), pack-reused 2401 (from 1)
# Receiving objects: 100% (2409/2409), 71.08 MiB | 50.93 MiB/s, done.
# Resolving deltas: 100% (440/440), done.

# %%
import os
import sys
os.chdir("Radiography_TFG")
sys.path.append("Radiography_TFG")

# %%
# !pip install -q lightning
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt

import torch
from torchvision import datasets, transforms
from torch.utils.data import DataLoader

from tensorflow.keras.preprocessing.image import ImageDataGenerator # type: ignore

from src.config import *
from src.data import *
from src.models.efficientnet import EfficientNetB5Custom, EfficientNetB0, EfficientNetB5, EfficientNetB7, EfficientNetB4
from src.models.resnet18 import ResNet18_v2
from src.models.ensembling import Ensembling
from src.models.simpleCNN import SimpleCNN
from src.utils import *
from src.data import OriginalOAIDataset, DatasetExperiment1
from src.train import train, train_model, test_model
from src.trainers.classification import Classification, ClassificationAdamax
import wandb
# Set random seeds
torch.manual_seed(RANDOM_SEED)
np.random.seed(RANDOM_SEED)
torch.cuda.manual_seed(RANDOM_SEED)

# %% [markdown]
# # Training

# %%
BATCH_SIZE = 30
LEARNING_RATE = 0.001
FACTOR = 0.1
L1 = 0.00
L2 = 0.00
PATIENCE = 5
BETAS=(0.9, 0.999)
LOCAL = False
# Regularización L1 y L2
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# wandb 254f72e7bdeec44797ba1b2a91ebbc63900b89f4
# /kaggle/input/aug-oai-capitulo3/augmented_oai
DATASET_PATH = '../../input/aug-oai-capitulo3/augmented_oai'
DATASET_PATH = '../../input/original-oai/split_oai'
train_dataset = DatasetExperiment1('train', batch_size=BATCH_SIZE, local=LOCAL,grey=False, path = DATASET_PATH)
val_dataset = DatasetExperiment1('val', batch_size=BATCH_SIZE, local=LOCAL, grey=False, path = DATASET_PATH)
#model =ResNet18_v2(n_classes = 5)
model = Ensembling(num_classes = 5, pretrained=True)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
trainer = Classification(model, device, L1=L1, L2=L2, lr=LEARNING_RATE, factor=FACTOR, patience=PATIENCE, betas=BETAS)
wandb.login(key="254f72e7bdeec44797ba1b2a91ebbc63900b89f4")
# Out:
# Downloading: "https://download.pytorch.org/models/efficientnet_b0_rwightman-7f5810bc.pth" to /root/.cache/torch/hub/checkpoints/efficientnet_b0_rwightman-7f5810bc.pth
# 100%|██████████| 20.5M/20.5M [00:00<00:00, 111MB/s]
# Downloading: "https://download.pytorch.org/models/efficientnet_b4_rwightman-23ab8bcd.pth" to /root/.cache/torch/hub/checkpoints/efficientnet_b4_rwightman-23ab8bcd.pth
# 100%|██████████| 74.5M/74.5M [00:00<00:00, 160MB/s]
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: chermar (chermar-universitat-polit-cnica-de-val-ncia). Use `wandb login --relogin` to force relogin
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %%
train_model(model, trainer, train_dataset, val_dataset, epochs=50, device=device, save_model = "_", name="_augmentedOAI", wdb=not LOCAL, local=False, early_stopping_patience=10)
# Out:
# wandb: Tracking run with wandb version 0.19.1
# wandb: Run data is saved locally in /kaggle/working/Radiography_TFG/wandb/run-20250317_151347-fwtj73o3
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run Ensembling__augmentedOAI
# wandb: ⭐️ View project at https://wandb.ai/chermar-universitat-polit-cnica-de-val-ncia/oai-knee-cartilage-segmentation
# wandb: 🚀 View run at https://wandb.ai/chermar-universitat-polit-cnica-de-val-ncia/oai-knee-cartilage-segmentation/runs/fwtj73o3
# Training Epoch [1/50]: 100%|███████████████████████████████████████████████████████████████████████████| 245/245 [04:13<00:00,  1.03s/it, AUC=0.713, acc=0.446, complete_loss=1.3348, train_loss=1.3348]
# Validation Epoch [1/50]:   0%|                                                                                                                                                   | 0/26 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/torchmetrics/utilities/prints.py:43: UserWarning: No positive samples in targets, true positive value should be meaningless. Returning zero tensor in true positive score
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation Epoch [1/50]: 100%|███████████████████████████████████████████████████████████████████████████████████████████████| 26/26 [00:15<00:00,  1.67it/s, AUC=0.841, acc=0.596, val_loss=1.02160089]
# Training Epoch [2/50]: 100%|████████████████████████████████████████████████████████████████████████████| 245/245 [03:35<00:00,  1.14it/s, AUC=0.836, acc=0.59, complete_loss=1.0053, train_loss=1.0053]
# Validation Epoch [2/50]: 100%|███████████████████████████████████████████████████████████████████████████████████████████████| 26/26 [00:11<00:00,  2.24it/s, AUC=0.877, acc=0.645, val_loss=0.88084355]
# Training Epoch [3/50]: 100%|████████████████████████████████████████████████████████████████████████████| 245/245 [03:27<00:00,  1.18it/s, AUC=0.87, acc=0.638, complete_loss=0.8764, train_loss=0.8764]
# Validation Epoch [3/50]: 100%|███████████████████████████████████████████████████████████████████████████████████████████████| 26/26 [00:11<00:00,  2.27it/s, AUC=0.897, acc=0.679, val_loss=0.79498130]
# Training Epoch [4/50]: 100%|███████████████████████████████████████████████████████████████████████████| 245/245 [03:31<00:00,  1.16it/s, AUC=0.898, acc=0.678, complete_loss=0.7723, train_loss=0.7723]
# Validation Epoch [4/50]: 100%|███████████████████████████████████████████████████████████████████████████████████████████████| 26/26 [00:11<00:00,  2.25it/s, AUC=0.876, acc=0.637, val_loss=0.88246665]
# Training Epoch [5/50]: 100%|████████████████████████████████████████████████████████████████████████████| 245/245 [03:34<00:00,  1.14it/s, AUC=0.92, acc=0.722, complete_loss=0.6814, train_loss=0.6814]
# Validation Epoch [5/50]: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████| 26/26 [00:12<00:00,  2.11it/s, AUC=0.8, acc=0.555, val_loss=1.33159387]
# Training Epoch [6/50]: 100%|███████████████████████████████████████████████████████████████████████████| 245/245 [03:40<00:00,  1.11it/s, AUC=0.936, acc=0.754, complete_loss=0.6019, train_loss=0.6019]
# Validation Epoch [6/50]: 100%|███████████████████████████████████████████████████████████████████████████████████████████████| 26/26 [00:12<00:00,  2.15it/s, AUC=0.873, acc=0.594, val_loss=0.94758382]
# Training Epoch [7/50]: 100%|███████████████████████████████████████████████████████████████████████████| 245/245 [03:34<00:00,  1.14it/s, AUC=0.953, acc=0.796, complete_loss=0.5149, train_loss=0.5149]
# Validation Epoch [7/50]: 100%|███████████████████████████████████████████████████████████████████████████████████████████████| 26/26 [00:11<00:00,  2.27it/s, AUC=0.911, acc=0.696, val_loss=0.80518107]
# Training Epoch [8/50]: 100%|███████████████████████████████████████████████████████████████████████████| 245/245 [03:34<00:00,  1.14it/s, AUC=0.966, acc=0.835, complete_loss=0.4369, train_loss=0.4369]
# Validation Epoch [8/50]: 100%|████████████████████████████████████████████████████████████████████████████████████████████████| 26/26 [00:12<00:00,  2.11it/s, AUC=0.896, acc=0.64, val_loss=0.87693259]
# Training Epoch [9/50]: 100%|███████████████████████████████████████████████████████████████████████████| 245/245 [03:39<00:00,  1.12it/s, AUC=0.971, acc=0.848, complete_loss=0.4075, train_loss=0.4075]
# Validation Epoch [9/50]: 100%|███████████████████████████████████████████████████████████████████████████████████████████████| 26/26 [00:12<00:00,  2.07it/s, AUC=0.899, acc=0.664, val_loss=0.88665076]
# Training Epoch [10/50]: 100%|███████████████████████████████████████████████████████████████████████████| 245/245 [03:38<00:00,  1.12it/s, AUC=0.991, acc=0.92, complete_loss=0.2375, train_loss=0.2375]
# Validation Epoch [10/50]: 100%|██████████████████████████████████████████████████████████████████████████████████████████████| 26/26 [00:12<00:00,  2.09it/s, AUC=0.912, acc=0.697, val_loss=0.82441823]
# Training Epoch [11/50]: 100%|██████████████████████████████████████████████████████████████████████████| 245/245 [03:37<00:00,  1.13it/s, AUC=0.994, acc=0.938, complete_loss=0.1856, train_loss=0.1856]
# Validation Epoch [11/50]: 100%|██████████████████████████████████████████████████████████████████████████████████████████████| 26/26 [00:11<00:00,  2.20it/s, AUC=0.913, acc=0.706, val_loss=0.85416630]
# Training Epoch [12/50]: 100%|██████████████████████████████████████████████████████████████████████████| 245/245 [03:31<00:00,  1.16it/s, AUC=0.997, acc=0.957, complete_loss=0.1360, train_loss=0.1360]
# Validation Epoch [12/50]: 100%|██████████████████████████████████████████████████████████████████████████████████████████████| 26/26 [00:11<00:00,  2.23it/s, AUC=0.914, acc=0.705, val_loss=0.87729097]
# Training Epoch [13/50]: 100%|██████████████████████████████████████████████████████████████████████████| 245/245 [03:37<00:00,  1.13it/s, AUC=0.997, acc=0.965, complete_loss=0.1183, train_loss=0.1183]
# Validation Epoch [13/50]: 100%|██████████████████████████████████████████████████████████████████████████████████████████████| 26/26 [00:12<00:00,  2.05it/s, AUC=0.913, acc=0.728, val_loss=0.91171275]
# Early stopping at epoch 13
# Test model Ensembling - Loss: 0.91, ACC: 0.73, AUC: 0.91, Sensivility: 0.71, Specificity: 0.71

# %%
test_model(model, val_dataset.get_dataloader(), trainer, device)
test_model(model, train_dataset.get_dataloader(), trainer, device)
# Out:
# /usr/local/lib/python3.10/dist-packages/torchmetrics/utilities/prints.py:43: UserWarning: No positive samples in targets, true positive value should be meaningless. Returning zero tensor in true positive score
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Test model Ensembling - Loss: 0.91, ACC: 0.73, AUC: 0.91, Sensivility: 0.71, Specificity: 0.71
# /usr/local/lib/python3.10/dist-packages/torchmetrics/utilities/prints.py:43: UserWarning: No positive samples in targets, true positive value should be meaningless. Returning zero tensor in true positive score
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Test model Ensembling - Loss: 0.02, ACC: 1.00, AUC: 1.00, Sensivility: 1.00, Specificity: 0.99
